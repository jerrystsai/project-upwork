# %%
import json
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import time
import datetime
import re
import cPickle as pickle

from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error

# %%
### MAKE PICKLES OF NEW DATAFRAMES
infile_skills_vectorized = 'data/_skills_vectorized_df.pkl'
infile_profiles = 'data/profiles_df.pkl'
infile_jobs = 'data/jobs_df.pkl'
infile_hr_paid_jobs = 'data/hr_paid_jobs_df.pkl'
infile_skills = 'data/skills_df.pkl'

# %%
# jobs_df = pickle.load(open(infile_jobs, 'rb'))  THESE DATA ARE FROM THE (PROVIDER) PROFILES DATA SET
#   GOING TO TAP THE RICHER JOBS PROFILES DATA SET BELOW
profiles_df = pickle.load(open(infile_profiles, 'rb'))
skills_df = pickle.load(open(infile_skills, 'rb'))

# %%
profiles_df.T.head(35)
# Out:
#                                                                   0      \
# dev_bill_rate                                                        15
# dev_blurb             Over the more than 6 years, I have developed a...
# dev_country                                                       India
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                 LAMP developer with more than 6 years
# dev_recno_ciphertext                                ~01cae3810dc6d2bbbc
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education             {u'institution': {u'ed_to': u'07/2007', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                  Masters
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         ajax apidashdevelopment curl javascript magent...
#
#                                                                   1      \
# dev_bill_rate                                                        12
# dev_blurb             I am a web application developer, having 2 yea...
# dev_country                                                       India
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                              Web Developer / Designer
# dev_recno_ciphertext                                ~01d24ced467385214d
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education             {u'institution': {u'ed_to': u'12/2012', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                         Bachelor of Engineering (B.Eng.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         ajax css3 grails groovy javascript jquery mysq...
#
#                                                                   2      \
# dev_bill_rate                                                     44.44
# dev_blurb             Extensive expertise in clinical research publi...
# dev_country                                               United States
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     English/French Writer/Translator,Scientific Di...
# dev_recno_ciphertext                                ~01953fb4fa2ceb67dc
# dev_timezone          UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# education             {u'institution': [{u'ed_to': u'12/2002', u'ed_...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree               Master of Business Administration (M.B.A.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         articledashwriting creativedashwriting datadas...
#
#                                                                   3      \
# dev_bill_rate                                                     24.44
# dev_blurb             I'm a WEB-developer with more than 5 years exp...
# dev_country                                                     Ukraine
# dev_eng_skill                                                         5
# dev_portrait
# dev_profile_title     PHP/Zend Framework/MySql/MongoDB/SPHINX/jQuery...
# dev_recno_ciphertext                                ~01a9ab111f973ae055
# dev_timezone                       UTC+02:00 Athens, Helsinki, Istanbul
# education
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                      False
# highest_degree                             Doctor of Philosophy (Ph.D.)
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         facebookdashapi googledashmapsdashapi html5 jq...
#
#                                                                   4      \
# dev_bill_rate                                                        15
# dev_blurb             Specializes in developing Photoshop and After ...
# dev_country                                                   Sri Lanka
# dev_eng_skill
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     After Effects, Photoshop - Scripting And Plugi...
# dev_recno_ciphertext                                ~016dcec1087cba565c
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         actionscriptdash3 adobedashafterdasheffects ad...
#
#                                                                   5      \
# dev_bill_rate                                                     16.67
# dev_blurb
# dev_country                                                     Germany
# dev_eng_skill                                                         5
# dev_portrait
# dev_profile_title     Development of reliable and flexible software(...
# dev_recno_ciphertext                                ~019e83a0dfa04c0e8b
# dev_timezone          UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# education             {u'institution': {u'ed_to': u'01/2008', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                      False
# highest_degree                                                    Other
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         cplusplus java oracledashdatabase perl php qt ...
#
#                                                                   6      \
# dev_bill_rate                                                        30
# dev_blurb             skype :  orange_project_kh\nemail:    contact@...
# dev_country                                                     Ukraine
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     Fullstack web developer, e-commerce developing...
# dev_recno_ciphertext                                ~01863825efc778f975
# dev_timezone                                   UTC+02:00 Eastern Europe
# education             {u'institution': {u'ed_to': u'12/2015', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                Bachelors
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         css3 html5 internetdashresearch javascript mys...
#
#                                                                   7      \
# dev_bill_rate                                                     11.11
# dev_blurb             DTL Solutions is the software solutions provid...
# dev_country                                                     Vietnam
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     Small IT solution company provides Development...
# dev_recno_ciphertext                                ~01614e82e3c5a0ccca
# dev_timezone                                UTC+07:00 Omsk, Novosibirsk
# education
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree               Master of Business Administration (M.B.A.)
# has_portfolio                                                      True
# took_tests                                                        False
# skills_string         agiledashsoftwaredashdevelopment androiddashap...
#
#                                                                   8      \
# dev_bill_rate                                                        10
# dev_blurb             I am an upcoming college graduate! I will rece...
# dev_country                                               United States
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title               Upbeat Enthusiastic Professional Writer
# dev_recno_ciphertext                                ~0122260b02b0c56563
# dev_timezone              UTC-08:00 Pacific Time (US & Canada); Tijuana
# education             {u'institution': {u'ed_to': u'Present', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         creativedashwriting datadashanalysis editorial...
#
#                                                                   9      \
# dev_bill_rate                                                      5.56
# dev_blurb             1)  Shopping Card Management System using C# a...
# dev_country                                                  Bangladesh
# dev_eng_skill
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title               Bsc in Computer Science and Engineering
# dev_recno_ciphertext                                ~01a3583a33f5146e8e
# dev_timezone                                    UTC+06:00 Almaty, Dhaka
# education             {u'institution': {u'ed_to': u'12/2014', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                Bachelors
# has_portfolio                                                     False
# took_tests                                                        False
# skills_string         androiddashappdashdevelopment csharp css3 html...
#
#                                             ...                          \
# dev_bill_rate                               ...
# dev_blurb                                   ...
# dev_country                                 ...
# dev_eng_skill                               ...
# dev_portrait                                ...
# dev_profile_title                           ...
# dev_recno_ciphertext                        ...
# dev_timezone                                ...
# education                                   ...
# agency_affl                                 ...
# group_affl                                  ...
# has_portrait                                ...
# highest_degree                              ...
# has_portfolio                               ...
# took_tests                                  ...
# skills_string                               ...
#
#                                                                   88686  \
# dev_bill_rate                                                     22.22
# dev_blurb             I'm a software engineer focused on backend and...
# dev_country                                                      Russia
# dev_eng_skill                                                         3
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                    Software Developer
# dev_recno_ciphertext                                ~01dfd63f31c5228d16
# dev_timezone                                UTC+07:00 Omsk, Novosibirsk
# education
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                  Diploma
# has_portfolio                                                      True
# took_tests                                                        False
# skills_string         css djangodashframework javascript linuxdashsy...
#
#                                                                   88687  \
# dev_bill_rate                                                         4
# dev_blurb             I am  working as a  officer at Checkpoint syst...
# dev_country                                                  Bangladesh
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                       IT Professional
# dev_recno_ciphertext                                ~018aaab6cfdc3fb96c
# dev_timezone                                    UTC+06:00 Almaty, Dhaka
# education             {u'institution': [{u'ed_to': u'12/2015', u'ed_...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                 Master of Computer Applications (M.C.A.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         adobedashillustrator adobedashphotoshop micros...
#
#                                                                   88688  \
# dev_bill_rate                                                      6.67
# dev_blurb             To enhance my journalistic prowess through onl...
# dev_country                                                 Philippines
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     Statistician|News&Sports Writer|InDesign|Pagem...
# dev_recno_ciphertext                                ~01360017155d421ae3
# dev_timezone          UTC+08:00 Hong Kong SAR, Perth, Singapore, Taipei
# education             {u'institution': {u'ed_to': u'04/2012', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                            Bachelor of Education (B.Ed.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         adobedashindesign adobedashpagemaker copywriti...
#
#                                                                   88689  \
# dev_bill_rate                                                     13.89
# dev_blurb             I'm a highly motivated person with a strong ba...
# dev_country                                                      Russia
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title        Experienced developer and scientific assistant
# dev_recno_ciphertext                                ~0169007d9fa447a06b
# dev_timezone                UTC+03:00 Moscow, St. Petersburg, Volgograd
# education             {u'institution': [{u'ed_to': u'Present', u'ed_...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                        Bachelor's degree
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         cprog cplusplus embeddeddashsystems hibernate ...
#
#                                                                   88690  \
# dev_bill_rate                                                        10
# dev_blurb             I like building cool web applications, and I o...
# dev_country                                                       India
# dev_eng_skill                                                         5
# dev_portrait
# dev_profile_title     An expert web application developer with Djang...
# dev_recno_ciphertext                                ~014920c811cecebbc4
# dev_timezone                           UTC (Coordinated Universal Time)
# education             {u'institution': {u'ed_to': u'12/2014', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                      False
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         css djangodashframework html javascript jquery...
#
#                                                                   88691  \
# dev_bill_rate                                                     16.67
# dev_blurb             I configure and run the base station WiMAX on ...
# dev_country                                                      Russia
# dev_eng_skill                                                         3
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                    Software Developer
# dev_recno_ciphertext                                ~0148cf1eca9907db89
# dev_timezone                UTC+04:00 Abu Dhabi, Muscat, Tbilisi, Kazan
# education             {u'institution': {u'ed_to': u'12/2012', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                            Bachelor of Commerce (B.Com.)
# has_portfolio                                                     False
# took_tests                                                        False
# skills_string         cplusplus ciscodashrouters freebsd gwt java li...
#
#                                                                   88692  \
# dev_bill_rate                                                     11.11
# dev_blurb             I am looking to help in software solutions . w...
# dev_country                                                       Egypt
# dev_eng_skill                                                         5
# dev_portrait          https://www.odesk.com/att/~~mOJyJwUvL-dOchJGOo...
# dev_profile_title                                           Ahmed Eshra
# dev_recno_ciphertext                                ~01baacbe6b9e3d8c30
# dev_timezone                                            UTC+02:00 Cairo
# education             {u'institution': {u'ed_to': u'Present', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                 Master's
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         androiddashappdashdevelopment cprog cplusplus ...
#
#                                                                   88693  \
# dev_bill_rate                                                        35
# dev_blurb             I have extensive experience using Python to so...
# dev_country                                               United States
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                            Python & ArcGIS Programmer
# dev_recno_ciphertext                                ~013659f86de224bdf9
# dev_timezone                      UTC-07:00 Mountain Time (US & Canada)
# education             {u'institution': {u'ed_to': u'12/2005', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                       Bachelor of Architecture (B.Arch.)
# has_portfolio                                                     False
# took_tests                                                        False
# skills_string                                     arcgis autocad python
#
#                                                                   88694  \
# dev_bill_rate                                                         3
# dev_blurb             Looking for work in proofreading, editing or c...
# dev_country                                                       India
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title
# dev_recno_ciphertext                                ~01b9ca1c9967daf519
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education             {u'institution': {u'ed_to': u'12/2015', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         englishdashgrammar matlab microsoftdashexcel m...
#
#                                                                   88695
# dev_bill_rate                                                        30
# dev_blurb             I have 8 Years of Profession Experience and i ...
# dev_country                                                       India
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                          Project Lead
# dev_recno_ciphertext                                ~01a0cdfa47888e70f7
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education             {u'institution': {u'ed_to': u'12/2013', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                  Masters
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         apachedashstruts hibernate java javadashservle...
#
# [16 rows x 88696 columns]

# %%
skills_df.T.head(35)
# Out:
#                                    0                    1       \
# dev_recno_ciphertext  ~01cae3810dc6d2bbbc  ~01cae3810dc6d2bbbc
# skl_name                             ajax      api-development
#
#                                    2                    3       \
# dev_recno_ciphertext  ~01cae3810dc6d2bbbc  ~01cae3810dc6d2bbbc
# skl_name                             curl           javascript
#
#                                    4                    5       \
# dev_recno_ciphertext  ~01cae3810dc6d2bbbc  ~01cae3810dc6d2bbbc
# skl_name                          magento                mysql
#
#                                    6                    7       \
# dev_recno_ciphertext  ~01cae3810dc6d2bbbc  ~01cae3810dc6d2bbbc
# skl_name                              php                 smtp
#
#                                    8                    9       \
# dev_recno_ciphertext  ~01cae3810dc6d2bbbc  ~01cae3810dc6d2bbbc
# skl_name                              xml              xml-rpc
#
#                              ...                        691868  \
# dev_recno_ciphertext         ...           ~01a0cdfa47888e70f7
# skl_name                     ...                 apache-struts
#
#                                    691869               691870  \
# dev_recno_ciphertext  ~01a0cdfa47888e70f7  ~01a0cdfa47888e70f7
# skl_name                        hibernate                 java
#
#                                          691871               691872  \
# dev_recno_ciphertext        ~01a0cdfa47888e70f7  ~01a0cdfa47888e70f7
# skl_name              java-servlets-development           javascript
#
#                                    691873               691874  \
# dev_recno_ciphertext  ~01a0cdfa47888e70f7  ~01a0cdfa47888e70f7
# skl_name                              jpa                  jsp
#
#                                    691875               691876  \
# dev_recno_ciphertext  ~01a0cdfa47888e70f7  ~01a0cdfa47888e70f7
# skl_name                  oracle-database            richfaces
#
#                                    691877
# dev_recno_ciphertext  ~01a0cdfa47888e70f7
# skl_name                 spring-framework
#
# [2 rows x 691878 columns]

# %% [markdown]
# # Investigate jobs profiles data set

# %%
def json_prep(in_file):
    '''
    Create pandas dataframe from text file of JSON strings
    '''
    # read the entire file `ainto a python array
    with open(in_file, 'rb') as f:
        data = f.readlines()

    # remove the trailing "\n" from each line
    data = map(lambda x: x.rstrip(), data)

    # each element of 'data' is an individual JSON object.
    # i want to convert it into an *array* of JSON objects
    # which, in and of itself, is one large JSON object
    # basically... add square brackets to the beginning
    # and end, and have all the individual business JSON objects
    # separated by a comma
    data_json_str = "[" + ','.join(data) + "]"

    data_list_of_dicts = json.loads(data_json_str)

    out_df = pd.read_json(data_json_str)
    return out_df

# %%
def grab_data(datalist, creature, id_, list_of_keys):
    if isinstance(creature, basestring):
        pass
    elif isinstance(creature, dict):
        tuple_to_add = tuple([id_] + [creature.get(key, '') for key in list_of_keys])
        datalist.append(tuple_to_add)
    elif isinstance(creature, list):
        for creature_item in creature:
            tuple_to_add = tuple([id_] + [creature_item.get(key, '') for key in list_of_keys])
            datalist.append(tuple_to_add)

# %%
def triage(dict_, level=0):
    '''
    Visualize JSON data
    "Pretty Print" data, showing nesting via indentation
    '''
    if not(isinstance(dict_, float) or isinstance(dict_, basestring)):
        print type(dict_)
        for key, val in dict_.iteritems():
            print ' '*level*2, key
            if isinstance(val, dict):
                triage(val, level=level+1)
            elif isinstance(val, list):
                for index, item in enumerate(val):
                    print ' '*level*2, 'item', index
                    triage(item, level=level+1)
            elif isinstance(val, basestring):
                print ' '*(level+1)*2, '=', val

# %%
jobs_profiles_df = json_prep('data/jobs_da_0.txt')

# %%
jobs_profiles_df.T.head(40)
# Out:
#                                                                           0     \
# amount                                                                      30
# assignment_info              {u'info': {u'end_data': u'1338768000000', u'ci...
# assignments                  {u'assignment': [{u'as_total_hours': u'0', u'a...
# buyer                        {u'op_timezone': u'UTC+01:00 Berlin, Stockholm...
# candidates                   {u'candidate': {u'ciphertext': u'~01ca3b6ff3e6...
# ciphertext                                                 ~01036ab99176fc9ca7
# engagement_weeks
# interviewees_total_active                                                    0
# job_category_level_one                                         Web Development
# job_category_level_two                                              Web Design
# job_type                                                                 Fixed
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1329663676000
# op_description               We need some deisgns for our website.\n\nIts e...
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                      0
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_low_hourly_rate_all                                                       0
# op_other_jobs
# op_pref_english_skill
# op_pref_fb_score
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours
# op_required_skills           {u'op_required_skill': [{u'skill': u'adobe-ill...
# op_title                                                 Web designer project.
# op_tot_cand                                                                  1
# op_tot_feedback                                                              3
# ui_opening_status                                                       Filled
#
#                                                                           1     \
# amount                                                                       5
# assignment_info              {u'info': {u'end_data': u'1318982400000', u'ci...
# assignments                  {u'assignment': [{u'as_total_hours': u'0', u'a...
# buyer                        {u'op_timezone': u'UTC-05:00 Eastern Time (US ...
# candidates                   {u'candidate': {u'ciphertext': u'~01eef64ef43a...
# ciphertext                                                 ~01036ecca7fbdb9d47
# engagement_weeks
# interviewees_total_active                                                    0
# job_category_level_one                                   Writing & Translation
# job_category_level_two                                  Blog & Article Writing
# job_type                                                                 Fixed
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1318941797000
# op_description               Each writer will be give a set of keywords.  M...
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                      0
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Article & B...
# op_low_hourly_rate_all                                                       0
# op_other_jobs
# op_pref_english_skill
# op_pref_fb_score
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours
# op_required_skills           {u'op_required_skill': {u'skill': u'article-wr...
# op_title                                   Article Writers - Fast and Reliable
# op_tot_cand                                                                  1
# op_tot_feedback                                                             43
# ui_opening_status                                                       Filled
#
#                                                                           2     \
# amount
# assignment_info              {u'info': {u'total_charge': u'498.33', u'end_d...
# assignments                  {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer                        {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates                   {u'candidate': [{u'ciphertext': u'~01f1c24717c...
# ciphertext                                                 ~0103703f207be9f938
# engagement_weeks                                              Less than 1 week
# interviewees_total_active                                                    0
# job_category_level_one
# job_category_level_two
# job_type                                                                Hourly
# op_additional_questions      {u'op_additional_question': [{u'position': u'1...
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier                                                           1
# op_ctime                                                         1430895397000
# op_description               Post archive page and post page designed to ma...
# op_engagement                                As needed - Less than 10 hrs/week
# op_high_hourly_rate_all                                                     35
# op_is_cover_letter_required                                                  0
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Web Develop...
# op_low_hourly_rate_all                                                       3
# op_other_jobs
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max                                                      0
# op_pref_hourly_rate_min                                                      0
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills            {u'op_required_skill': {u'skill': u'wordpress'}}
# op_title                                                   WordPress Templates
# op_tot_cand                                                                 62
# op_tot_feedback                                                              9
# ui_opening_status                                                       Filled
#
#                                                                           3     \
# amount
# assignment_info              {u'info': [{u'total_charge': u'0', u'end_data'...
# assignments                  {u'assignment': [{u'as_total_hours': u'3.33', ...
# buyer                        {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates                   {u'candidate': [{u'ciphertext': u'~01cde4ef409...
# ciphertext                                                 ~01037164e7e1613e2f
# engagement_weeks                                            More than 6 months
# interviewees_total_active                                                    0
# job_category_level_one
# job_category_level_two
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier                                                           2
# op_ctime                                                         1446497383000
# op_description               Hi,\n\nWe are a company with a special niche a...
# op_engagement                                As needed - Less than 10 hrs/week
# op_high_hourly_rate_all                                                  38.89
# op_is_cover_letter_required                                                  1
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Lead Genera...
# op_low_hourly_rate_all                                                    3.33
# op_other_jobs                {u'op_other_job': [{u'op_ciphertext': u'~019c8...
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills           {u'op_required_skill': [{u'skill': u'internet-...
# op_title                                       Generate lead for special niche
# op_tot_cand                                                                 14
# op_tot_feedback                                                             23
# ui_opening_status                                                       Filled
#
#                                                                           4     \
# amount                                                                     150
# assignment_info              {u'info': {u'end_data': u'1376006400000', u'ci...
# assignments                  {u'assignment': [{u'as_total_hours': u'0', u'a...
# buyer                        {u'op_timezone': u'UTC+01:00 Berlin, Stockholm...
# candidates                   {u'candidate': [{u'ciphertext': u'~01e546ffa0d...
# ciphertext                                                 ~01037313aee93f572b
# engagement_weeks
# interviewees_total_active                                                    0
# job_category_level_one                                         Web Development
# job_category_level_two                                 Other - Web Development
# job_type                                                                 Fixed
# op_additional_questions
# op_attached_doc              https://www.odesk.com/att/~~nT9iPWRj*QWfvkrgu7...
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1371043816000
# op_description               Hi,\n\nWe're looking for someone with Joomla, ...
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                      0
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Other - Sof...
# op_low_hourly_rate_all                                                       0
# op_other_jobs                {u'op_other_job': {u'op_ciphertext': u'~0118be...
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills           {u'op_required_skill': [{u'skill': u'css'}, {u...
# op_title                                                  Basic Joomla website
# op_tot_cand                                                                 47
# op_tot_feedback                                                             45
# ui_opening_status                                                       Filled
#
#                                                                           5     \
# amount                                                                  250.00
# assignment_info              {u'info': {u'end_data': u'1416355200000', u'ci...
# assignments                  {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer                        {u'op_timezone': u'UTC (Coordinated Universal ...
# candidates                   {u'candidate': [{u'ciphertext': u'~01e02cdeeb0...
# ciphertext                                                 ~010373177cb75fac67
# engagement_weeks
# interviewees_total_active                                                    0
# job_category_level_one                                    Software Development
# job_category_level_two                                     Scripts & Utilities
# job_type                                                                 Fixed
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1410011062000
# op_description               Morning\n\nI'm looking for a developer to crea...
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                      0
# op_is_cover_letter_required                                                  1
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Scripts & U...
# op_low_hourly_rate_all                                                       0
# op_other_jobs
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills
# op_title                     Create a dashboard to collect reviews and auto...
# op_tot_cand                                                                  5
# op_tot_feedback                                                             49
# ui_opening_status                                                       Filled
#
#                                                                           6     \
# amount                                                                       8
# assignment_info              {u'info': {u'end_data': u'1389657600000', u'ci...
# assignments                  {u'assignment': [{u'as_to': u'04/2016', u'as_r...
# buyer                        {u'op_timezone': u'UTC-05:00 Eastern Time (US ...
# candidates                   {u'candidate': [{u'ciphertext': u'~01ee1be0350...
# ciphertext                                                 ~01037460b8b2e770bb
# engagement_weeks
# interviewees_total_active                                                    0
# job_category_level_one                                  Administrative Support
# job_category_level_two                                              Data Entry
# job_type                                                                 Fixed
# op_additional_questions      {u'op_additional_question': [{u'position': u'1...
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1389671728000
# op_description                             Update images url for 2000 products
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                      0
# op_is_cover_letter_required                                                  0
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Data Entry'...
# op_low_hourly_rate_all                                                       0
# op_other_jobs
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills           {u'op_required_skill': {u'skill': u'microsoft-...
# op_title                                                   Update spread sheet
# op_tot_cand                                                                 66
# op_tot_feedback                                                              8
# ui_opening_status                                                       Filled
#
#                                                                           7     \
# amount
# assignment_info              {u'info': {u'end_data': u'1318809600000', u'ci...
# assignments                  {u'assignment': [{u'as_to': u'12/2013', u'as_r...
# buyer                        {u'op_timezone': u'UTC+10:00 Brisbane', u'op_t...
# candidates                   {u'candidate': [{u'ciphertext': u'~010973123f7...
# ciphertext                                                 ~010374b5de700160df
# engagement_weeks                                              Less than 1 week
# interviewees_total_active                                                    0
# job_category_level_one                                         Web Development
# job_category_level_two                                              Web Design
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1311225937000
# op_description               Hi,\n\nIm wanting to have a joomla template ch...
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                  27.78
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_low_hourly_rate_all                                                    4.44
# op_other_jobs
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max                                                      0
# op_pref_hourly_rate_min                                                      0
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills           {u'op_required_skill': [{u'skill': u'joomla'},...
# op_title                                                       Joomla 1.5 site
# op_tot_cand                                                                 36
# op_tot_feedback                                                              8
# ui_opening_status                                                       Filled
#
#                                                                           8     \
# amount                                                                  400.00
# assignment_info              {u'info': [{u'total_charge': u'0', u'end_data'...
# assignments                  {u'assignment': {u'as_total_hours': u'0', u'as...
# buyer                        {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates                   {u'candidate': [{u'ciphertext': u'~018c64192f2...
# ciphertext                                                 ~010376f8c47b978d93
# engagement_weeks
# interviewees_total_active                                                    0
# job_category_level_one                                         Web Development
# job_category_level_two                                              Web Design
# job_type                                                                 Fixed
# op_additional_questions      {u'op_additional_question': [{u'position': u'1...
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier                                                           3
# op_ctime                                                         1416513273000
# op_description                                                       Modernize
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                      0
# op_is_cover_letter_required                                                  1
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_low_hourly_rate_all                                                       0
# op_other_jobs
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills
# op_title                                                         Sidler-ng.com
# op_tot_cand                                                                 13
# op_tot_feedback                                                              0
# ui_opening_status                                                       Filled
#
#                                                                           9     \
# amount
# assignment_info              {u'info': {u'end_data': u'1436313600000', u'ci...
# assignments                  {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer                        {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates                   {u'candidate': [{u'ciphertext': u'~011a4fcf20c...
# ciphertext                                                 ~01037713e90f373b91
# engagement_weeks                                              Less than 1 week
# interviewees_total_active                                                    0
# job_category_level_one
# job_category_level_two
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier                                                           2
# op_ctime                                                         1434671597000
# op_description               Need help getting my Drupal store back up and ...
# op_engagement                                       Part-time - 10-30 hrs/week
# op_high_hourly_rate_all                                                     27
# op_is_cover_letter_required                                                  1
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Desktop Sof...
# op_low_hourly_rate_all                                                       7
# op_other_jobs
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max                                                      0
# op_pref_hourly_rate_min                                                      0
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills
# op_title                                             Drupal Ecommerce Site Fix
# op_tot_cand                                                                 27
# op_tot_feedback                                                             35
# ui_opening_status                                                       Filled
#
#                                                    ...                          \
# amount                                             ...
# assignment_info                                    ...
# assignments                                        ...
# buyer                                              ...
# candidates                                         ...
# ciphertext                                         ...
# engagement_weeks                                   ...
# interviewees_total_active                          ...
# job_category_level_one                             ...
# job_category_level_two                             ...
# job_type                                           ...
# op_additional_questions                            ...
# op_attached_doc                                    ...
# op_cny_upm_verified                                ...
# op_contractor_tier                                 ...
# op_ctime                                           ...
# op_description                                     ...
# op_engagement                                      ...
# op_high_hourly_rate_all                            ...
# op_is_cover_letter_required                        ...
# op_job_category_v2                                 ...
# op_low_hourly_rate_all                             ...
# op_other_jobs                                      ...
# op_pref_english_skill                              ...
# op_pref_fb_score                                   ...
# op_pref_group_id                                   ...
# op_pref_group_logo                                 ...
# op_pref_group_name                                 ...
# op_pref_has_portfolio                              ...
# op_pref_hourly_rate_max                            ...
# op_pref_hourly_rate_min                            ...
# op_pref_location                                   ...
# op_pref_odesk_hours                                ...
# op_required_skills                                 ...
# op_title                                           ...
# op_tot_cand                                        ...
# op_tot_feedback                                    ...
# ui_opening_status                                  ...
#
#                                                                           7872  \
# amount                                                                      20
# assignment_info              {u'info': {u'end_data': u'1334966400000', u'ci...
# assignments                  {u'assignment': [{u'as_total_hours': u'0', u'a...
# buyer                        {u'op_timezone': u'UTC-06:00 Central Time (US ...
# candidates                   {u'candidate': {u'ciphertext': u'~01f120be2a0d...
# ciphertext                                                 ~01274b7db3f83e986c
# engagement_weeks
# interviewees_total_active                                                    0
# job_category_level_one                                       Sales & Marketing
# job_category_level_two                                 Sales & Lead Generation
# job_type                                                                 Fixed
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1326511487000
# op_description               This job requires you to have a fast internet ...
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                      0
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Lead Genera...
# op_low_hourly_rate_all                                                       0
# op_other_jobs
# op_pref_english_skill
# op_pref_fb_score
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours
# op_required_skills           {u'op_required_skill': {u'skill': u'spreadshee...
# op_title                                         Virtual Lead Generator Needed
# op_tot_cand                                                                  1
# op_tot_feedback                                                              9
# ui_opening_status                                                       Filled
#
#                                                                           7873  \
# amount                                                                    0.00
# assignment_info              {u'info': [{u'end_data': u'1451347200000', u'c...
# assignments                  {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer                        {u'op_timezone': u'UTC+05:00 Islamabad, Karach...
# candidates                   {u'candidate': {u'ciphertext': u'~01e495c52e01...
# ciphertext                                                 ~01274cff9a4becab2e
# engagement_weeks                                              Less than 1 week
# interviewees_total_active                                                    0
# job_category_level_one
# job_category_level_two
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier                                                           2
# op_ctime                                                         1448980384000
# op_description               - Job description\nI need a senior django deve...
# op_engagement                                As needed - Less than 10 hrs/week
# op_high_hourly_rate_all                                                  27.78
# op_is_cover_letter_required                                                  1
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Web Develop...
# op_low_hourly_rate_all                                                   27.78
# op_other_jobs                {u'op_other_job': [{u'op_ciphertext': u'~01704...
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max                                                      0
# op_pref_hourly_rate_min                                                      0
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills
# op_title                              Senior Python/Django/Bootstrap developer
# op_tot_cand                                                                  1
# op_tot_feedback                                                             99
# ui_opening_status                                                       Filled
#
#                                                                           7874  \
# amount
# assignment_info              {u'info': [{u'end_data': u'1359590400000', u'c...
# assignments                  {u'assignment': [{u'as_total_hours': u'52', u'...
# buyer                        {u'op_timezone': u'UTC-05:00 Eastern Time (US ...
# candidates                   {u'candidate': [{u'ciphertext': u'~015a583df5a...
# ciphertext                                                 ~01274d1cb929fb7d32
# engagement_weeks                                             Less than 1 month
# interviewees_total_active                                                    0
# job_category_level_one                                         Web Development
# job_category_level_two                                               UI Design
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1350832640000
# op_description               Surpass the Limit is a social platform where u...
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                  72.22
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_low_hourly_rate_all                                                    2.22
# op_other_jobs
# op_pref_english_skill                                                        0
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max                                                      0
# op_pref_hourly_rate_min                                                      0
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills           {u'op_required_skill': [{u'skill': u'adobe-fir...
# op_title                                   UI Design, Wireframing, Prototyping
# op_tot_cand                                                                 38
# op_tot_feedback                                                             11
# ui_opening_status                                                       Filled
#
#                                                                           7875  \
# amount
# assignment_info              {u'info': {u'end_data': u'1349740800000', u'ci...
# assignments                  {u'assignment': [{u'as_to': u'02/2016', u'as_r...
# buyer                        {u'op_timezone': u'UTC+01:00 Berlin, Stockholm...
# candidates                   {u'candidate': [{u'ciphertext': u'~010d9ec6757...
# ciphertext                                                 ~0127500b1b70ff31b2
# engagement_weeks                                              Less than 1 week
# interviewees_total_active                                                    0
# job_category_level_one                                         Web Development
# job_category_level_two                                 Other - Web Development
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1272668981000
# op_description               Create the speaker pages for a conference.\n\n...
# op_engagement                                As needed - Less than 10 hrs/week
# op_high_hourly_rate_all                                                  16.67
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Other - Sof...
# op_low_hourly_rate_all                                                    4.44
# op_other_jobs
# op_pref_english_skill
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours
# op_required_skills                 {u'op_required_skill': {u'skill': u'html'}}
# op_title                          Create html files using a template from text
# op_tot_cand                                                                 27
# op_tot_feedback                                                             14
# ui_opening_status                                                       Filled
#
# ...
#
#                                                                           7877  \
# amount                                                                  400.00
# assignment_info              {u'info': {u'end_data': u'1449792000000', u'ci...
# assignments                  {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer                        {u'op_timezone': u'UTC+10:00 Sydney, Melbourne...
# candidates
# ciphertext                                                 ~01275285137d94fcb4
# engagement_weeks
# interviewees_total_active                                                    0
# job_category_level_one
# job_category_level_two
# job_type                                                                 Fixed
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier                                                           3
# op_ctime                                                         1449489763000
# op_description               Hi Mubbashar,\n\nas discussed, i need to scrap...
# op_engagement                                         Full-time - 30+ hrs/week
# op_high_hourly_rate_all                                                      0
# op_is_cover_letter_required                                                  1
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Data Extrac...
# op_low_hourly_rate_all                                                       0
# op_other_jobs
# op_pref_english_skill                                                        0
# op_pref_fb_score
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills           {u'op_required_skill': [{u'skill': u'amazon-we...
# op_title                                              Scrapping data of amazon
# op_tot_cand                                                                  0
# op_tot_feedback                                                             48
# ui_opening_status                                                       Filled
#
#                                                                           7878  \
# amount
# assignment_info              {u'info': {u'end_data': u'1354233600000', u'ci...
# assignments                  {u'assignment': {u'as_to': u'11/2012', u'as_ra...
# buyer                        {u'op_timezone': u'UTC (Coordinated Universal ...
# candidates                   {u'candidate': [{u'ciphertext': u'~01f9d6c47b2...
# ciphertext                                                 ~012753e9dd081c4643
# engagement_weeks                                              Less than 1 week
# interviewees_total_active                                                    0
# job_category_level_one                                         Web Development
# job_category_level_two                                         Web Programming
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1352065095000
# op_description               We need a web developer to implement  a few re...
# op_engagement                                As needed - Less than 10 hrs/week
# op_high_hourly_rate_all                                                  64.44
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Web Develop...
# op_low_hourly_rate_all                                                    4.44
# op_other_jobs
# op_pref_english_skill                                                        4
# op_pref_fb_score                                                             0
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        1
# op_pref_hourly_rate_max                                                      0
# op_pref_hourly_rate_min                                                      0
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills           {u'op_required_skill': [{u'skill': u'css'}, {u...
# op_title                                 Wordpress theme fixes, HTML, CSS, PHP
# op_tot_cand                                                                 53
# op_tot_feedback                                                              1
# ui_opening_status                                                       Filled
#
#                                                                           7879  \
# amount
# assignment_info              {u'info': {u'end_data': u'1342915200000', u'ci...
# assignments                  {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer                        {u'op_timezone': u'UTC+08:00 Hong Kong SAR, Pe...
# candidates                   {u'candidate': [{u'ciphertext': u'~0100d91faec...
# ciphertext                                                 ~0127547bbab346404b
# engagement_weeks                                            More than 6 months
# interviewees_total_active                                                    0
# job_category_level_one                                  Administrative Support
# job_category_level_two                                              Data Entry
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1331797836000
# op_description               We run a travel destination portal. On the sit...
# op_engagement                                As needed - Less than 10 hrs/week
# op_high_hourly_rate_all                                                   5.56
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Data Entry'...
# op_low_hourly_rate_all                                                    1.67
# op_other_jobs
# op_pref_english_skill                                                        4
# op_pref_fb_score                                                             4
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max                                                      3
# op_pref_hourly_rate_min                                                      1
# op_pref_location                                                    South Asia
# op_pref_odesk_hours                                                          0
# op_required_skills           {u'op_required_skill': [{u'skill': u'data-entr...
# op_title                                              Data Cleaning Specialist
# op_tot_cand                                                                  7
# op_tot_feedback                                                             21
# ui_opening_status                                                       Filled
#
#                                                                           7880  \
# amount
# assignment_info              {u'info': {u'end_data': u'1282089600000', u'ci...
# assignments                  {u'assignment': [{u'as_to': u'01/2011', u'as_r...
# buyer                        {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates
# ciphertext                                                 ~01275667fa5be0de44
# engagement_weeks                                              Less than 1 week
# interviewees_total_active                                                    0
# job_category_level_one                                         Web Development
# job_category_level_two                                              Web Design
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1281881877000
# op_description               We have an immediate need for an html/css code...
# op_engagement                                       Part-time - 10-30 hrs/week
# op_high_hourly_rate_all                                                      0
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_low_hourly_rate_all                                                       0
# op_other_jobs
# op_pref_english_skill
# op_pref_fb_score
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio
# op_pref_hourly_rate_max
# op_pref_hourly_rate_min
# op_pref_location
# op_pref_odesk_hours
# op_required_skills           {u'op_required_skill': [{u'skill': u'css'}, {u...
# op_title                     w3c html/css + javascript django template desi...
# op_tot_cand                                                                  0
# op_tot_feedback                                                              8
# ui_opening_status                                                       Filled
#
#                                                                           7881
# amount
# assignment_info              {u'info': {u'end_data': u'1356393600000', u'ci...
# assignments                  {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer                        {u'op_timezone': u'UTC+01:00 Berlin, Stockholm...
# candidates                   {u'candidate': [{u'ciphertext': u'~01a46a852de...
# ciphertext                                                 ~0127566a84c383a055
# engagement_weeks                                             Less than 1 month
# interviewees_total_active                                                    0
# job_category_level_one                                   Writing & Translation
# job_category_level_two                                  Blog & Article Writing
# job_type                                                                Hourly
# op_additional_questions
# op_attached_doc              https://www.odesk.com/att/~~nT9iPWRj*QU0ZgGhTn...
# op_cny_upm_verified                                                          1
# op_contractor_tier
# op_ctime                                                         1339361833000
# op_description               I need an Excel Macro (VBA) course for my web ...
# op_engagement                                       Part-time - 10-30 hrs/week
# op_high_hourly_rate_all                                                  17.78
# op_is_cover_letter_required
# op_job_category_v2           {u'op_job_category_v': {u'name': u'Article & B...
# op_low_hourly_rate_all                                                    3.33
# op_other_jobs
# op_pref_english_skill                                                        4
# op_pref_fb_score                                                             4
# op_pref_group_id                                                           NaN
# op_pref_group_logo                                                         NaN
# op_pref_group_name                                                         NaN
# op_pref_has_portfolio                                                        0
# op_pref_hourly_rate_max                                                      0
# op_pref_hourly_rate_min                                                      0
# op_pref_location
# op_pref_odesk_hours                                                          0
# op_required_skills           {u'op_required_skill': [{u'skill': u'microsoft...
# op_title                                            Excel macro – VBA - Course
# op_tot_cand                                                                 11
# op_tot_feedback                                                              9
# ui_opening_status                                                       Filled
#
# [38 rows x 7882 columns]

# %% [markdown]
# ### Drop evidently unuseful columns

# %% [markdown]
# ### Data leak

# %%
jobs_profiles_df.drop([ \
                       'amount', \
                       'engagement_weeks', \
                       'op_other_jobs', \
                       'ui_opening_status', \
                      ], axis=1, inplace=True)

# %% [markdown]
# ### Irrelevant

# %%
jobs_profiles_df.drop([ \
                        'interviewees_total_active', \
                        'op_additional_questions', \
                        'op_attached_doc', \
                        'op_cny_upm_verified', \
                        'op_is_cover_letter_required', \
                        'op_pref_group_id', \
                        'op_pref_group_logo', \
                        'op_pref_group_name' \
                      ], axis=1, inplace=True)

# %% [markdown]
# ### Deprecated

# %%
jobs_profiles_df.drop([ \
                        'job_category_level_one', \
                        'job_category_level_two'
                      ], axis=1, inplace=True)

# %% [markdown]
# ### Unsure and unlikely

# %%
jobs_profiles_df.drop([ \
                        'op_contractor_tier', \
                        'op_engagement', \
                        'op_high_hourly_rate_all', \
                        'op_low_hourly_rate_all', \
                        'op_pref_english_skill', \
                        'op_pref_fb_score', \
                        'op_pref_has_portfolio', \
                        'op_pref_hourly_rate_max', \
                        'op_pref_hourly_rate_min', \
                        'op_pref_location', \
                        'op_pref_odesk_hours', \
                        'op_tot_feedback' \
                      ], axis=1, inplace=True)

# %%
jobs_profiles_df.T.head(20)
# Out:
#                                                                  0     \
# assignment_info     {u'info': {u'end_data': u'1338768000000', u'ci...
# assignments         {u'assignment': [{u'as_total_hours': u'0', u'a...
# buyer               {u'op_timezone': u'UTC+01:00 Berlin, Stockholm...
# candidates          {u'candidate': {u'ciphertext': u'~01ca3b6ff3e6...
# ciphertext                                        ~01036ab99176fc9ca7
# job_type                                                        Fixed
# op_ctime                                                1329663676000
# op_description      We need some deisgns for our website.\n\nIts e...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_required_skills  {u'op_required_skill': [{u'skill': u'adobe-ill...
# op_title                                        Web designer project.
# op_tot_cand                                                         1
#
#                                                                  1     \
# assignment_info     {u'info': {u'end_data': u'1318982400000', u'ci...
# assignments         {u'assignment': [{u'as_total_hours': u'0', u'a...
# buyer               {u'op_timezone': u'UTC-05:00 Eastern Time (US ...
# candidates          {u'candidate': {u'ciphertext': u'~01eef64ef43a...
# ciphertext                                        ~01036ecca7fbdb9d47
# job_type                                                        Fixed
# op_ctime                                                1318941797000
# op_description      Each writer will be give a set of keywords.  M...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Article & B...
# op_required_skills  {u'op_required_skill': {u'skill': u'article-wr...
# op_title                          Article Writers - Fast and Reliable
# op_tot_cand                                                         1
#
#                                                                  2     \
# assignment_info     {u'info': {u'total_charge': u'498.33', u'end_d...
# assignments         {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer               {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates          {u'candidate': [{u'ciphertext': u'~01f1c24717c...
# ciphertext                                        ~0103703f207be9f938
# job_type                                                       Hourly
# op_ctime                                                1430895397000
# op_description      Post archive page and post page designed to ma...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Web Develop...
# op_required_skills   {u'op_required_skill': {u'skill': u'wordpress'}}
# op_title                                          WordPress Templates
# op_tot_cand                                                        62
#
#                                                                  3     \
# assignment_info     {u'info': [{u'total_charge': u'0', u'end_data'...
# assignments         {u'assignment': [{u'as_total_hours': u'3.33', ...
# buyer               {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates          {u'candidate': [{u'ciphertext': u'~01cde4ef409...
# ciphertext                                        ~01037164e7e1613e2f
# job_type                                                       Hourly
# op_ctime                                                1446497383000
# op_description      Hi,\n\nWe are a company with a special niche a...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Lead Genera...
# op_required_skills  {u'op_required_skill': [{u'skill': u'internet-...
# op_title                              Generate lead for special niche
# op_tot_cand                                                        14
#
#                                                                  4     \
# assignment_info     {u'info': {u'end_data': u'1376006400000', u'ci...
# assignments         {u'assignment': [{u'as_total_hours': u'0', u'a...
# buyer               {u'op_timezone': u'UTC+01:00 Berlin, Stockholm...
# candidates          {u'candidate': [{u'ciphertext': u'~01e546ffa0d...
# ciphertext                                        ~01037313aee93f572b
# job_type                                                        Fixed
# op_ctime                                                1371043816000
# op_description      Hi,\n\nWe're looking for someone with Joomla, ...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Other - Sof...
# op_required_skills  {u'op_required_skill': [{u'skill': u'css'}, {u...
# op_title                                         Basic Joomla website
# op_tot_cand                                                        47
#
#                                                                  5     \
# assignment_info     {u'info': {u'end_data': u'1416355200000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer               {u'op_timezone': u'UTC (Coordinated Universal ...
# candidates          {u'candidate': [{u'ciphertext': u'~01e02cdeeb0...
# ciphertext                                        ~010373177cb75fac67
# job_type                                                        Fixed
# op_ctime                                                1410011062000
# op_description      Morning\n\nI'm looking for a developer to crea...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Scripts & U...
# op_required_skills
# op_title            Create a dashboard to collect reviews and auto...
# op_tot_cand                                                         5
#
#                                                                  6     \
# assignment_info     {u'info': {u'end_data': u'1389657600000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'04/2016', u'as_r...
# buyer               {u'op_timezone': u'UTC-05:00 Eastern Time (US ...
# candidates          {u'candidate': [{u'ciphertext': u'~01ee1be0350...
# ciphertext                                        ~01037460b8b2e770bb
# job_type                                                        Fixed
# op_ctime                                                1389671728000
# op_description                    Update images url for 2000 products
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Data Entry'...
# op_required_skills  {u'op_required_skill': {u'skill': u'microsoft-...
# op_title                                          Update spread sheet
# op_tot_cand                                                        66
#
#                                                                  7     \
# assignment_info     {u'info': {u'end_data': u'1318809600000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'12/2013', u'as_r...
# buyer               {u'op_timezone': u'UTC+10:00 Brisbane', u'op_t...
# candidates          {u'candidate': [{u'ciphertext': u'~010973123f7...
# ciphertext                                        ~010374b5de700160df
# job_type                                                       Hourly
# op_ctime                                                1311225937000
# op_description      Hi,\n\nIm wanting to have a joomla template ch...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_required_skills  {u'op_required_skill': [{u'skill': u'joomla'},...
# op_title                                              Joomla 1.5 site
# op_tot_cand                                                        36
#
#                                                                  8     \
# assignment_info     {u'info': [{u'total_charge': u'0', u'end_data'...
# assignments         {u'assignment': {u'as_total_hours': u'0', u'as...
# buyer               {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates          {u'candidate': [{u'ciphertext': u'~018c64192f2...
# ciphertext                                        ~010376f8c47b978d93
# job_type                                                        Fixed
# op_ctime                                                1416513273000
# op_description                                              Modernize
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_required_skills
# op_title                                                Sidler-ng.com
# op_tot_cand                                                        13
#
#                                                                  9     \
# assignment_info     {u'info': {u'end_data': u'1436313600000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer               {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates          {u'candidate': [{u'ciphertext': u'~011a4fcf20c...
# ciphertext                                        ~01037713e90f373b91
# job_type                                                       Hourly
# op_ctime                                                1434671597000
# op_description      Need help getting my Drupal store back up and ...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Desktop Sof...
# op_required_skills
# op_title                                    Drupal Ecommerce Site Fix
# op_tot_cand                                                        27
#
#                                           ...                          \
# assignment_info                           ...
# assignments                               ...
# buyer                                     ...
# candidates                                ...
# ciphertext                                ...
# job_type                                  ...
# op_ctime                                  ...
# op_description                            ...
# op_job_category_v2                        ...
# op_required_skills                        ...
# op_title                                  ...
# op_tot_cand                               ...
#
#                                                                  7872  \
# assignment_info     {u'info': {u'end_data': u'1334966400000', u'ci...
# assignments         {u'assignment': [{u'as_total_hours': u'0', u'a...
# buyer               {u'op_timezone': u'UTC-06:00 Central Time (US ...
# candidates          {u'candidate': {u'ciphertext': u'~01f120be2a0d...
# ciphertext                                        ~01274b7db3f83e986c
# job_type                                                        Fixed
# op_ctime                                                1326511487000
# op_description      This job requires you to have a fast internet ...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Lead Genera...
# op_required_skills  {u'op_required_skill': {u'skill': u'spreadshee...
# op_title                                Virtual Lead Generator Needed
# op_tot_cand                                                         1
#
#                                                                  7873  \
# assignment_info     {u'info': [{u'end_data': u'1451347200000', u'c...
# assignments         {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer               {u'op_timezone': u'UTC+05:00 Islamabad, Karach...
# candidates          {u'candidate': {u'ciphertext': u'~01e495c52e01...
# ciphertext                                        ~01274cff9a4becab2e
# job_type                                                       Hourly
# op_ctime                                                1448980384000
# op_description      - Job description\nI need a senior django deve...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Web Develop...
# op_required_skills
# op_title                     Senior Python/Django/Bootstrap developer
# op_tot_cand                                                         1
#
#                                                                  7874  \
# assignment_info     {u'info': [{u'end_data': u'1359590400000', u'c...
# assignments         {u'assignment': [{u'as_total_hours': u'52', u'...
# buyer               {u'op_timezone': u'UTC-05:00 Eastern Time (US ...
# candidates          {u'candidate': [{u'ciphertext': u'~015a583df5a...
# ciphertext                                        ~01274d1cb929fb7d32
# job_type                                                       Hourly
# op_ctime                                                1350832640000
# op_description      Surpass the Limit is a social platform where u...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_required_skills  {u'op_required_skill': [{u'skill': u'adobe-fir...
# op_title                          UI Design, Wireframing, Prototyping
# op_tot_cand                                                        38
#
#                                                                  7875  \
# assignment_info     {u'info': {u'end_data': u'1349740800000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'02/2016', u'as_r...
# buyer               {u'op_timezone': u'UTC+01:00 Berlin, Stockholm...
# candidates          {u'candidate': [{u'ciphertext': u'~010d9ec6757...
# ciphertext                                        ~0127500b1b70ff31b2
# job_type                                                       Hourly
# op_ctime                                                1272668981000
# op_description      Create the speaker pages for a conference.\n\n...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Other - Sof...
# op_required_skills        {u'op_required_skill': {u'skill': u'html'}}
# op_title                 Create html files using a template from text
# op_tot_cand                                                        27
#
#                                                                  7876  \
# assignment_info     {u'info': {u'end_data': u'1275523200000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer               {u'op_timezone': u'UTC-05:00 Eastern Time (US ...
# candidates
# ciphertext                                        ~012750a2a32232cd0d
# job_type                                                        Fixed
# op_ctime                                                1275567746000
# op_description      Hi,\nwe need a few themes customized for Wordp...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Other - Sof...
# op_required_skills  {u'op_required_skill': [{u'skill': u'php'}, {u...
# op_title                                             Wordpress Expert
# op_tot_cand                                                         0
#
#                                                                  7877  \
# assignment_info     {u'info': {u'end_data': u'1449792000000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer               {u'op_timezone': u'UTC+10:00 Sydney, Melbourne...
# candidates
# ciphertext                                        ~01275285137d94fcb4
# job_type                                                        Fixed
# op_ctime                                                1449489763000
# op_description      Hi Mubbashar,\n\nas discussed, i need to scrap...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Data Extrac...
# op_required_skills  {u'op_required_skill': [{u'skill': u'amazon-we...
# op_title                                     Scrapping data of amazon
# op_tot_cand                                                         0
#
#                                                                  7878  \
# assignment_info     {u'info': {u'end_data': u'1354233600000', u'ci...
# assignments         {u'assignment': {u'as_to': u'11/2012', u'as_ra...
# buyer               {u'op_timezone': u'UTC (Coordinated Universal ...
# candidates          {u'candidate': [{u'ciphertext': u'~01f9d6c47b2...
# ciphertext                                        ~012753e9dd081c4643
# job_type                                                       Hourly
# op_ctime                                                1352065095000
# op_description      We need a web developer to implement  a few re...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Web Develop...
# op_required_skills  {u'op_required_skill': [{u'skill': u'css'}, {u...
# op_title                        Wordpress theme fixes, HTML, CSS, PHP
# op_tot_cand                                                        53
#
#                                                                  7879  \
# assignment_info     {u'info': {u'end_data': u'1342915200000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer               {u'op_timezone': u'UTC+08:00 Hong Kong SAR, Pe...
# candidates          {u'candidate': [{u'ciphertext': u'~0100d91faec...
# ciphertext                                        ~0127547bbab346404b
# job_type                                                       Hourly
# op_ctime                                                1331797836000
# op_description      We run a travel destination portal. On the sit...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Data Entry'...
# op_required_skills  {u'op_required_skill': [{u'skill': u'data-entr...
# op_title                                     Data Cleaning Specialist
# op_tot_cand                                                         7
#
#                                                                  7880  \
# assignment_info     {u'info': {u'end_data': u'1282089600000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'01/2011', u'as_r...
# buyer               {u'op_timezone': u'UTC-08:00 Pacific Time (US ...
# candidates
# ciphertext                                        ~01275667fa5be0de44
# job_type                                                       Hourly
# op_ctime                                                1281881877000
# op_description      We have an immediate need for an html/css code...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Web & Mobil...
# op_required_skills  {u'op_required_skill': [{u'skill': u'css'}, {u...
# op_title            w3c html/css + javascript django template desi...
# op_tot_cand                                                         0
#
#                                                                  7881
# assignment_info     {u'info': {u'end_data': u'1356393600000', u'ci...
# assignments         {u'assignment': [{u'as_to': u'Present', u'as_r...
# buyer               {u'op_timezone': u'UTC+01:00 Berlin, Stockholm...
# candidates          {u'candidate': [{u'ciphertext': u'~01a46a852de...
# ciphertext                                        ~0127566a84c383a055
# job_type                                                       Hourly
# op_ctime                                                1339361833000
# op_description      I need an Excel Macro (VBA) course for my web ...
# op_job_category_v2  {u'op_job_category_v': {u'name': u'Article & B...
# op_required_skills  {u'op_required_skill': [{u'skill': u'microsoft...
# op_title                                   Excel macro – VBA - Course
# op_tot_cand                                                        11
#
# [12 rows x 7882 columns]

# %% [markdown]
# # Create derived variables

# %%
def convert_millisecond_epoch_datetime(str):
    if str <> '':
        return datetime.datetime.fromtimestamp(int(str)/1000)
    else:
        return np.datetime64('nat')

# %%
def convert_epoch_datetime(str):
    if str <> '':
        return datetime.datetime.fromtimestamp(int(str))
    else:
        return np.datetime64('nat')

# %% [markdown]
# ### `assignment_info` : contains info on Providers who obtained the Assignment

# %%
assi_tuples = list()
key_list = ['ciphertext_developer_recno', 'start_date', 'end_data']
for index, assi_tuple in \
  enumerate(jobs_profiles_df[['ciphertext', 'assignment_info']].itertuples(index=False)):
    profile_id = assi_tuple[0]
    assi_info = assi_tuple[1]
    if 'info' in assi_info:
        grab_data(assi_tuples, assi_info['info'], profile_id, key_list)

# %%
assi_df = pd.DataFrame(assi_tuples)
assi_df.columns = ['ciphertext'] + key_list

# %%
assi_df['start_datetime'] = assi_df['start_date'].apply(convert_millisecond_epoch_datetime)
assi_df['end_datetime'] = assi_df['end_data'].apply(convert_millisecond_epoch_datetime)
assi_df.drop(['start_date', 'end_data'], axis=1, inplace=True)

# %% [markdown]
# ### `assignments` is a history of jobs offered by the Buyer

# %%
# for index, assi_tuple in \
#   enumerate(jobs_profiles_df[['ciphertext', 'assignments']].itertuples(index=False)):
#     profile_id = assi_tuple[0]
#     assi_info = assi_tuple[1]
#     if isinstance(assi_info, dict):
#         triage(assi_info)
#         print
#     if index > 1: break

# %% [markdown]
# ### `buyer`

# %%
buyers_tuples = list()
key_list = ['op_timezone', 'op_country', 'op_city', 'op_contract_date']
for index, buyer_tuple in \
  enumerate(jobs_profiles_df[['ciphertext', 'buyer']].itertuples(index=False)):
    profile_id = buyer_tuple[0]
    buyer_info = buyer_tuple[1]
    if isinstance(buyer_info, dict):
        grab_data(buyers_tuples, buyer_info, profile_id, key_list)

# %%
buyer_df = pd.DataFrame(buyers_tuples)
buyer_df.columns = ['ciphertext'] + key_list

# %% [markdown]
# ### `candidate`

# %%
cand_tuples = list()
key_list = ['ciphertext', 'create_date_ts']

for index, cand_tuple in \
  enumerate(jobs_profiles_df[['ciphertext', 'candidates']].itertuples(index=False)):
    profile_id = cand_tuple[0]
    cand_info = cand_tuple[1]
    if 'candidate' in cand_info:
        grab_data(cand_tuples, cand_info['candidate'], profile_id, key_list)

# %%
cand_df = pd.DataFrame(cand_tuples)
cand_df.columns = ['ciphertext', 'cand_ciphertext', 'create_date_ts']

# %%
cand_df['create_datetime'] = cand_df['create_date_ts'].apply(convert_epoch_datetime)
cand_df.drop(['create_date_ts'], axis=1, inplace=True)

# %% [markdown]
# ### `op_ctime`

# %%
jobs_profiles_df['job_post_date'] = \
  jobs_profiles_df['op_ctime'].apply(convert_millisecond_epoch_datetime)
jobs_profiles_df.drop(['op_ctime'], axis=1, inplace=True)

# %% [markdown]
# ### `op_description`

# %%
def stripped(str):
    return ' '.join(str.split())

# %%
jobs_profiles_df['op_description_stripped'] = jobs_profiles_df['op_description'].apply(stripped)
jobs_profiles_df.drop(['op_description'], axis=1, inplace=True)

# %% [markdown]
# ### `op_job_category_v2`: Get category group (larger in size than category)

# %%
categ_tuples = list()
key_list = ['name']

for index, cat2_tuple in \
  enumerate(jobs_profiles_df[['ciphertext', 'op_job_category_v2']].itertuples(index=False)):
    profile_id = cat2_tuple[0]
    cat2_info = cat2_tuple[1]
    if isinstance(cat2_info, dict):
        if 'op_job_category_v' in cat2_info:
#             print cat2_info['op_job_category_v']
            if 'groups' in cat2_info['op_job_category_v']:
                groups_info = cat2_info['op_job_category_v']['groups']
                if 'group' in groups_info:
                    categ_tuples.append((profile_id, groups_info['group']['name']))

# %%
categ_df = pd.DataFrame(categ_tuples)
categ_df.columns = ['ciphertext', 'category_group']

# %%
jobs_profiles_df.drop(['op_job_category_v2'], axis=1, inplace=True)

# %% [markdown]
# ### `op_required_skills`

# %%
def multiple_replace(dict, text):
    # Make one-letter skills longer
    if text == 'c':
        longtext = 'cprog'
    elif text == 'r':
        longtext = 'rprog'
    elif text == 's':
        longtext = 'sprog'
    else:
        longtext = text

    regex = re.compile("(%s)" % "|".join(map(re.escape, dict.keys())))

    # For each match, look-up corresponding value in dictionary
    return regex.sub(lambda mo: dict[mo.string[mo.start():mo.end()]], longtext)

substitution_dict = { \
    '+': 'plus', \
    '#': 'sharp', \
    '/': 'slash', \
    '-': 'dash', \
    '.': 'dot' \
}

def contiguous_word(skill):
    return multiple_replace(substitution_dict, skill)

# %%
skills_tuples = list()
key_list = ['skill']

for index, jobs_tuple in \
  enumerate(jobs_profiles_df[['ciphertext', 'op_required_skills']].itertuples(index=False)):
    profile_id = jobs_tuple[0]
    skill_info = jobs_tuple[1]
    if isinstance(skill_info, dict):
        if 'op_required_skill' in skill_info:
            grab_data(skills_tuples, skill_info['op_required_skill'], profile_id, key_list)

# %%
skills_set_list = list()
key_list = ['skill_set']
start_tuple_number = 0
end_tuple_number = len(skills_tuples) - 1

for index, skills_tuple in enumerate(skills_tuples):
    if index == start_tuple_number:
        curr_ciphertext = skills_tuple[0]
        skills_set = set( {contiguous_word(skills_tuple[1])} )
    elif curr_ciphertext == skills_tuple[0]:
        skills_set.add(contiguous_word(skills_tuple[1]))
    elif curr_ciphertext <> skills_tuple[0]:
        skills_set_list.append((curr_ciphertext, skills_set.copy()))
        skills_set = set( {contiguous_word(skills_tuple[1])} )
        curr_ciphertext = skills_tuple[0]

    if index == end_tuple_number:
        skills_set_list.append((curr_ciphertext, skills_set))

# %%
print len(skills_tuples)
print len(skills_set_list)
# Out:
# 16473
# 5725

# %%
req_skills_df = pd.DataFrame(skills_set_list)
req_skills_df.columns = ['ciphertext'] + key_list

# %%
jobs_profiles_df.drop(['op_required_skills'], axis=1, inplace=True)

# %%
df_list = [ \
assi_df, \
buyer_df, \
cand_df, \
categ_df, \
req_skills_df \
]

for df in df_list:
    print df.info()
    print
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11382 entries, 0 to 11381
# Data columns (total 4 columns):
# ciphertext                    11382 non-null object
# ciphertext_developer_recno    11382 non-null object
# start_datetime                11382 non-null datetime64[ns]
# end_datetime                  10142 non-null datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 444.6+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7882 entries, 0 to 7881
# Data columns (total 5 columns):
# ciphertext          7882 non-null object
# op_timezone         7882 non-null object
# op_country          7882 non-null object
# op_city             7882 non-null object
# op_contract_date    7882 non-null object
# dtypes: object(5)
# memory usage: 369.5+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146106 entries, 0 to 146105
# Data columns (total 3 columns):
# ciphertext         146106 non-null object
# cand_ciphertext    146106 non-null object
# create_datetime    146106 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 4.5+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7876 entries, 0 to 7875
# Data columns (total 2 columns):
# ciphertext        7876 non-null object
# category_group    7876 non-null object
# dtypes: object(2)
# memory usage: 184.6+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5725 entries, 0 to 5724
# Data columns (total 2 columns):
# ciphertext    5725 non-null object
# skill         5725 non-null object
# dtypes: object(2)
# memory usage: 134.2+ KB
# None

# %%
assi_df.T.head(30)
# Out:
#                                           0                    1      \
# ciphertext                  ~01036ab99176fc9ca7  ~01036ecca7fbdb9d47
# ciphertext_developer_recno  ~01ca3b6ff3e632f6ab  ~01eef64ef43a757c51
# start_datetime              2012-02-18 16:00:00  2011-10-17 17:00:00
# end_datetime                2012-06-03 17:00:00  2011-10-18 17:00:00
#
#                                           2                    3      \
# ciphertext                  ~0103703f207be9f938  ~01037164e7e1613e2f
# ciphertext_developer_recno  ~0140a8c1b287ababb9  ~0172e72850ac36a641
# start_datetime              2015-05-05 17:00:00  2015-11-02 16:00:00
# end_datetime                                NaT  2016-01-25 16:00:00
#
#                                           4                    5      \
# ciphertext                  ~01037164e7e1613e2f  ~01037164e7e1613e2f
# ciphertext_developer_recno  ~01daf57550023b5bbe  ~01174ba84e44af17a5
# start_datetime              2015-11-02 16:00:00  2015-11-01 16:00:00
# end_datetime                                NaT                  NaT
#
#                                           6                    7      \
# ciphertext                  ~01037313aee93f572b  ~010373177cb75fac67
# ciphertext_developer_recno  ~012ac81a79539b8972  ~01a15cfa577cb31a5d
# start_datetime              2013-06-12 17:00:00  2014-09-13 17:00:00
# end_datetime                2013-08-08 17:00:00  2014-11-18 16:00:00
#
#                                           8                    9      \
# ciphertext                  ~01037460b8b2e770bb  ~010374b5de700160df
# ciphertext_developer_recno  ~017129c3d0ac9e32e2  ~010973123f73f21e24
# start_datetime              2014-01-13 16:00:00  2011-08-09 17:00:00
# end_datetime                2014-01-13 16:00:00  2011-10-16 17:00:00
#
#                                    ...                         11372  \
# ciphertext                         ...           ~01274cff9a4becab2e
# ciphertext_developer_recno         ...           ~01ee6ef35b5fe3a0f2
# start_datetime                     ...           2015-12-02 16:00:00
# end_datetime                       ...           2016-01-02 16:00:00
#
#                                           11373                11374  \
# ciphertext                  ~01274d1cb929fb7d32  ~01274d1cb929fb7d32
# ciphertext_developer_recno  ~0103353dd45da96b07  ~010535fd344e7b9ca3
# start_datetime              2012-10-25 17:00:00  2012-10-24 17:00:00
# end_datetime                2013-01-30 16:00:00  2013-01-26 16:00:00
#
#                                           11375                11376  \
# ciphertext                  ~0127500b1b70ff31b2  ~012750a2a32232cd0d
# ciphertext_developer_recno  ~0163ceb94c37a856e2  ~0151206f7fbb479350
# start_datetime              2010-04-30 17:00:00  2010-06-02 17:00:00
# end_datetime                2012-10-08 17:00:00  2010-06-02 17:00:00
#
#                                           11377                11378  \
# ciphertext                  ~01275285137d94fcb4  ~012753e9dd081c4643
# ciphertext_developer_recno  ~014606c48dfaaf5f8f  ~01d3f2d9207ca51d55
# start_datetime              2015-12-06 16:00:00  2012-11-06 16:00:00
# end_datetime                2015-12-10 16:00:00  2012-11-29 16:00:00
#
#                                           11379                11380  \
# ciphertext                  ~0127547bbab346404b  ~01275667fa5be0de44
# ciphertext_developer_recno  ~01820a3866e9ecb989  ~011fbff93e5f5f1117
# start_datetime              2012-03-17 17:00:00  2010-08-14 17:00:00
# end_datetime                2012-07-21 17:00:00  2010-08-17 17:00:00
#
#                                           11381
# ciphertext                  ~0127566a84c383a055
# ciphertext_developer_recno  ~014e77cc7d6c4d44b7
# start_datetime              2012-06-10 17:00:00
# end_datetime                2012-12-24 16:00:00
#
# [4 rows x 11382 columns]

# %%
buyer_df.T.head(30)
# Out:
#                                                                0     \
# ciphertext                                      ~01036ab99176fc9ca7
# op_timezone       UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# op_country                                                   Sweden
# op_city                                                     Uppsala
# op_contract_date                                   January 31, 2012
#
#                                                   1     \
# ciphertext                         ~01036ecca7fbdb9d47
# op_timezone       UTC-05:00 Eastern Time (US & Canada)
# op_country                               United States
# op_city                                         Exeter
# op_contract_date                        April 23, 2011
#
#                                                            2     \
# ciphertext                                  ~0103703f207be9f938
# op_timezone       UTC-08:00 Pacific Time (US & Canada); Tijuana
# op_country                                        United States
# op_city                                                 Fairfax
# op_contract_date                                August 22, 2011
#
#                                                            3     \
# ciphertext                                  ~01037164e7e1613e2f
# op_timezone       UTC-08:00 Pacific Time (US & Canada); Tijuana
# op_country                                        United States
# op_city                                           Newport Coast
# op_contract_date                               October 26, 2015
#
#                                                                4     \
# ciphertext                                      ~01037313aee93f572b
# op_timezone       UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# op_country                                              Netherlands
# op_city                                                    Nijmegen
# op_contract_date                                     April 18, 2013
#
#                                                                5     \
# ciphertext                                      ~010373177cb75fac67
# op_timezone       UTC (Coordinated Universal Time) Dublin, Edinb...
# op_country                                           United Kingdom
# op_city                                                      london
# op_contract_date                                  February 11, 2012
#
#                                                   6                    7     \
# ciphertext                         ~01037460b8b2e770bb  ~010374b5de700160df
# op_timezone       UTC-05:00 Eastern Time (US & Canada)   UTC+10:00 Brisbane
# op_country                               United States            Australia
# op_city                                   Elmwood Park           Gold Coast
# op_contract_date                           May 9, 2013        July 20, 2011
#
#                                                            8     \
# ciphertext                                  ~010376f8c47b978d93
# op_timezone       UTC-08:00 Pacific Time (US & Canada); Tijuana
# op_country                                        United States
# op_city                                                 Cumming
# op_contract_date                              November 20, 2014
#
#                                                            9     \
# ciphertext                                  ~01037713e90f373b91
# op_timezone       UTC-08:00 Pacific Time (US & Canada); Tijuana
# op_country                                        United States
# op_city                                                  Arcata
# op_contract_date                                 March 16, 2012
#
#                                         ...                          \
# ciphertext                              ...
# op_timezone                             ...
# op_country                              ...
# op_city                                 ...
# op_contract_date                        ...
#
#                                                   7872  \
# ciphertext                         ~01274b7db3f83e986c
# op_timezone       UTC-06:00 Central Time (US & Canada)
# op_country                               United States
# op_city                                        chicago
# op_contract_date                      January 14, 2012
#
#                                           7873  \
# ciphertext                 ~01274cff9a4becab2e
# op_timezone       UTC+05:00 Islamabad, Karachi
# op_country                            Pakistan
# op_city                              Hyderabad
# op_contract_date             December 27, 2009
#
#                                                   7874  \
# ciphertext                         ~01274d1cb929fb7d32
# op_timezone       UTC-05:00 Eastern Time (US & Canada)
# op_country                               United States
# op_city                                Oakland Gardens
# op_contract_date                    September 20, 2012
#
#                                                                7875  \
# ciphertext                                      ~0127500b1b70ff31b2
# op_timezone       UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# op_country                                                    Italy
# op_city                                                  Brusaporto
# op_contract_date                                     March 19, 2008
#
#                                                   7876  \
# ciphertext                         ~012750a2a32232cd0d
# op_timezone       UTC-05:00 Eastern Time (US & Canada)
# op_country                               United States
# op_city                                         Vienna
# op_contract_date                     February 10, 2010
#
#                                          7877  \
# ciphertext                ~01275285137d94fcb4
# op_timezone       UTC+10:00 Sydney, Melbourne
# op_country                          Australia
# op_city                                Casula
# op_contract_date              August 18, 2012
#
#                                                                7878  \
# ciphertext                                      ~012753e9dd081c4643
# op_timezone       UTC (Coordinated Universal Time) Dublin, Edinb...
# op_country                                           United Kingdom
# op_city                                                      London
# op_contract_date                                   November 4, 2012
#
#                                                                7879  \
# ciphertext                                      ~0127547bbab346404b
# op_timezone       UTC+08:00 Hong Kong SAR, Perth, Singapore, Taipei
# op_country                                                Singapore
# op_city                                                   Singapore
# op_contract_date                                     March 15, 2012
#
#                                                                7880  \
# ciphertext                                      ~01275667fa5be0de44
# op_timezone       UTC-08:00 Pacific Time (US & Canada); Los Angeles
# op_country                                            United States
# op_city                                                 Los Angeles
# op_contract_date                                    August 15, 2008
#
#                                                                7881
# ciphertext                                      ~0127566a84c383a055
# op_timezone       UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# op_country                                                  Denmark
# op_city                                                 Snekkersten
# op_contract_date                                      June 10, 2012
#
# [5 rows x 7882 columns]

# %%
cand_df.T.head(30)
# Out:
#                               0                    1       \
# ciphertext       ~01036ab99176fc9ca7  ~01036ecca7fbdb9d47
# cand_ciphertext  ~01ca3b6ff3e632f6ab  ~01eef64ef43a757c51
# create_datetime  2012-02-19 07:04:06  2011-10-18 06:20:55
#
#                               2                    3       \
# ciphertext       ~0103703f207be9f938  ~0103703f207be9f938
# cand_ciphertext  ~01f1c24717cd7b9b1a  ~014ea0e381dd57e4aa
# create_datetime  2015-05-06 00:19:14  2015-05-06 00:18:48
#
#                               4                    5       \
# ciphertext       ~0103703f207be9f938  ~0103703f207be9f938
# cand_ciphertext  ~01a8d9c1ce117cd5f4  ~01043970e768f1f1bf
# create_datetime  2015-05-06 00:17:30  2015-05-06 00:17:19
#
#                               6                    7       \
# ciphertext       ~0103703f207be9f938  ~0103703f207be9f938
# cand_ciphertext  ~0125ca99f9886137c3  ~01af9e3f87bd07bd37
# create_datetime  2015-05-06 00:15:21  2015-05-06 00:14:19
#
#                               8                    9       \
# ciphertext       ~0103703f207be9f938  ~0103703f207be9f938
# cand_ciphertext  ~01b3b4f6c00e83d1ce  ~0101eb1074369f013f
# create_datetime  2015-05-06 00:12:55  2015-05-06 00:12:44
#
#                         ...                        146096  \
# ciphertext              ...           ~0127566a84c383a055
# cand_ciphertext         ...           ~012143fe423c737e05
# create_datetime         ...           2012-06-11 05:55:30
#
#                               146097               146098  \
# ciphertext       ~0127566a84c383a055  ~0127566a84c383a055
# cand_ciphertext  ~01b87e26e111ccf21f  ~0110be1279e706cf30
# create_datetime  2012-06-10 19:27:14  2012-06-10 15:06:39
#
#                               146099               146100  \
# ciphertext       ~0127566a84c383a055  ~0127566a84c383a055
# cand_ciphertext  ~0197083dbd816c4f13  ~011d5eddf1cd9067ca
# create_datetime  2012-06-10 14:45:58  2012-06-10 14:40:19
#
#                               146101               146102  \
# ciphertext       ~0127566a84c383a055  ~0127566a84c383a055
# cand_ciphertext  ~0160939c65766d58c0  ~01f5d75e40b9b7aff1
# create_datetime  2012-06-10 14:28:47  2012-06-10 14:05:08
#
#                               146103               146104               146105
# ciphertext       ~0127566a84c383a055  ~0127566a84c383a055  ~0127566a84c383a055
# cand_ciphertext  ~014e77cc7d6c4d44b7  ~01e4bdce8490715995  ~0130a751ae02b232d2
# create_datetime  2012-06-10 14:04:19  2012-06-10 14:03:22  2012-06-10 14:02:01
#
# [3 rows x 146106 columns]

# %%
categ_df.T.head(30)
# Out:
#                                       0                    1     \
# ciphertext             ~01036ab99176fc9ca7  ~01036ecca7fbdb9d47
# category_group  Web, Mobile & Software Dev              Writing
#
#                                       2                    3     \
# ciphertext             ~0103703f207be9f938  ~01037164e7e1613e2f
# category_group  Web, Mobile & Software Dev    Sales & Marketing
#
#                                       4                           5     \
# ciphertext             ~01037313aee93f572b         ~010373177cb75fac67
# category_group  Web, Mobile & Software Dev  Web, Mobile & Software Dev
#
#                                6                           7     \
# ciphertext      ~01037460b8b2e770bb         ~010374b5de700160df
# category_group        Admin Support  Web, Mobile & Software Dev
#
#                                       8                           9     \
# ciphertext             ~010376f8c47b978d93         ~01037713e90f373b91
# category_group  Web, Mobile & Software Dev  Web, Mobile & Software Dev
#
#                        ...                          7866  \
# ciphertext             ...           ~01274b7db3f83e986c
# category_group         ...             Sales & Marketing
#
#                                       7867                        7868  \
# ciphertext             ~01274cff9a4becab2e         ~01274d1cb929fb7d32
# category_group  Web, Mobile & Software Dev  Web, Mobile & Software Dev
#
#                                       7869                        7870  \
# ciphertext             ~0127500b1b70ff31b2         ~012750a2a32232cd0d
# category_group  Web, Mobile & Software Dev  Web, Mobile & Software Dev
#
#                                     7871                        7872  \
# ciphertext           ~01275285137d94fcb4         ~012753e9dd081c4643
# category_group  Data Science & Analytics  Web, Mobile & Software Dev
#
#                                7873                        7874  \
# ciphertext      ~0127547bbab346404b         ~01275667fa5be0de44
# category_group        Admin Support  Web, Mobile & Software Dev
#
#                                7875
# ciphertext      ~0127566a84c383a055
# category_group              Writing
#
# [2 rows x 7876 columns]

# %%
req_skills_df.T.head(30)
# Out:
#                                                   0                     1     \
# ciphertext                         ~01036ab99176fc9ca7   ~01036ecca7fbdb9d47
# skill       {adobedashillustrator, adobedashphotoshop}  {articledashwriting}
#
#                            2     \
# ciphertext  ~0103703f207be9f938
# skill               {wordpress}
#
#                                                          3     \
# ciphertext                                ~01037164e7e1613e2f
# skill       {internetdashresearch, leaddashgeneration, int...
#
#                                 4                     5     \
# ciphertext       ~01037313aee93f572b   ~01037460b8b2e770bb
# skill       {joomla, html, css, php}  {microsoftdashexcel}
#
#                            6     \
# ciphertext  ~010374b5de700160df
# skill             {seo, joomla}
#
#                                                          7     \
# ciphertext                                ~0103794b12d99e1b0e
# skill       {jquery, seodashbacklinking, contentdashwritin...
#
#                            8                    9     \
# ciphertext  ~01037b2a4355a611ba  ~01037b2c81e8cece68
# skill                    {html}     {adobedashflash}
#
#                       ...                                              5715  \
# ciphertext            ...                               ~012749acb58c2698ae
# skill                 ...              {microsoftdashaccessdashprogramming}
#
#                            5716  \
# ciphertext  ~01274b7db3f83e986c
# skill            {spreadsheets}
#
#                                                          5717  \
# ciphertext                                ~01274d1cb929fb7d32
# skill       {adobedashfireworks, html, adobedashphotoshop,...
#
#                            5718                 5719  \
# ciphertext  ~0127500b1b70ff31b2  ~012750a2a32232cd0d
# skill                    {html}     {php, wordpress}
#
#                                                          5720  \
# ciphertext                                ~01275285137d94fcb4
# skill       {amazondashwebdashservices, apidashdevelopment...
#
#                                    5721  \
# ciphertext          ~012753e9dd081c4643
# skill       {html, wordpress, css, php}
#
#                                                          5722  \
# ciphertext                                ~0127547bbab346404b
# skill       {internetdashresearch, webdashcontentdashmanag...
#
#                              5723                       5724
# ciphertext    ~01275667fa5be0de44        ~0127566a84c383a055
# skill       {svn, git, html, css}  {vba, microsoftdashexcel}
#
# [2 rows x 5725 columns]

# %%
profiles_df.T.head(30)
# Out:
#                                                                   0      \
# dev_bill_rate                                                        15
# dev_blurb             Over the more than 6 years, I have developed a...
# dev_country                                                       India
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                 LAMP developer with more than 6 years
# dev_recno_ciphertext                                ~01cae3810dc6d2bbbc
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education             {u'institution': {u'ed_to': u'07/2007', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                  Masters
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         ajax apidashdevelopment curl javascript magent...
#
#                                                                   1      \
# dev_bill_rate                                                        12
# dev_blurb             I am a web application developer, having 2 yea...
# dev_country                                                       India
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                              Web Developer / Designer
# dev_recno_ciphertext                                ~01d24ced467385214d
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education             {u'institution': {u'ed_to': u'12/2012', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                         Bachelor of Engineering (B.Eng.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         ajax css3 grails groovy javascript jquery mysq...
#
#                                                                   2      \
# dev_bill_rate                                                     44.44
# dev_blurb             Extensive expertise in clinical research publi...
# dev_country                                               United States
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     English/French Writer/Translator,Scientific Di...
# dev_recno_ciphertext                                ~01953fb4fa2ceb67dc
# dev_timezone          UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# education             {u'institution': [{u'ed_to': u'12/2002', u'ed_...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree               Master of Business Administration (M.B.A.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         articledashwriting creativedashwriting datadas...
#
#                                                                   3      \
# dev_bill_rate                                                     24.44
# dev_blurb             I'm a WEB-developer with more than 5 years exp...
# dev_country                                                     Ukraine
# dev_eng_skill                                                         5
# dev_portrait
# dev_profile_title     PHP/Zend Framework/MySql/MongoDB/SPHINX/jQuery...
# dev_recno_ciphertext                                ~01a9ab111f973ae055
# dev_timezone                       UTC+02:00 Athens, Helsinki, Istanbul
# education
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                      False
# highest_degree                             Doctor of Philosophy (Ph.D.)
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         facebookdashapi googledashmapsdashapi html5 jq...
#
#                                                                   4      \
# dev_bill_rate                                                        15
# dev_blurb             Specializes in developing Photoshop and After ...
# dev_country                                                   Sri Lanka
# dev_eng_skill
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     After Effects, Photoshop - Scripting And Plugi...
# dev_recno_ciphertext                                ~016dcec1087cba565c
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         actionscriptdash3 adobedashafterdasheffects ad...
#
#                                                                   5      \
# dev_bill_rate                                                     16.67
# dev_blurb
# dev_country                                                     Germany
# dev_eng_skill                                                         5
# dev_portrait
# dev_profile_title     Development of reliable and flexible software(...
# dev_recno_ciphertext                                ~019e83a0dfa04c0e8b
# dev_timezone          UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# education             {u'institution': {u'ed_to': u'01/2008', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                      False
# highest_degree                                                    Other
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         cplusplus java oracledashdatabase perl php qt ...
#
#                                                                   6      \
# dev_bill_rate                                                        30
# dev_blurb             skype :  orange_project_kh\nemail:    contact@...
# dev_country                                                     Ukraine
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     Fullstack web developer, e-commerce developing...
# dev_recno_ciphertext                                ~01863825efc778f975
# dev_timezone                                   UTC+02:00 Eastern Europe
# education             {u'institution': {u'ed_to': u'12/2015', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                Bachelors
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         css3 html5 internetdashresearch javascript mys...
#
#                                                                   7      \
# dev_bill_rate                                                     11.11
# dev_blurb             DTL Solutions is the software solutions provid...
# dev_country                                                     Vietnam
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     Small IT solution company provides Development...
# dev_recno_ciphertext                                ~01614e82e3c5a0ccca
# dev_timezone                                UTC+07:00 Omsk, Novosibirsk
# education
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree               Master of Business Administration (M.B.A.)
# has_portfolio                                                      True
# took_tests                                                        False
# skills_string         agiledashsoftwaredashdevelopment androiddashap...
#
#                                                                   8      \
# dev_bill_rate                                                        10
# dev_blurb             I am an upcoming college graduate! I will rece...
# dev_country                                               United States
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title               Upbeat Enthusiastic Professional Writer
# dev_recno_ciphertext                                ~0122260b02b0c56563
# dev_timezone              UTC-08:00 Pacific Time (US & Canada); Tijuana
# education             {u'institution': {u'ed_to': u'Present', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         creativedashwriting datadashanalysis editorial...
#
#                                                                   9      \
# dev_bill_rate                                                      5.56
# dev_blurb             1)  Shopping Card Management System using C# a...
# dev_country                                                  Bangladesh
# dev_eng_skill
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title               Bsc in Computer Science and Engineering
# dev_recno_ciphertext                                ~01a3583a33f5146e8e
# dev_timezone                                    UTC+06:00 Almaty, Dhaka
# education             {u'institution': {u'ed_to': u'12/2014', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                Bachelors
# has_portfolio                                                     False
# took_tests                                                        False
# skills_string         androiddashappdashdevelopment csharp css3 html...
#
#                                             ...                          \
# dev_bill_rate                               ...
# dev_blurb                                   ...
# dev_country                                 ...
# dev_eng_skill                               ...
# dev_portrait                                ...
# dev_profile_title                           ...
# dev_recno_ciphertext                        ...
# dev_timezone                                ...
# education                                   ...
# agency_affl                                 ...
# group_affl                                  ...
# has_portrait                                ...
# highest_degree                              ...
# has_portfolio                               ...
# took_tests                                  ...
# skills_string                               ...
#
#                                                                   88686  \
# dev_bill_rate                                                     22.22
# dev_blurb             I'm a software engineer focused on backend and...
# dev_country                                                      Russia
# dev_eng_skill                                                         3
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                    Software Developer
# dev_recno_ciphertext                                ~01dfd63f31c5228d16
# dev_timezone                                UTC+07:00 Omsk, Novosibirsk
# education
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                  Diploma
# has_portfolio                                                      True
# took_tests                                                        False
# skills_string         css djangodashframework javascript linuxdashsy...
#
#                                                                   88687  \
# dev_bill_rate                                                         4
# dev_blurb             I am  working as a  officer at Checkpoint syst...
# dev_country                                                  Bangladesh
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                       IT Professional
# dev_recno_ciphertext                                ~018aaab6cfdc3fb96c
# dev_timezone                                    UTC+06:00 Almaty, Dhaka
# education             {u'institution': [{u'ed_to': u'12/2015', u'ed_...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                 Master of Computer Applications (M.C.A.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         adobedashillustrator adobedashphotoshop micros...
#
#                                                                   88688  \
# dev_bill_rate                                                      6.67
# dev_blurb             To enhance my journalistic prowess through onl...
# dev_country                                                 Philippines
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title     Statistician|News&Sports Writer|InDesign|Pagem...
# dev_recno_ciphertext                                ~01360017155d421ae3
# dev_timezone          UTC+08:00 Hong Kong SAR, Perth, Singapore, Taipei
# education             {u'institution': {u'ed_to': u'04/2012', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                            Bachelor of Education (B.Ed.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         adobedashindesign adobedashpagemaker copywriti...
#
#                                                                   88689  \
# dev_bill_rate                                                     13.89
# dev_blurb             I'm a highly motivated person with a strong ba...
# dev_country                                                      Russia
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title        Experienced developer and scientific assistant
# dev_recno_ciphertext                                ~0169007d9fa447a06b
# dev_timezone                UTC+03:00 Moscow, St. Petersburg, Volgograd
# education             {u'institution': [{u'ed_to': u'Present', u'ed_...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                        Bachelor's degree
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         cprog cplusplus embeddeddashsystems hibernate ...
#
#                                                                   88690  \
# dev_bill_rate                                                        10
# dev_blurb             I like building cool web applications, and I o...
# dev_country                                                       India
# dev_eng_skill                                                         5
# dev_portrait
# dev_profile_title     An expert web application developer with Djang...
# dev_recno_ciphertext                                ~014920c811cecebbc4
# dev_timezone                           UTC (Coordinated Universal Time)
# education             {u'institution': {u'ed_to': u'12/2014', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                      False
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         css djangodashframework html javascript jquery...
#
#                                                                   88691  \
# dev_bill_rate                                                     16.67
# dev_blurb             I configure and run the base station WiMAX on ...
# dev_country                                                      Russia
# dev_eng_skill                                                         3
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                    Software Developer
# dev_recno_ciphertext                                ~0148cf1eca9907db89
# dev_timezone                UTC+04:00 Abu Dhabi, Muscat, Tbilisi, Kazan
# education             {u'institution': {u'ed_to': u'12/2012', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                            Bachelor of Commerce (B.Com.)
# has_portfolio                                                     False
# took_tests                                                        False
# skills_string         cplusplus ciscodashrouters freebsd gwt java li...
#
#                                                                   88692  \
# dev_bill_rate                                                     11.11
# dev_blurb             I am looking to help in software solutions . w...
# dev_country                                                       Egypt
# dev_eng_skill                                                         5
# dev_portrait          https://www.odesk.com/att/~~mOJyJwUvL-dOchJGOo...
# dev_profile_title                                           Ahmed Eshra
# dev_recno_ciphertext                                ~01baacbe6b9e3d8c30
# dev_timezone                                            UTC+02:00 Cairo
# education             {u'institution': {u'ed_to': u'Present', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                 Master's
# has_portfolio                                                      True
# took_tests                                                         True
# skills_string         androiddashappdashdevelopment cprog cplusplus ...
#
#                                                                   88693  \
# dev_bill_rate                                                        35
# dev_blurb             I have extensive experience using Python to so...
# dev_country                                               United States
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                            Python & ArcGIS Programmer
# dev_recno_ciphertext                                ~013659f86de224bdf9
# dev_timezone                      UTC-07:00 Mountain Time (US & Canada)
# education             {u'institution': {u'ed_to': u'12/2005', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                       Bachelor of Architecture (B.Arch.)
# has_portfolio                                                     False
# took_tests                                                        False
# skills_string                                     arcgis autocad python
#
#                                                                   88694  \
# dev_bill_rate                                                         3
# dev_blurb             Looking for work in proofreading, editing or c...
# dev_country                                                       India
# dev_eng_skill                                                         4
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title
# dev_recno_ciphertext                                ~01b9ca1c9967daf519
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education             {u'institution': {u'ed_to': u'12/2015', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         englishdashgrammar matlab microsoftdashexcel m...
#
#                                                                   88695
# dev_bill_rate                                                        30
# dev_blurb             I have 8 Years of Profession Experience and i ...
# dev_country                                                       India
# dev_eng_skill                                                         5
# dev_portrait          https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                          Project Lead
# dev_recno_ciphertext                                ~01a0cdfa47888e70f7
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# education             {u'institution': {u'ed_to': u'12/2013', u'ed_a...
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                  Masters
# has_portfolio                                                     False
# took_tests                                                         True
# skills_string         apachedashstruts hibernate java javadashservle...
#
# [16 rows x 88696 columns]

# %% [markdown]
# ### Delete multi-var variables that have been featurized (for the most part)

# %%
jobs_profiles_df.drop([
                       'assignment_info', 'assignments', \
                       'buyer', 'candidates', \
                       'op_tot_cand' \
                      ], axis=1, inplace=True)

# %% [markdown]
# # COMBINE JOB-LEVEL DATA SETS

# %%
jobs_profiles_df.T.head(38)
# Out:
#                                                                       0     \
# ciphertext                                             ~01036ab99176fc9ca7
# job_type                                                             Fixed
# op_title                                             Web designer project.
# job_post_date                                          2012-02-19 07:01:16
# op_description_stripped  We need some deisgns for our website. Its exac...
#
#                                                                       1     \
# ciphertext                                             ~01036ecca7fbdb9d47
# job_type                                                             Fixed
# op_title                               Article Writers - Fast and Reliable
# job_post_date                                          2011-10-18 05:43:17
# op_description_stripped  Each writer will be give a set of keywords. Mo...
#
#                                                                       2     \
# ciphertext                                             ~0103703f207be9f938
# job_type                                                            Hourly
# op_title                                               WordPress Templates
# job_post_date                                          2015-05-05 23:56:37
# op_description_stripped  Post archive page and post page designed to ma...
#
#                                                                       3     \
# ciphertext                                             ~01037164e7e1613e2f
# job_type                                                            Hourly
# op_title                                   Generate lead for special niche
# job_post_date                                          2015-11-02 12:49:43
# op_description_stripped  Hi, We are a company with a special niche and ...
#
#                                                                       4     \
# ciphertext                                             ~01037313aee93f572b
# job_type                                                             Fixed
# op_title                                              Basic Joomla website
# job_post_date                                          2013-06-12 06:30:16
# op_description_stripped  Hi, We're looking for someone with Joomla, HTM...
#
#                                                                       5     \
# ciphertext                                             ~010373177cb75fac67
# job_type                                                             Fixed
# op_title                 Create a dashboard to collect reviews and auto...
# job_post_date                                          2014-09-06 06:44:22
# op_description_stripped  Morning I'm looking for a developer to create ...
#
#                                                         6     \
# ciphertext                               ~01037460b8b2e770bb
# job_type                                               Fixed
# op_title                                 Update spread sheet
# job_post_date                            2014-01-13 19:55:28
# op_description_stripped  Update images url for 2000 products
#
#                                                                       7     \
# ciphertext                                             ~010374b5de700160df
# job_type                                                            Hourly
# op_title                                                   Joomla 1.5 site
# job_post_date                                          2011-07-20 22:25:37
# op_description_stripped  Hi, Im wanting to have a joomla template chang...
#
#                                         8     \
# ciphertext               ~010376f8c47b978d93
# job_type                               Fixed
# op_title                       Sidler-ng.com
# job_post_date            2014-11-20 11:54:33
# op_description_stripped            Modernize
#
#                                                                       9     \
# ciphertext                                             ~01037713e90f373b91
# job_type                                                            Hourly
# op_title                                         Drupal Ecommerce Site Fix
# job_post_date                                          2015-06-18 16:53:17
# op_description_stripped  Need help getting my Drupal store back up and ...
#
#                                                ...                          \
# ciphertext                                     ...
# job_type                                       ...
# op_title                                       ...
# job_post_date                                  ...
# op_description_stripped                        ...
#
#                                                                       7872  \
# ciphertext                                             ~01274b7db3f83e986c
# job_type                                                             Fixed
# op_title                                     Virtual Lead Generator Needed
# job_post_date                                          2012-01-13 19:24:47
# op_description_stripped  This job requires you to have a fast internet ...
#
#                                                                       7873  \
# ciphertext                                             ~01274cff9a4becab2e
# job_type                                                            Hourly
# op_title                          Senior Python/Django/Bootstrap developer
# job_post_date                                          2015-12-01 06:33:04
# op_description_stripped  - Job description I need a senior django devel...
#
#                                                                       7874  \
# ciphertext                                             ~01274d1cb929fb7d32
# job_type                                                            Hourly
# op_title                               UI Design, Wireframing, Prototyping
# job_post_date                                          2012-10-21 08:17:20
# op_description_stripped  Surpass the Limit is a social platform where u...
#
#                                                                       7875  \
# ciphertext                                             ~0127500b1b70ff31b2
# job_type                                                            Hourly
# op_title                      Create html files using a template from text
# job_post_date                                          2010-04-30 16:09:41
# op_description_stripped  Create the speaker pages for a conference. Sta...
#
#                                                                       7876  \
# ciphertext                                             ~012750a2a32232cd0d
# job_type                                                             Fixed
# op_title                                                  Wordpress Expert
# job_post_date                                          2010-06-03 05:22:26
# op_description_stripped  Hi, we need a few themes customized for Wordpr...
#
#                                                                       7877  \
# ciphertext                                             ~01275285137d94fcb4
# job_type                                                             Fixed
# op_title                                          Scrapping data of amazon
# job_post_date                                          2015-12-07 04:02:43
# op_description_stripped  Hi Mubbashar, as discussed, i need to scrape t...
#
#                                                                       7878  \
# ciphertext                                             ~012753e9dd081c4643
# job_type                                                            Hourly
# op_title                             Wordpress theme fixes, HTML, CSS, PHP
# job_post_date                                          2012-11-04 13:38:15
# op_description_stripped  We need a web developer to implement a few rem...
#
#                                                                       7879  \
# ciphertext                                             ~0127547bbab346404b
# job_type                                                            Hourly
# op_title                                          Data Cleaning Specialist
# job_post_date                                          2012-03-15 00:50:36
# op_description_stripped  We run a travel destination portal. On the sit...
#
#                                                                       7880  \
# ciphertext                                             ~01275667fa5be0de44
# job_type                                                            Hourly
# op_title                 w3c html/css + javascript django template desi...
# job_post_date                                          2010-08-15 07:17:57
# op_description_stripped  We have an immediate need for an html/css code...
#
#                                                                       7881
# ciphertext                                             ~0127566a84c383a055
# job_type                                                            Hourly
# op_title                                        Excel macro – VBA - Course
# job_post_date                                          2012-06-10 13:57:13
# op_description_stripped  I need an Excel Macro (VBA) course for my web ...
#
# [5 rows x 7882 columns]

# %%
df_list = [ \
jobs_profiles_df,
buyer_df, \
categ_df, \
req_skills_df, \
profiles_df
]

for df in df_list:
    for col in list(df.columns):
        print col
    print
# Out:
# ciphertext
# job_type
# op_title
# job_post_date
# op_description_stripped
#
# ciphertext
# op_timezone
# op_country
# op_city
# op_contract_date
#
# ciphertext
# category_group
#
# ciphertext
# skill_set
#
# dev_bill_rate
# dev_blurb
# dev_country
# dev_eng_skill
# dev_profile_title
# dev_recno_ciphertext
# dev_timezone
# agency_affl
# group_affl
# has_portrait
# highest_degree
# has_portfolio
# took_tests
# skills_set

# %%
job_level_df = pd.merge(jobs_profiles_df, buyer_df, how='left', on='ciphertext')

# %%
job_level_df = pd.merge(job_level_df, categ_df, how='left', on='ciphertext')

# %%
job_level_df = pd.merge(job_level_df, req_skills_df, how='left', on='ciphertext')

# %%
job_level_df.T.head(25)
# Out:
#                                                                       0     \
# ciphertext                                             ~01036ab99176fc9ca7
# job_type                                                             Fixed
# op_title                                             Web designer project.
# job_post_date                                          2012-02-19 07:01:16
# op_description_stripped  We need some deisgns for our website. Its exac...
# op_timezone              UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# op_country                                                          Sweden
# op_city                                                            Uppsala
# op_contract_date                                          January 31, 2012
# category_group                                  Web, Mobile & Software Dev
# skill_set                       {adobedashillustrator, adobedashphotoshop}
#
#                                                                       1     \
# ciphertext                                             ~01036ecca7fbdb9d47
# job_type                                                             Fixed
# op_title                               Article Writers - Fast and Reliable
# job_post_date                                          2011-10-18 05:43:17
# op_description_stripped  Each writer will be give a set of keywords. Mo...
# op_timezone                           UTC-05:00 Eastern Time (US & Canada)
# op_country                                                   United States
# op_city                                                             Exeter
# op_contract_date                                            April 23, 2011
# category_group                                                     Writing
# skill_set                                             {articledashwriting}
#
#                                                                       2     \
# ciphertext                                             ~0103703f207be9f938
# job_type                                                            Hourly
# op_title                                               WordPress Templates
# job_post_date                                          2015-05-05 23:56:37
# op_description_stripped  Post archive page and post page designed to ma...
# op_timezone                  UTC-08:00 Pacific Time (US & Canada); Tijuana
# op_country                                                   United States
# op_city                                                            Fairfax
# op_contract_date                                           August 22, 2011
# category_group                                  Web, Mobile & Software Dev
# skill_set                                                      {wordpress}
#
#                                                                       3     \
# ciphertext                                             ~01037164e7e1613e2f
# job_type                                                            Hourly
# op_title                                   Generate lead for special niche
# job_post_date                                          2015-11-02 12:49:43
# op_description_stripped  Hi, We are a company with a special niche and ...
# op_timezone                  UTC-08:00 Pacific Time (US & Canada); Tijuana
# op_country                                                   United States
# op_city                                                      Newport Coast
# op_contract_date                                          October 26, 2015
# category_group                                           Sales & Marketing
# skill_set                {internetdashresearch, leaddashgeneration, int...
#
#                                                                       4     \
# ciphertext                                             ~01037313aee93f572b
# job_type                                                             Fixed
# op_title                                              Basic Joomla website
# job_post_date                                          2013-06-12 06:30:16
# op_description_stripped  Hi, We're looking for someone with Joomla, HTM...
# op_timezone              UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# op_country                                                     Netherlands
# op_city                                                           Nijmegen
# op_contract_date                                            April 18, 2013
# category_group                                  Web, Mobile & Software Dev
# skill_set                                         {joomla, html, css, php}
#
#                                                                       5     \
# ciphertext                                             ~010373177cb75fac67
# job_type                                                             Fixed
# op_title                 Create a dashboard to collect reviews and auto...
# job_post_date                                          2014-09-06 06:44:22
# op_description_stripped  Morning I'm looking for a developer to create ...
# op_timezone              UTC (Coordinated Universal Time) Dublin, Edinb...
# op_country                                                  United Kingdom
# op_city                                                             london
# op_contract_date                                         February 11, 2012
# category_group                                  Web, Mobile & Software Dev
# skill_set                                                              NaN
#
#                                                          6     \
# ciphertext                                ~01037460b8b2e770bb
# job_type                                                Fixed
# op_title                                  Update spread sheet
# job_post_date                             2014-01-13 19:55:28
# op_description_stripped   Update images url for 2000 products
# op_timezone              UTC-05:00 Eastern Time (US & Canada)
# op_country                                      United States
# op_city                                          Elmwood Park
# op_contract_date                                  May 9, 2013
# category_group                                  Admin Support
# skill_set                                {microsoftdashexcel}
#
#                                                                       7     \
# ciphertext                                             ~010374b5de700160df
# job_type                                                            Hourly
# op_title                                                   Joomla 1.5 site
# job_post_date                                          2011-07-20 22:25:37
# op_description_stripped  Hi, Im wanting to have a joomla template chang...
# op_timezone                                             UTC+10:00 Brisbane
# op_country                                                       Australia
# op_city                                                         Gold Coast
# op_contract_date                                             July 20, 2011
# category_group                                  Web, Mobile & Software Dev
# skill_set                                                    {seo, joomla}
#
#                                                                   8     \
# ciphertext                                         ~010376f8c47b978d93
# job_type                                                         Fixed
# op_title                                                 Sidler-ng.com
# job_post_date                                      2014-11-20 11:54:33
# op_description_stripped                                      Modernize
# op_timezone              UTC-08:00 Pacific Time (US & Canada); Tijuana
# op_country                                               United States
# op_city                                                        Cumming
# op_contract_date                                     November 20, 2014
# category_group                              Web, Mobile & Software Dev
# skill_set                                                          NaN
#
#                                                                       9     \
# ciphertext                                             ~01037713e90f373b91
# job_type                                                            Hourly
# op_title                                         Drupal Ecommerce Site Fix
# job_post_date                                          2015-06-18 16:53:17
# op_description_stripped  Need help getting my Drupal store back up and ...
# op_timezone                  UTC-08:00 Pacific Time (US & Canada); Tijuana
# op_country                                                   United States
# op_city                                                             Arcata
# op_contract_date                                            March 16, 2012
# category_group                                  Web, Mobile & Software Dev
# skill_set                                                              NaN
#
#                                                ...                          \
# ciphertext                                     ...
# job_type                                       ...
# op_title                                       ...
# job_post_date                                  ...
# op_description_stripped                        ...
# op_timezone                                    ...
# op_country                                     ...
# op_city                                        ...
# op_contract_date                               ...
# category_group                                 ...
# skill_set                                      ...
#
#                                                                       7872  \
# ciphertext                                             ~01274b7db3f83e986c
# job_type                                                             Fixed
# op_title                                     Virtual Lead Generator Needed
# job_post_date                                          2012-01-13 19:24:47
# op_description_stripped  This job requires you to have a fast internet ...
# op_timezone                           UTC-06:00 Central Time (US & Canada)
# op_country                                                   United States
# op_city                                                            chicago
# op_contract_date                                          January 14, 2012
# category_group                                           Sales & Marketing
# skill_set                                                   {spreadsheets}
#
#                                                                       7873  \
# ciphertext                                             ~01274cff9a4becab2e
# job_type                                                            Hourly
# op_title                          Senior Python/Django/Bootstrap developer
# job_post_date                                          2015-12-01 06:33:04
# op_description_stripped  - Job description I need a senior django devel...
# op_timezone                                   UTC+05:00 Islamabad, Karachi
# op_country                                                        Pakistan
# op_city                                                          Hyderabad
# op_contract_date                                         December 27, 2009
# category_group                                  Web, Mobile & Software Dev
# skill_set                                                              NaN
#
#                                                                       7874  \
# ciphertext                                             ~01274d1cb929fb7d32
# job_type                                                            Hourly
# op_title                               UI Design, Wireframing, Prototyping
# job_post_date                                          2012-10-21 08:17:20
# op_description_stripped  Surpass the Limit is a social platform where u...
# op_timezone                           UTC-05:00 Eastern Time (US & Canada)
# op_country                                                   United States
# op_city                                                    Oakland Gardens
# op_contract_date                                        September 20, 2012
# category_group                                  Web, Mobile & Software Dev
# skill_set                {adobedashfireworks, html, adobedashphotoshop,...
#
#                                                                       7875  \
# ciphertext                                             ~0127500b1b70ff31b2
# job_type                                                            Hourly
# op_title                      Create html files using a template from text
# job_post_date                                          2010-04-30 16:09:41
# op_description_stripped  Create the speaker pages for a conference. Sta...
# op_timezone              UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# op_country                                                           Italy
# op_city                                                         Brusaporto
# op_contract_date                                            March 19, 2008
# category_group                                  Web, Mobile & Software Dev
# skill_set                                                           {html}
#
#                                                                       7876  \
# ciphertext                                             ~012750a2a32232cd0d
# job_type                                                             Fixed
# op_title                                                  Wordpress Expert
# job_post_date                                          2010-06-03 05:22:26
# op_description_stripped  Hi, we need a few themes customized for Wordpr...
# op_timezone                           UTC-05:00 Eastern Time (US & Canada)
# op_country                                                   United States
# op_city                                                             Vienna
# op_contract_date                                         February 10, 2010
# category_group                                  Web, Mobile & Software Dev
# skill_set                                                 {php, wordpress}
#
#                                                                       7877  \
# ciphertext                                             ~01275285137d94fcb4
# job_type                                                             Fixed
# op_title                                          Scrapping data of amazon
# job_post_date                                          2015-12-07 04:02:43
# op_description_stripped  Hi Mubbashar, as discussed, i need to scrape t...
# op_timezone                                    UTC+10:00 Sydney, Melbourne
# op_country                                                       Australia
# op_city                                                             Casula
# op_contract_date                                           August 18, 2012
# category_group                                    Data Science & Analytics
# skill_set                {amazondashwebdashservices, apidashdevelopment...
#
#                                                                       7878  \
# ciphertext                                             ~012753e9dd081c4643
# job_type                                                            Hourly
# op_title                             Wordpress theme fixes, HTML, CSS, PHP
# job_post_date                                          2012-11-04 13:38:15
# op_description_stripped  We need a web developer to implement a few rem...
# op_timezone              UTC (Coordinated Universal Time) Dublin, Edinb...
# op_country                                                  United Kingdom
# op_city                                                             London
# op_contract_date                                          November 4, 2012
# category_group                                  Web, Mobile & Software Dev
# skill_set                                      {html, wordpress, css, php}
#
#                                                                       7879  \
# ciphertext                                             ~0127547bbab346404b
# job_type                                                            Hourly
# op_title                                          Data Cleaning Specialist
# job_post_date                                          2012-03-15 00:50:36
# op_description_stripped  We run a travel destination portal. On the sit...
# op_timezone              UTC+08:00 Hong Kong SAR, Perth, Singapore, Taipei
# op_country                                                       Singapore
# op_city                                                          Singapore
# op_contract_date                                            March 15, 2012
# category_group                                               Admin Support
# skill_set                {internetdashresearch, webdashcontentdashmanag...
#
#                                                                       7880  \
# ciphertext                                             ~01275667fa5be0de44
# job_type                                                            Hourly
# op_title                 w3c html/css + javascript django template desi...
# job_post_date                                          2010-08-15 07:17:57
# op_description_stripped  We have an immediate need for an html/css code...
# op_timezone              UTC-08:00 Pacific Time (US & Canada); Los Angeles
# op_country                                                   United States
# op_city                                                        Los Angeles
# op_contract_date                                           August 15, 2008
# category_group                                  Web, Mobile & Software Dev
# skill_set                                            {svn, git, html, css}
#
#                                                                       7881
# ciphertext                                             ~0127566a84c383a055
# job_type                                                            Hourly
# op_title                                        Excel macro – VBA - Course
# job_post_date                                          2012-06-10 13:57:13
# op_description_stripped  I need an Excel Macro (VBA) course for my web ...
# op_timezone              UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# op_country                                                         Denmark
# op_city                                                        Snekkersten
# op_contract_date                                             June 10, 2012
# category_group                                                     Writing
# skill_set                                        {vba, microsoftdashexcel}
#
# [11 rows x 7882 columns]

# %%
job_level_df.drop(['op_city', 'op_contract_date'], axis=1, inplace=True)

# %% [markdown]
# # CREATE CANDIDATE-LEVEL DATA SET (JOB-PERSON TUPLES)

# %%
# DUPE CHECK
# jj = profiles_df.duplicated('dev_recno_ciphertext')
# any(jj = True)

# %%
def string_to_set(str):
    return set(str.split())
profiles_df['skills_set'] = profiles_df['skills_string'].apply(string_to_set)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-325-937ec8f3fd2f> in <module>()
#       1 def string_to_set(str):
#       2     return set(str.split())
# ----> 3 profiles_df['skills_set'] = profiles_df['skills_string'].apply(string_to_set)
#
# /Users/JerryTsai/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /Users/JerryTsai/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /Users/JerryTsai/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /Users/JerryTsai/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/JerryTsai/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'skills_string'

# %%
profiles_df.drop(['dev_portrait', 'education', 'skills_string'], axis=1, inplace=True)

# %%
profiles_df.T.head(30)
# Out:
#                                                                   0      \
# dev_bill_rate                                                        15
# dev_blurb             Over the more than 6 years, I have developed a...
# dev_country                                                       India
# dev_eng_skill                                                         4
# dev_profile_title                 LAMP developer with more than 6 years
# dev_recno_ciphertext                                ~01cae3810dc6d2bbbc
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                  Masters
# has_portfolio                                                      True
# took_tests                                                         True
# skills_set            {xml, apidashdevelopment, javascript, smtp, xm...
#
#                                                                   1      \
# dev_bill_rate                                                        12
# dev_blurb             I am a web application developer, having 2 yea...
# dev_country                                                       India
# dev_eng_skill                                                         5
# dev_profile_title                              Web Developer / Designer
# dev_recno_ciphertext                                ~01d24ced467385214d
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                         Bachelor of Engineering (B.Eng.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {css3, groovy, jquery, javascript, grails, aja...
#
#                                                                   2      \
# dev_bill_rate                                                     44.44
# dev_blurb             Extensive expertise in clinical research publi...
# dev_country                                               United States
# dev_eng_skill                                                         5
# dev_profile_title     English/French Writer/Translator,Scientific Di...
# dev_recno_ciphertext                                ~01953fb4fa2ceb67dc
# dev_timezone          UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree               Master of Business Administration (M.B.A.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {startupdashconsulting, technicaldashwriting, ...
#
#                                                                   3      \
# dev_bill_rate                                                     24.44
# dev_blurb             I'm a WEB-developer with more than 5 years exp...
# dev_country                                                     Ukraine
# dev_eng_skill                                                         5
# dev_profile_title     PHP/Zend Framework/MySql/MongoDB/SPHINX/jQuery...
# dev_recno_ciphertext                                ~01a9ab111f973ae055
# dev_timezone                       UTC+02:00 Athens, Helsinki, Istanbul
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                      False
# highest_degree                             Doctor of Philosophy (Ph.D.)
# has_portfolio                                                      True
# took_tests                                                         True
# skills_set            {jquery, linuxdashsystemdashadministration, sp...
#
#                                                                   4      \
# dev_bill_rate                                                        15
# dev_blurb             Specializes in developing Photoshop and After ...
# dev_country                                                   Sri Lanka
# dev_eng_skill
# dev_profile_title     After Effects, Photoshop - Scripting And Plugi...
# dev_recno_ciphertext                                ~016dcec1087cba565c
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {adobedashafterdasheffects, python, cplusplus,...
#
#                                                                   5      \
# dev_bill_rate                                                     16.67
# dev_blurb
# dev_country                                                     Germany
# dev_eng_skill                                                         5
# dev_profile_title     Development of reliable and flexible software(...
# dev_recno_ciphertext                                ~019e83a0dfa04c0e8b
# dev_timezone          UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                      False
# highest_degree                                                    Other
# has_portfolio                                                      True
# took_tests                                                         True
# skills_set            {xml, java, qt, unixdashsystemdashadministrati...
#
#                                                                   6      \
# dev_bill_rate                                                        30
# dev_blurb             skype :  orange_project_kh\nemail:    contact@...
# dev_country                                                     Ukraine
# dev_eng_skill                                                         4
# dev_profile_title     Fullstack web developer, e-commerce developing...
# dev_recno_ciphertext                                ~01863825efc778f975
# dev_timezone                                   UTC+02:00 Eastern Europe
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                Bachelors
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {css3, websitedashdevelopment, javascript, wor...
#
#                                                                   7      \
# dev_bill_rate                                                     11.11
# dev_blurb             DTL Solutions is the software solutions provid...
# dev_country                                                     Vietnam
# dev_eng_skill                                                         4
# dev_profile_title     Small IT solution company provides Development...
# dev_recno_ciphertext                                ~01614e82e3c5a0ccca
# dev_timezone                                UTC+07:00 Omsk, Novosibirsk
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree               Master of Business Administration (M.B.A.)
# has_portfolio                                                      True
# took_tests                                                        False
# skills_set            {webdashtesting, java, agiledashsoftwaredashde...
#
#                                                                   8      \
# dev_bill_rate                                                        10
# dev_blurb             I am an upcoming college graduate! I will rece...
# dev_country                                               United States
# dev_eng_skill                                                         5
# dev_profile_title               Upbeat Enthusiastic Professional Writer
# dev_recno_ciphertext                                ~0122260b02b0c56563
# dev_timezone              UTC-08:00 Pacific Time (US & Canada); Tijuana
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {editorialdashwriting, datadashanalysis, creat...
#
#                                                                   9      \
# dev_bill_rate                                                      5.56
# dev_blurb             1)  Shopping Card Management System using C# a...
# dev_country                                                  Bangladesh
# dev_eng_skill
# dev_profile_title               Bsc in Computer Science and Engineering
# dev_recno_ciphertext                                ~01a3583a33f5146e8e
# dev_timezone                                    UTC+06:00 Almaty, Dhaka
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                Bachelors
# has_portfolio                                                     False
# took_tests                                                        False
# skills_set            {css3, java, androiddashappdashdevelopment, ja...
#
#                                             ...                          \
# dev_bill_rate                               ...
# dev_blurb                                   ...
# dev_country                                 ...
# dev_eng_skill                               ...
# dev_profile_title                           ...
# dev_recno_ciphertext                        ...
# dev_timezone                                ...
# agency_affl                                 ...
# group_affl                                  ...
# has_portrait                                ...
# highest_degree                              ...
# has_portfolio                               ...
# took_tests                                  ...
# skills_set                                  ...
#
#                                                                   88686  \
# dev_bill_rate                                                     22.22
# dev_blurb             I'm a software engineer focused on backend and...
# dev_country                                                      Russia
# dev_eng_skill                                                         3
# dev_profile_title                                    Software Developer
# dev_recno_ciphertext                                ~01dfd63f31c5228d16
# dev_timezone                                UTC+07:00 Omsk, Novosibirsk
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                  Diploma
# has_portfolio                                                      True
# took_tests                                                        False
# skills_set            {djangodashframework, linuxdashsystemdashadmin...
#
#                                                                   88687  \
# dev_bill_rate                                                         4
# dev_blurb             I am  working as a  officer at Checkpoint syst...
# dev_country                                                  Bangladesh
# dev_eng_skill                                                         4
# dev_profile_title                                       IT Professional
# dev_recno_ciphertext                                ~018aaab6cfdc3fb96c
# dev_timezone                                    UTC+06:00 Almaty, Dhaka
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                 Master of Computer Applications (M.C.A.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {microsoftdashoutlook, virtualdashassistant, a...
#
#                                                                   88688  \
# dev_bill_rate                                                      6.67
# dev_blurb             To enhance my journalistic prowess through onl...
# dev_country                                                 Philippines
# dev_eng_skill                                                         4
# dev_profile_title     Statistician|News&Sports Writer|InDesign|Pagem...
# dev_recno_ciphertext                                ~01360017155d421ae3
# dev_timezone          UTC+08:00 Hong Kong SAR, Perth, Singapore, Taipei
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                            Bachelor of Education (B.Ed.)
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {datadashanalysis, statistics, adobedashpagema...
#
#                                                                   88689  \
# dev_bill_rate                                                     13.89
# dev_blurb             I'm a highly motivated person with a strong ba...
# dev_country                                                      Russia
# dev_eng_skill                                                         4
# dev_profile_title        Experienced developer and scientific assistant
# dev_recno_ciphertext                                ~0169007d9fa447a06b
# dev_timezone                UTC+03:00 Moscow, St. Petersburg, Volgograd
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                        Bachelor's degree
# has_portfolio                                                      True
# took_tests                                                         True
# skills_set            {springdashframework, hibernate, java, python,...
#
#                                                                   88690  \
# dev_bill_rate                                                        10
# dev_blurb             I like building cool web applications, and I o...
# dev_country                                                       India
# dev_eng_skill                                                         5
# dev_profile_title     An expert web application developer with Djang...
# dev_recno_ciphertext                                ~014920c811cecebbc4
# dev_timezone                           UTC (Coordinated Universal Time)
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                      False
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {djangodashframework, jquery, knockoutjs, pyth...
#
#                                                                   88691  \
# dev_bill_rate                                                     16.67
# dev_blurb             I configure and run the base station WiMAX on ...
# dev_country                                                      Russia
# dev_eng_skill                                                         3
# dev_profile_title                                    Software Developer
# dev_recno_ciphertext                                ~0148cf1eca9907db89
# dev_timezone                UTC+04:00 Abu Dhabi, Muscat, Tbilisi, Kazan
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                            Bachelor of Commerce (B.Com.)
# has_portfolio                                                     False
# took_tests                                                        False
# skills_set            {ciscodashrouters, linuxdashsystemdashadminist...
#
#                                                                   88692  \
# dev_bill_rate                                                     11.11
# dev_blurb             I am looking to help in software solutions . w...
# dev_country                                                       Egypt
# dev_eng_skill                                                         5
# dev_profile_title                                           Ahmed Eshra
# dev_recno_ciphertext                                ~01baacbe6b9e3d8c30
# dev_timezone                                            UTC+02:00 Cairo
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                 Master's
# has_portfolio                                                      True
# took_tests                                                         True
# skills_set            {j2ee, java, androiddashappdashdevelopment, cp...
#
#                                                                   88693  \
# dev_bill_rate                                                        35
# dev_blurb             I have extensive experience using Python to so...
# dev_country                                               United States
# dev_eng_skill                                                         5
# dev_profile_title                            Python & ArcGIS Programmer
# dev_recno_ciphertext                                ~013659f86de224bdf9
# dev_timezone                      UTC-07:00 Mountain Time (US & Canada)
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                       Bachelor of Architecture (B.Arch.)
# has_portfolio                                                     False
# took_tests                                                        False
# skills_set                                    {python, arcgis, autocad}
#
#                                                                   88694  \
# dev_bill_rate                                                         3
# dev_blurb             Looking for work in proofreading, editing or c...
# dev_country                                                       India
# dev_eng_skill                                                         4
# dev_profile_title
# dev_recno_ciphertext                                ~01b9ca1c9967daf519
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                    Other
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {microsoftdashword, microsoftdashexcel, presen...
#
#                                                                   88695
# dev_bill_rate                                                        30
# dev_blurb             I have 8 Years of Profession Experience and i ...
# dev_country                                                       India
# dev_eng_skill                                                         5
# dev_profile_title                                          Project Lead
# dev_recno_ciphertext                                ~01a0cdfa47888e70f7
# dev_timezone              UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# agency_affl                                                       False
# group_affl                                                        False
# has_portrait                                                       True
# highest_degree                                                  Masters
# has_portfolio                                                     False
# took_tests                                                         True
# skills_set            {springdashframework, hibernate, java, richfac...
#
# [14 rows x 88696 columns]

# %%
for col in list(profiles_df.columns):
    print col
# Out:
# dev_bill_rate
# dev_blurb
# dev_country
# dev_eng_skill
# dev_profile_title
# dev_recno_ciphertext
# dev_timezone
# agency_affl
# group_affl
# has_portrait
# highest_degree
# has_portfolio
# took_tests
# skills_set

# %%
cand_level_df = pd.merge( \
                           cand_df, assi_df, how='left', \
                           left_on=['ciphertext', 'cand_ciphertext'], \
                           right_on=['ciphertext', 'ciphertext_developer_recno'], \
                           indicator=True \
                          )

# %%
cand_level_df['got_assignment'] = (cand_level_df['_merge'] == 'both')

# %%
cand_level_df.drop(['_merge'], axis=1, inplace=True)

# %% [markdown]
# ### GRAFT PERSON-LEVEL and JOB-LEVEL DATA SETS TO CANDIDATE=(PERSON, JOB)-LEVEL DATA SET

# %%
cand_level_df = pd.merge( \
                           cand_level_df, profiles_df, how='inner', \
                           left_on='cand_ciphertext', \
                           right_on='dev_recno_ciphertext', \
                           indicator=True
                          )

# %%
cand_level_df = pd.merge( \
                           job_level_df, cand_level_df, how='inner', \
                           on='ciphertext'
                          )
# Out:
#    dev_bill_rate                                          dev_blurb  \
# 0             25       To work on challenging and Interesting tasks
# 1             25       To work on challenging and Interesting tasks
# 2             15  I have been creating desktop and web applicati...
# 3              5  Over the last 3 years, I have worked on variou...
# 4             18  **AngularJS Expert with Good Experience of int...
#
#    dev_country dev_eng_skill  \
# 0   Bangladesh             5
# 1   Bangladesh             5
# 2  Philippines             5
# 3        India             5
# 4        India             5
#
#                                    dev_profile_title dev_recno_ciphertext  \
# 0  Full Stack Ninja-Scrumaster,ZCE,PHP architect ...  ~0134cb1a5bc41091bd
# 1  Full Stack Ninja-Scrumaster,ZCE,PHP architect ...  ~0134cb1a5bc41091bd
# 2  SAP ABAP / Desktop / Web / Android Application...  ~0145e2b0413f5370db
# 3    more than 3 years experience in .Net framework.  ~014b5cba34a56db30c
# 4  AngularJS / MEAN stack expert with extensive e...  ~018bb9b4242df48d59
#
#                                     dev_timezone agency_affl group_affl  \
# 0                        UTC+06:00 Almaty, Dhaka       False       True
# 1                        UTC+06:00 Almaty, Dhaka       False       True
# 2           UTC+08:00 Beijing, Chongqing, Urumqi       False      False
# 3  UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi       False      False
# 4  UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi        True      False
#
#   has_portrait  ...   took_tests  \
# 0         True  ...         True
# 1         True  ...         True
# 2         True  ...         True
# 3         True  ...         True
# 4        False  ...        False
#
#                                           skills_set           ciphertext  \
# 0  {scrum, codeigniter, mongodb, javascript, lara...  ~011dee797f850958f4
# 1  {scrum, codeigniter, mongodb, javascript, lara...  ~012305d1bdefe9f258
# 2  {microsoftdashword, vba, java, androiddashappd...  ~01219d223b11f09e19
# 3  {jquery, dotnetdashframework, linqdashtodashsq...  ~01097c28695055d013
# 4  {jquery, firebase, mongodb, javascript, nodedo...  ~011656b1a5a3c9bc66
#
#        cand_ciphertext     create_datetime ciphertext_developer_recno  \
# 0  ~0134cb1a5bc41091bd 2013-08-14 02:10:05                        NaN
# 1  ~0134cb1a5bc41091bd 2011-03-28 03:24:21        ~0134cb1a5bc41091bd
# 2  ~0145e2b0413f5370db 2011-04-22 04:33:29        ~0145e2b0413f5370db
# 3  ~014b5cba34a56db30c 2013-12-23 06:33:05                        NaN
# 4  ~018bb9b4242df48d59 2016-02-11 04:25:52                        NaN
#
#        start_datetime        end_datetime got_assignment _merge
# 0                 NaT                 NaT          False   both
# 1 2011-03-28 17:00:00 2011-05-31 17:00:00           True   both
# 2 2011-04-21 17:00:00 2011-04-21 17:00:00           True   both
# 3                 NaT                 NaT          False   both
# 4                 NaT                 NaT          False   both
#
# [5 rows x 22 columns]

# %%
cand.T.head(30)
