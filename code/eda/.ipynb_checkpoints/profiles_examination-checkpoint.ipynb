# %%
import json
import pandas as pd
import numpy as np
from collections import Counter
# %matplotlib inline

# %% [markdown]
# Get freelancer profile by key
#
# Endpoint
# GET /api/profiles/v1/providers/{profile_key}.{format}

# %%
def json_read(in_file):
    # read the entire file into a python array
    with open(in_file, 'rb') as f:
        data = f.readlines()

    # remove the trailing "\n" from each line
    data = map(lambda x: x.rstrip(), data)

    # each element of 'data' is an individual JSON object.
    # i want to convert it into an *array* of JSON objects
    # which, in and of itself, is one large JSON object
    # basically... add square brackets to the beginning
    # and end, and have all the individual business JSON objects
    # separated by a comma
    data_json_str = "[" + ','.join(data) + "]"

    # now, load it into pandas
    out_df = pd.read_json(data_json_str)
    return out_df

# %% [markdown]
# ## Data Science

# %%
ds_profiles = json_read('../../data/skills_id/data_scientist.txt')

# %%
ds_profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3549 entries, 0 to 3548
# Data columns (total 16 columns):
# categories2              3494 non-null object
# country                  3549 non-null object
# description              3536 non-null object
# feedback                 3549 non-null float64
# groups                   25 non-null object
# id                       3549 non-null object
# last_activity            3549 non-null object
# member_since             3549 non-null object
# name                     3549 non-null object
# portfolio_items_count    3549 non-null int64
# portrait_50              3294 non-null object
# profile_type             3549 non-null object
# rate                     3549 non-null float64
# skills                   2828 non-null object
# test_passed_count        3549 non-null int64
# title                    3521 non-null object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 471.4+ KB

# %%
ds_profiles['title'].value_counts()
# Out:
# Data Scientist                                                       635
# Data scientist                                                       101
# Computer Scientist                                                    47
# Research Scientist                                                    30
# Scientist                                                             27
# Senior Data Scientist                                                 22
# data scientist                                                        18
# Data Analyst                                                          16
# Software Engineer                                                     15
# Environmental Scientist                                               15
# Junior Data Scientist                                                 11
# computer scientist                                                    11
# Freelance Data Scientist                                               9
# Computer scientist                                                     8
# Statistician/Data Scientist                                            8
# Software Developer                                                     8
# Decision Scientist                                                     6
# Mr                                                                     6
# Aspiring Data Scientist                                                6
# Expert Data Scientist                                                  6
# Senior Scientist                                                       5
# Biomedical Scientist                                                   5
# Data Scientist/Analyst                                                 5
# Analyst                                                                5
# Bioinformatics Scientist                                               5
# Medical Laboratory Scientist                                           5
# Research scientist                                                     5
# Information Scientist                                                  4
# Writer and Editor                                                      4
# Lead Data Scientist                                                    4
#                                                                     ...
# Data Entry                                                             1
# scientist, translator                                                  1
# Experience Data Scientist with NLP,ML,BigData                          1
# Project Manager / Data Scientist / SEO                                 1
# Data Scientist / C# Developer / SQL Server Developer                   1
# Data scientist, Bioinformatician                                       1
# Aspiring Data scientist / Software developer                           1
# International relationship manager                                     1
# Professional Environmental Scientist, Technical Writer                 1
# PhD statistics and writing expert with 10+ years experience            1
# Technical, Academic, and Blog Writer                                   1
# Software Developer/Data Analyst/Data Scientist                         1
# Junior executive                                                       1
# kaba computer scientist and design                                     1
# Data Scientist / C# Developer                                          1
# Bioinformatician, data scientist, Linux/Unix expert                    1
# EXPERIENCED DATA-MINING,INTERNET RESEARCHER AND CREATIVE WRITER        1
# Junior Biology Scientist                                               1
# Magento/E-Commerce/Wordpress Expert / Data Scientist                   1
# Expert Data Scientist with R, Python, SQL, Tableau.. experience        1
# Writer, Business Consultant, Data Scientist and Philosopher            1
# Researcher, Strategist, Data Scientist                                 1
# Software Engineer / Big Data Scientist                                 1
# Senior Research Scientist and Statistical Consultant                   1
# Data Scientist and Software Engineer                                   1
# iOS Developer and Data Scientist                                       1
# computer scientist-Translator from English to French                   1
# Environmental Scientist with Biodiversity and Research experience      1
# machine learning / data scientist                                      1
# Image Processing and Machine Learning Expert                           1
# Name: title, dtype: int64

# %%
def data_scientist_in(str):
    # Some people may not have titles in which case their titles are NaNs
    if isinstance(str, float):
        return False
    if 'data' in str.lower() and 'scientist' in str.lower():
        return True
    else: return False

# %%
vect_dsi = np.vectorize(data_scientist_in)
ds_profiles['ds_flag'] = vect_dsi(np.array(ds_profiles[u'title']))

# %%
ds_profiles[ds_profiles['ds_flag'] == True][u'title'].value_counts()
# Out:
# Data Scientist                                                            635
# Data scientist                                                            101
# Senior Data Scientist                                                      22
# data scientist                                                             18
# Junior Data Scientist                                                      11
# Freelance Data Scientist                                                    9
# Statistician/Data Scientist                                                 8
# Expert Data Scientist                                                       6
# Aspiring Data Scientist                                                     6
# Data Scientist/Analyst                                                      5
# Lead Data Scientist                                                         4
# Experienced Data Scientist                                                  4
# Web Developer and Data Scientist                                            4
# Data Analyst/Scientist                                                      3
# Data Analyst/Data Scientist                                                 3
# Software Engineer / Data Scientist                                          3
# Data Scientist/Statistician                                                 3
# Data Scientist / Engineer                                                   3
# Software Engineer & Data Scientist                                          3
# Data Scientist & Web Developer                                              3
# Data Scientist/Engineer                                                     3
# Data Scientist / Statistical Analyst                                        3
# Professional Data Scientist                                                 3
# Full Stack Data Scientist                                                   3
# Software Developer and Data Scientist                                       3
# Data Scientist and Strategy Consultant                                      3
# Data Scientist and Statistician                                             2
# Applied Mathematician and Data Scientist                                    2
# Software Developer, Python Programmer, Data Scientist                       2
# Data Scientist/Machine learning engineer                                    2
#                                                                          ...
# Data Scientist | Computer Scientist | Physicist                             1
# Cross-Functional Data Scientist and Mechanical Engineer                     1
# Data Scientist / Semantic Web                                               1
# Hadoop developer, Data Scientist, Web Developer                             1
# Data Scientist. ML, R, SAS, Python, ETL, AWS Developer.                     1
# Data scientist with expertise in data analytics                             1
# Data scientist with experimental biophysics research background             1
# PhD Professional Data Scientist/Statistician                                1
# Data Scientist/ programmer/ Big Data consultant                             1
# Data and Algorithms Lead, Scientist                                         1
# Python programmer, Django Web Developer, Data Scientist                     1
# Scala developer / Data scientist                                            1
# Data Scientist and IT Architect                                             1
# C++ and data scientist expert                                               1
# python scrapper / data scientist                                            1
# Big Data Engineer & Scientist                                               1
# Youngest Data Scientist                                                     1
# Data Scientist , Data Entry proffesional                                    1
# Comercially minded Data Scientist/Machine Learning Engineer                 1
# Researcher/ scientist/ lecturer/ Copywriter/ Technical Writer, Data en      1
# Data Scientist,Engineering Student,Persistent Web Surfer and Workhorse      1
# Physicist/Data Scientist                                                    1
# Data Scientist, Machine learning developer, Quantitative researcher         1
# Data Scientist and Astrophysicist                                           1
# Data Scientist, Tableau Consultant                                          1
# Statistician / Research Scientist / Data Manager                            1
# Finance Specialist, Data Scientist, English/French Speaker                  1
# Jr. Machine Learning Researcher / Data Scientist                            1
# Statistician (Data scientist) with PhD and 10 years of R experience         1
# Data Scientist and Data Miner, Python, scipy, R                             1
# Name: title, dtype: int64

# %%
ds_profiles[ds_profiles['ds_flag'] == True][u'skills'][0]
# Out:
# [u'elasticsearch',
#  u'full-text-search-engines',
#  u'data-science',
#  u'machine-learning',
#  u'natural-language-processing',
#  u'lucene-search']

# %%
skills_of_ds = ds_profiles[ds_profiles['ds_flag'] == True][u'skills']

# %%
ds_skill_words = Counter()
for index, skill_set in enumerate(skills_of_ds):
    if isinstance(skill_set, float):
        print index
        pass
    else: ds_skill_words += Counter(skill_set)
# Out:
# 3
# 28
# 29
# 31
# 42
# 45
# 46
# 49
# 52
# 58
# 66
# 68
# 69
# 70
# 71
# 76
# 77
# 78
# 113
# 120
# 128
# 130
# 145
# 147
# 148
# 149
# 150
# 151
# 155
# 156
# 157
# 179
# 190
# 191
# 192
# 194
# 207
# 208
# 217
# 219
# 223
# 224
# 229
# 248
# 249
# 253
# 258
# 259
# 264
# 267
# 271
# 307
# 335
# 359
# 360
# 363
# 371
# 372
# 373
# 374
# 379
# 380
# 386
# 429
# 430
# 436
# 447
# 449
# 459
# 465
# 466
# 467
# 469
# 470
# 474
# 475
# 477
# 479
# 482
# 503
# 510
# 514
# 516
# 521
# 526
# 528
# 540
# 541
# 561
# 564
# 569
# 592
# 599
# 600
# 601
# 604
# 605
# 606
# 609
# 610
# 613
# 614
# 621
# 630
# 634
# 636
# 639
# 641
# 642
# 643
# 644
# 645
# 646
# 649
# 655
# 656
# 659
# 660
# 668
# 670
# 671
# 672
# 674
# 689
# 699
# 706
# 727
# 729
# 731
# 732
# 744
# 751
# 752
# 755
# 756
# 761
# 767
# 768
# 769
# 772
# 780
# 787
# 788
# 789
# 798
# 805
# 814
# 816
# 818
# 819
# 820
# 822
# 824
# 849
# 856
# 875
# 879
# 880
# 884
# 886
# 888
# 889
# 890
# 895
# 899
# 901
# 909
# 910
# 912
# 915
# 922
# 926
# 928
# 938
# 939
# 940
# 941
# 950
# 957
# 958
# 959
# 962
# 970
# 971
# 972
# 973
# 990
# 994
# 995
# 998
# 1004
# 1009
# 1016
# 1020
# 1021
# 1023
# 1038
# 1050
# 1051
# 1056
# 1058
# 1059
# 1061
# 1062
# 1068
# 1070
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1084
# 1088
# 1090
# 1092
# 1097
# 1101
# 1107
# 1108
# 1118
# 1120
# 1122
# 1123
# 1130
# 1132
# 1134
# 1145
# 1151
# 1152
# 1153
# 1172
# 1178
# 1184
# 1185
# 1190
# 1194
# 1199
# 1210
# 1219
# 1229
# 1231
# 1232
# 1233
# 1247
# 1260
# 1266
# 1277
# 1283
# 1288
# 1289
# 1294
# 1298
# 1310
# 1311
# 1312
# 1313
# 1316
# 1318
# 1319
# 1320
# 1321
# 1323
# 1324
# 1326
# 1330
# 1333
# 1335
# 1342
# 1352
# 1362
# 1371
# 1374
# 1376
# 1383
# 1396
# 1400
# 1403
# 1408
# 1413
# 1415
# 1422
# 1426
# 1427
# 1428
# 1431
# 1432
# 1434
# 1438
# 1441
# 1444
# 1446
# 1449
# 1458
# 1465
# 1467
# 1470
# 1472
# 1475
# 1476
# 1477
# 1479
# 1485
# 1487
# 1488
# 1489
# 1495
# 1497
# 1502
# 1504
# 1506
# 1512
# 1521
# 1526
# 1530
# 1548
# 1550
# 1559
# 1564
# 1574
# 1578
# 1579
# 1587
# 1591
# 1601
# 1604
# 1605
# 1606
# 1607
# 1610
# 1612
# 1616
# 1627
# 1630
# 1633
# 1645
# 1647
# 1649
# 1650
# 1655
# 1665
# 1668
# 1677
# 1680
# 1682
# 1684
# 1686
# 1688
# 1691
# 1695
# 1703
# 1707
# 1708
# 1710
# 1714
# 1722
# 1730
# 1731
# 1733
# 1738
# 1739
# 1742
# 1743
# 1746
# 1751
# 1753
# 1766
# 1769
# 1776
# 1780
# 1781
# 1782
# 1784
# 1791
# 1793
# 1794
# 1803
# 1814
# 1817
# 1824
# 1825

# %%
ds_profiles[ds_profiles['ds_flag'] == True][u'skills'][3]
# Out:
# nan

# %%
ds_profiles[ds_profiles['ds_flag'] == True].loc[3]
# Out:
# categories2                                                            NaN
# country                                                      United States
# description              I have seven years of experience using data to...
# feedback                                                                 0
# groups                                                                 NaN
# id                                                     ~012e0c5b631c1fea24
# last_activity                                               April 10, 2016
# member_since                                             February 21, 2011
# name                                                        Christopher F.
# portfolio_items_count                                                    1
# portrait_50              https://odesk-prod-portraits.s3.amazonaws.com/...
# profile_type                                                   Independent
# rate                                                                   159
# skills                                                                 NaN
# test_passed_count                                                        0
# title                                                       Data Scientist
# ds_flag                                                               True
# Name: 3, dtype: object

# %%
ds_skill_words
# Out:
# Counter({u'.net-framework': 9,
#          u'3d-design': 1,
#          u'ab-testing': 11,
#          u'academic-writing': 12,
#          u'accounting': 3,
#          u'ad-posting': 1,
#          u'adaptive-algorithms': 1,
#          u'administrative-support': 4,
#          u'adobe-acrobat': 1,
#          u'adobe-after-effects': 1,
#          u'adobe-analytics': 4,
#          u'adobe-business-catalyst': 2,
#          u'adobe-creative-suite': 2,
#          u'adobe-digital-marketing-suite': 1,
#          u'adobe-dreamweaver': 1,
#          u'adobe-illustrator': 4,
#          u'adobe-indesign': 2,
#          u'adobe-photoshop': 10,
#          u'adobe-photoshop-lightroom': 1,
#          u'adobe-premiere-pro': 1,
#          u'advertising': 1,
#          u'agile-software-development': 9,
#          u'aix': 1,
#          u'ajax': 2,
#          u'akka': 1,
#          u'algorithm-development': 12,
#          u'algorithms': 44,
#          u'amazon-ec2': 11,
#          u'amazon-rds': 3,
#          u'amazon-s3': 5,
#          u'amazon-web-services': 25,
#          u'analytics': 70,
#          u'android': 11,
#          u'android-app-development': 11,
#          u'android-sdk': 2,
#          u'angularjs': 28,
#          u'ansi-c': 1,
#          u'ansys': 1,
#          u'apache-administration': 1,
#          u'apache-cordova': 1,
#          u'apache-flume': 1,
#          u'apache-hive': 34,
#          u'apache-kafka': 4,
#          u'apache-mahout': 7,
#          u'apache-maven': 1,
#          u'apache-nutch': 1,
#          u'apache-solr': 7,
#          u'apache-spark': 106,
#          u'apache-tomcat': 1,
#          u'api-development': 6,
#          u'app-usability-analysis': 1,
#          u'apple-xcode': 1,
#          u'application-programming': 2,
#          u'application-server': 1,
#          u'arabic': 1,
#          u'arcgis': 7,
#          u'architectural-design': 1,
#          u'arduino': 3,
#          u'article-curation': 2,
#          u'article-rewriting': 1,
#          u'article-writing': 11,
#          u'artificial-intelligence': 34,
#          u'artificial-neural-networks': 56,
#          u'asp.net': 7,
#          u'asp.net-mvc': 8,
#          u'astrophysics': 1,
#          u'atlassian-confluence': 1,
#          u'atlassian-jira': 3,
#          u'autocad': 1,
#          u'autodesk': 1,
#          u'autohotkey': 1,
#          u'autoit': 1,
#          u'automation': 3,
#          u'avid-pro-tools': 1,
#          u'awk': 2,
#          u'axapta': 1,
#          u'b2b-marketing': 1,
#          u'backbone-js': 1,
#          u'baking': 1,
#          u'bas-reporting': 1,
#          u'bash': 10,
#          u'bash-shell-scripting': 21,
#          u'big-data': 89,
#          u'bio-informatics': 15,
#          u'biology': 6,
#          u'biostatistics': 21,
#          u'biotechnology': 4,
#          u'bitcoin': 1,
#          u'black-box-testing': 1,
#          u'blog-commenting': 1,
#          u'blog-writing': 5,
#          u'bootstrap': 5,
#          u'brand-consulting': 2,
#          u'brand-licensing': 1,
#          u'brand-management': 1,
#          u'budgeting': 1,
#          u'business-analysis': 61,
#          u'business-card-design': 1,
#          u'business-coaching': 2,
#          u'business-development': 1,
#          u'business-intelligence': 45,
#          u'business-it-alignment': 2,
#          u'business-management': 4,
#          u'business-mathematics': 6,
#          u'business-models': 4,
#          u'business-plans': 5,
#          u'business-process-modelling': 9,
#          u'business-process-reengineering': 2,
#          u'business-proposal-writing': 1,
#          u'business-writing': 2,
#          u'c': 68,
#          u'c#': 46,
#          u'c++': 80,
#          u'c-shell': 1,
#          u'cad-design': 1,
#          u'cakephp': 1,
#          u'calculus': 5,
#          u'cartography': 2,
#          u'cassandra': 8,
#          u'catalan': 1,
#          u'centos': 2,
#          u'certified-public-accountant': 1,
#          u'chemistry': 4,
#          u'christian-theology': 1,
#          u'climate-sciences': 1,
#          u'clojure': 5,
#          u'cloudera': 3,
#          u'clustering': 14,
#          u'cobol': 2,
#          u'cocos2d': 1,
#          u'codeigniter': 1,
#          u'coffeescript': 2,
#          u'cognos': 4,
#          u'collaborative-filtering': 2,
#          u'communications': 2,
#          u'compiler': 1,
#          u'computational-linguistics': 5,
#          u'computer-networking': 1,
#          u'computer-skills': 2,
#          u'computer-vision': 18,
#          u'content-moderation': 1,
#          u'content-writing': 8,
#          u'continuous-integration': 2,
#          u'conversion-rate-optimization': 5,
#          u'cooking': 1,
#          u'copy-editing': 1,
#          u'copywriting': 2,
#          u'core-java': 7,
#          u'corporate-finance': 5,
#          u'corporate-strategy': 6,
#          u'corporate-tax': 1,
#          u'cover-letter-writing': 3,
#          u'cpanel': 1,
#          u'creative-writing': 5,
#          u'crm': 3,
#          u'cryptography': 1,
#          u'crystal-reports': 2,
#          u'css': 41,
#          u'css3': 23,
#          u'cuda': 2,
#          u'customer-service': 2,
#          u'd3.js': 48,
#          u'data-analysis': 420,
#          u'data-cleansing': 49,
#          u'data-encoding': 7,
#          u'data-engineering': 21,
#          u'data-entry': 40,
#          u'data-ingestion': 1,
#          u'data-interpretation': 22,
#          u'data-logistics': 4,
#          u'data-mining': 378,
#          u'data-modeling': 114,
#          u'data-protection': 2,
#          u'data-recovery': 1,
#          u'data-science': 488,
#          u'data-scraping': 75,
#          u'data-sheet-writing': 2,
#          u'data-structures': 12,
#          u'data-sufficiency': 1,
#          u'data-visualization': 161,
#          u'data-warehousing': 27,
#          u'database-administration': 2,
#          u'database-adminstration': 3,
#          u'database-cataloguing': 2,
#          u'database-design': 23,
#          u'database-management': 13,
#          u'database-modeling': 12,
#          u'database-programming': 13,
#          u'database-testing': 2,
#          u'dbase': 1,
#          u'dbase-programming': 1,
#          u'dbms': 1,
#          u'dental-technology': 1,
#          u'derivatives': 1,
#          u'desktop-applications': 1,
#          u'digital-mapping': 1,
#          u'digital-signal-processing': 11,
#          u'distance-education': 1,
#          u'distributed-computing': 4,
#          u'django-framework': 32,
#          u'dns': 1,
#          u'docker': 2,
#          u'dos': 1,
#          u'drupal': 4,
#          u'e-health': 2,
#          u'ebay-listing-writing': 1,
#          u'ebook-writing': 1,
#          u'ecommerce-consulting': 4,
#          u'econometrics': 32,
#          u'economic-analysis': 12,
#          u'economics': 11,
#          u'editing': 4,
#          u'editorial-writing': 1,
#          u'education-technology': 2,
#          u'elasticsearch': 18,
#          u'email-handling': 1,
#          u'email-marketing': 3,
#          u'embedded-linux': 2,
#          u'embedded-systems': 3,
#          u'energy-engineering': 1,
#          u'engineering-design': 1,
#          u'english': 3,
#          u'english-proofreading': 2,
#          u'english-spelling': 1,
#          u'entrepreneurship': 2,
#          u'environmental-science': 3,
#          u'erlang': 1,
#          u'erp': 1,
#          u'erwin': 2,
#          u'esl-teaching': 1,
#          u'essbase': 1,
#          u'etl': 28,
#          u'event-management': 1,
#          u'event-planning': 1,
#          u'eviews': 4,
#          u'excel-vba': 91,
#          u'express-js': 1,
#          u'facebook-api': 1,
#          u'facebook-marketing': 4,
#          u'fiber-optics': 1,
#          u'final-cut-pro': 2,
#          u'financial-accounting': 1,
#          u'financial-analysis': 26,
#          u'financial-forecasting': 14,
#          u'financial-management': 2,
#          u'financial-modeling': 28,
#          u'financial-prospectus-writing': 1,
#          u'financial-reporting': 1,
#          u'flask': 18,
#          u'forex-trading': 2,
#          u'fortran': 5,
#          u'fraud-analysis': 2,
#          u'french': 3,
#          u'frontend-development': 2,
#          u'full-text-search-engines': 3,
#          u'functional-testing': 1,
#          u'game-design': 4,
#          u'game-development': 3,
#          u'game-programming': 2,
#          u'genetic-algorithms': 4,
#          u'genetic-engineering': 2,
#          u'geology': 2,
#          u'geometry': 1,
#          u'geospatial': 8,
#          u'german': 1,
#          u'ggplot2': 18,
#          u'gis': 16,
#          u'git': 12,
#          u'github': 6,
#          u'golang': 4,
#          u'google-adwords': 7,
#          u'google-analytics': 23,
#          u'google-analytics-api': 3,
#          u'google-app-engine': 4,
#          u'google-app-engine-api': 1,
#          u'google-docs': 5,
#          u'google-maps-api': 3,
#          u'google-plus': 1,
#          u'google-searching': 1,
#          u'google-spreadsheet': 2,
#          u'google-website-optimizer': 1,
#          u'grant-writing': 4,
#          u'graph-databases': 8,
#          u'graphic-design': 3,
#          u'graphics-programming': 2,
#          u'guitar-composition': 1,
#          u'guitar-performance': 1,
#          u'hadoop': 108,
#          u'haskell': 3,
#          u'hbase': 12,
#          u'health-level-7': 1,
#          u'helpdesk-support': 1,
#          u'heroku': 1,
#          u'hibernate': 4,
#          u'highcharts': 3,
#          u'hp-quality-center': 1,
#          u'html': 51,
#          u'html5': 42,
#          u'human-resource-management': 1,
#          u'human-sciences': 3,
#          u'humor-writing': 1,
#          u'hyperion': 1,
#          u'ibatis': 1,
#          u'ibm-db2': 3,
#          u'ibm-spss': 94,
#          u'ibm-watson': 1,
#          u'image-processing': 13,
#          u'imaging': 1,
#          u'inbound-marketing': 1,
#          u'indexing': 1,
#          u'infographics': 2,
#          u'informatica': 9,
#          u'information-architecture': 1,
#          u'information-design': 1,
#          u'information-security': 1,
#          u'instagram-api': 2,
#          u'interaction-design': 1,
#          u'internet-marketing': 1,
#          u'internet-research': 10,
#          u'internet-security': 1,
#          u'internet-surveys': 3,
#          u'intuit-quickbooks': 2,
#          u'inventory-management': 1,
#          u'investment-research': 3,
#          u'invitation-design': 1,
#          u'ionic-framework': 2,
#          u'ios-development': 6,
#          u'iso-9001': 1,
#          u'it-management': 2,
#          u'j2ee': 5,
#          u'japanese': 2,
#          u'java': 201,
#          u'java-ee': 4,
#          u'java-servlets-development': 4,
#          u'javascript': 106,
#          u'job-description-writing': 1,
#          u'joomla': 1,
#          u'journalism-writing': 1,
#          u'jquery': 23,
#          u'jquery-mobile': 1,
#          u'json': 1,
#          u'junit': 2,
#          u'keynote': 1,
#          u'labview': 2,
#          u'lamp-administration': 2,
#          u'laravel-framework': 1,
#          u'lasso': 1,
#          u'latex': 31,
#          u'lean-consulting': 3,
#          u'legal-research': 1,
#          u'libreoffice': 1,
#          u'linear-programming': 7,
#          u'linguistics': 1,
#          u'linq': 1,
#          u'linq-to-sql': 1,
#          u'linux-slackware': 1,
#          u'linux-system-administration': 18,
#          u'lisp': 2,
#          u'literature-review': 3,
#          u'logo-design': 1,
#          u'lua': 3,
#          u'lucene-search': 4,
#          u'mac-os-app-development': 1,
#          u'machine-design': 2,
#          u'machine-learning': 531,
#          u'magento': 2,
#          u'mail-merge': 1,
#          u'management-consulting': 4,
#          u'management-development': 2,
#          u'management-skills': 5,
#          u'manufacturing': 3,
#          u'mapreduce': 17,
#          u'market-research': 22,
#          u'marketing-automation': 2,
#          u'marketing-strategy': 18,
#          u'mathcad': 1,
#          u'mathematica': 13,
#          u'mathematics': 59,
#          u'matlab': 194,
#          u'maven': 1,
#          u'mechanical-design': 2,
#          u'mechanical-engineering': 4,
#          u'mechatronics': 1,
#          u'mediawiki': 1,
#          u'medical-imaging': 2,
#          u'medical-informatics': 2,
#          u'medical-records-research': 2,
#          u'medical-transcription': 1,
#          u'medical-translation': 1,
#          u'medical-writing': 2,
#          u'mercurial': 1,
#          u'metatrader-4-mt4': 2,
#          u'meteor': 6,
#          u'methods-engineering': 1,
#          u'microcontroller-programming': 1,
#          u'microsoft-access': 24,
#          u'microsoft-access-programming': 9,
#          u'microsoft-business-intelligence-studio': 3,
#          u'microsoft-connect': 1,
#          u'microsoft-dynamics': 1,
#          u'microsoft-dynamics-crm': 2,
#          u'microsoft-entity-framework': 1,
#          u'microsoft-excel': 248,
#          u'microsoft-excel-powerpivot': 33,
#          u'microsoft-hyper-v': 1,
#          u'microsoft-office': 22,
#          u'microsoft-onenote': 1,
#          u'microsoft-outlook': 5,
#          u'microsoft-powerpoint': 46,
#          u'microsoft-project': 4,
#          u'microsoft-sccm': 1,
#          u'microsoft-scvmm': 1,
#          u'microsoft-sharepoint-administration': 1,
#          u'microsoft-sharepoint-development': 2,
#          u'microsoft-sql-server-administration': 5,
#          u'microsoft-sql-server-development': 14,
#          u'microsoft-sql-ssas': 7,
#          u'microsoft-sql-ssrs': 13,
#          u'microsoft-visio': 7,
#          u'microsoft-visual-basic': 4,
#          u'microsoft-visual-c++': 2,
#          u'microsoft-visual-studio': 3,
#          u'microsoft-windows-powershell': 2,
#          u'microsoft-word': 29,
#          u'microstrategy': 4,
#          u'mind-mapping': 1,
#          u'minitab': 12,
#          u'mixpanel': 3,
#          u'mobile-app-development': 3,
#          u'mobile-ui-design': 2,
#          u'mongodb': 50,
#          u'mql4': 1,
#          u'ms-office-365': 4,
#          u'multi-level-marketing-mlm': 1,
#          u'multithreaded-programming': 1,
#          u'music-composition': 2,
#          u'mvc-framework': 1,
#          u'mysql': 76,
#          u'mysql-programming': 10,
#          u'nanotechnology': 1,
#          u'natural-language-processing': 62,
#          u'negotiation': 1,
#          u'neo4j': 5,
#          u'netezza': 1,
#          u'netsuite-administration': 1,
#          u'network-administration': 1,
#          u'network-analysis': 6,
#          u'network-security': 1,
#          u'nginx': 1,
#          u'node.js': 31,
#          u'nopcommerce': 1,
#          u'nosql': 18,
#          u'nutrition': 1,
#          u'oauth': 1,
#          u'objective-c': 5,
#          u'ocr-algorithms': 1,
#          u'ocr-tesseract': 1,
#          u'octave': 23,
#          u'office-administration': 1,
#          u'olap': 5,
#          u'online-help': 1,
#          u'oop': 1,
#          u'opencv': 11,
#          u'opengl': 1,
#          u'openstack': 1,
#          u'operating-systems-development': 1,
#          u'operations-management': 2,
#          u'operations-research': 9,
#          u'optimizely': 1,
#          u'oracle-administration': 1,
#          u'oracle-application-server': 1,
#          u'oracle-database': 12,
#          u'oracle-database-administration': 2,
#          u'oracle-forms': 1,
#          u'oracle-fusion-middleware': 1,
#          u'oracle-java-ee': 2,
#          u'oracle-obiee-plus': 5,
#          u'oracle-pl/sql': 11,
#          u'oracle-plsql': 10,
#          u'oracle-reports': 1,
#          u'parallels-virtual-desktop': 1,
#          u'pattern-recognition': 16,
#          u'pcb-design': 2,
#          u'pdf-conversion': 1,
#          u'pentaho': 2,
#          u'peoplesoft-administration': 1,
#          u'peoplesoft-development': 1,
#          u'performance-testing': 2,
#          u'perl': 27,
#          u'perl-catalyst': 1,
#          u'phonegap': 1,
#          u'photo-editing': 1,
#          u'photography': 2,
#          u'php': 59,
#          u'phpbb': 1,
#          u'phpmyadmin': 1,
#          u'physics': 11,
#          u'pig': 11,
#          u'play-framework': 2,
#          u'poetry': 1,
#          u'policy-writing': 1,
#          u'portfolio-performance-modeling': 4,
#          u'portuguese': 3,
#          u'postgresql': 27,
#          u'postgresql-programming': 1,
#          u'ppc-advertising': 3,
#          u'predictive-analytics': 96,
#          u'presentation-design': 3,
#          u'presentations': 4,
#          u'prezi-presentations': 1,
#          u'process-improvement': 1,
#          u'processing': 1,
#          u'product-development': 2,
#          u'product-management': 4,
#          u'program-management': 2,
#          u'project-management': 26,
#          u'project-management-professional': 4,
#          u'project-planning': 4,
#          u'project-scheduling': 1,
#          u'prolog': 4,
#          u'proofreading': 3,
#          u'psd-to-html': 1,
#          u'public-relations': 1,
#          u'public-speaking': 3,
#          u'python': 714,
#          u'python-numpy': 166,
#          u'python-scipy': 152,
#          u'qa-engineering': 1,
#          u'qgis': 4,
#          u'qliktech-qlikview': 12,
#          u'qt': 2,
#          u'qualitative-research': 6,
#          u'quantitative-analysis': 66,
#          u'quarkxpress': 1,
#          u'r': 758,
#          u'r-hadoop': 10,
#          u'rapid-miner': 7,
#          u'raspberry-pi': 1,
#          u'rational-rose': 1,
#          u'react-js': 2,
#          u'real-time-stream-processing': 1,
#          u'recommender-systems': 18,
#          u'recruiting': 1,
#          u'redis': 9,
#          u'regex': 1,
#          u'regression-testing': 25,
#          u'regular-expressions': 1,
#          u'relational-databases': 6,
#          u'remote-sensing': 2,
#          u'report-writing': 10,
#          u'requirements-analysis': 2,
#          u'research': 17,
#          u'research-papers': 13,
#          u'responsive-web-design': 1,
#          u'rest': 3,
#          u'resume-writing': 4,
#          u'retail-ops-management': 1,
#          u'risk-management': 12,
#          u'robotics': 5,
#          u'ruby': 16,
#          u'ruby-on-rails': 25,
#          u'rup': 1,
#          u'russian': 1,
#          u'saas': 2,
#          u'sales': 4,
#          u'sales-management': 1,
#          u'salesforce.com': 3,
#          u'sap': 3,
#          u'sap-abap': 1,
#          u'sap-business-objects': 5,
#          u'sap-mm': 1,
#          u'sas': 131,
#          u'scala': 31,
#          u'scientific-computation': 11,
#          u'scientific-research': 21,
#          u'scientific-writing': 20,
#          u'scrapy-framework': 7,
#          u'screenwriting': 1,
#          u'scripting': 7,
#          u'security': 3,
#          u'security-analysis': 1,
#          u'selenium': 2,
#          u'selenium-webdriver': 1,
#          u'sem': 2,
#          u'sentiment-analysis': 10,
#          u'seo': 9,
#          u'seo-audit': 1,
#          u'seo-keyword-research': 1,
#          u'service-cloud-development': 1,
#          u'short-story-writing': 1,
#          u'simulink': 4,
#          u'six-sigma': 8,
#          u'snmp': 1,
#          u'social-bookmarking': 1,
#          u'social-media-management': 2,
#          u'social-media-marketing': 5,
#          u'social-networking-development': 1,
#          u'software-qa-testing': 1,
#          u'software-testing': 3,
#          u'solidworks': 4,
#          u'spanish': 4,
#          u'sparx-systems-enterprise-architect': 1,
#          u'splunk': 4,
#          u'spreadsheets': 2,
#          u'spring-framework': 11,
#          u'sql': 292,
#          u'sql-azure': 1,
#          u'sql-programming': 27,
#          u'sqlite': 5,
#          u'sqoop': 1,
#          u'ssis': 10,
#          u'startup-consulting': 6,
#          u'stata': 36,
#          u'statistical-computing': 73,
#          u'statistics': 370,
#          u'statpoint-statgraphics': 1,
#          u'stock-management': 1,
#          u'strategic-planning': 10,
#          u'structural-analysis': 1,
#          u'subversion': 1,
#          u'supervised-learning': 3,
#          u'supply-chain-management': 2,
#          u'survey-design': 12,
#          u'survey-monkey': 1,
#          u'sustainable-energy': 1,
#          u'swift': 5,
#          u'sybase-programming': 1,
#          u'symfony': 2,
#          u'system-administration': 3,
#          u'system-analysis': 4,
#          u'systems-development': 2,
#          u't-sql': 13,
#          u'tableau': 106,
#          u'talend-open-studio': 2,
#          u'tax-preparation': 1,
#          u'teaching-algebra': 2,
#          u'teaching-english': 1,
#          u'teaching-mathematics': 28,
#          u'teaching-physics': 8,
#          u'technical-analysis': 4,
#          u'technical-documentation': 3,
#          u'technical-editing': 5,
#          u'technical-recruiter': 1,
#          u'technical-support': 1,
#          u'technical-translation': 2,
#          u'technical-writing': 22,
#          u'telecommunications-engineering': 1,
#          u'test-driven-development': 2,
#          u'textpattern': 6,
#          u'tfs': 1,
#          u'transcription': 6,
#          u'translation': 7,
#          u'translation-brazilian-portuguese-english': 1,
#          u'translation-chinese-english': 3,
#          u'translation-english-arabic': 1,
#          u'translation-english-bengali': 1,
#          u'translation-english-brazilian-portuguese': 2,
#          u'translation-english-chinese': 2,
#          u'translation-english-filipino': 1,
#          u'translation-english-french': 5,
#          u'translation-english-german': 1,
#          u'translation-english-hindi': 1,
#          u'translation-english-japanese': 1,
#          u'translation-english-korean': 1,
#          u'translation-english-portuguese': 2,
#          u'translation-english-russian': 1,
#          u'translation-english-spanish': 5,
#          u'translation-filipino-english': 1,
#          u'translation-french-english': 4,
#          u'translation-hindi-english': 1,
#          u'translation-japanese-english': 1,
#          u'translation-korean-english': 1,
#          u'translation-portuguese-english': 1,
#          u'translation-russian-english': 1,
#          u'translation-spanish-english': 5,
#          u'travel-planning': 1,
#          u'travel-writing': 2,
#          u'turkish': 1,
#          u'twitter-api': 4,
#          u'twitter-bootstrap': 7,
#          u'twitter-marketing': 1,
#          u'typing': 5,
#          u'ubuntu': 4,
#          u'ui-design': 3,
#          u'ukrainian': 1,
#          u'uml': 1,
#          u'unix': 10,
#          u'unix-shell': 15,
#          u'urban-design': 1,
#          u'usability-testing': 1,
#          u'user-experience-design': 3,
#          u'vb.net': 4,
#          u'vba': 20,
#          u'venture-capital-consulting': 1,
#          u'verilog': 1,
#          u'version-control': 1,
#          u'vertica': 3,
#          u'vhdl': 1,
#          u'video-editing': 1,
#          u'video-streaming': 1,
#          u'video-upload': 1,
#          u'vim': 1,
#          u'virtual-assistant': 1,
#          u'virtual-machine': 1,
#          u'visual-arts': 1,
#          u'visual-basic': 2,
#          u'visualization': 16,
#          u'vlookup-tables': 2,
#          u'vmware-administration': 1,
#          u'vmware-esx': 1,
#          u'wcf': 1,
#          u'web-analytics': 8,
#          u'web-crawler': 13,
#          u'web-design': 9,
#          u'web-programming': 9,
#          u'web-scraping': 50,
#          u'web-services': 1,
#          u'web-services-development': 3,
#          u'webgl': 1,
#          u'website-analytics': 9,
#          u'website-development': 11,
#          u'website-prototyping': 2,
#          u'website-wireframing': 1,
#          u'weka': 19,
#          u'white-paper-writing': 1,
#          u'windows-7-administration': 2,
#          u'windows-8-administration': 2,
#          u'windows-app-development': 2,
#          u'windows-azure': 3,
#          u'windows-forms-development': 1,
#          u'windows-mobile': 1,
#          u'windows-xp-administration': 1,
#          u'wire-framing': 1,
#          u'wireless-network-implementation': 1,
#          u'word-processing': 2,
#          u'wordpress': 16,
#          u'wpf': 1,
#          u'writing': 11,
#          u'xlinesoft-phprunner': 1,
#          u'xml': 6,
#          u'xml-web-services': 1,
#          u'xslt': 2,
#          u'yahoo-search-marketing': 1,
#          u'yii-framework': 2,
#          u'youtube-api': 1,
#          u'youtube-marketing': 1,
#          u'zend-framework': 1})

# %%
ds_popular_skills = sorted(ds_skill_words, key = ds_skill_words.get, reverse = True)
print ds_popular_skills[:25]
# Out:
# [u'r', u'python', u'machine-learning', u'data-science', u'data-analysis', u'data-mining', u'statistics', u'sql', u'microsoft-excel', u'java', u'matlab', u'python-numpy', u'data-visualization', u'python-scipy', u'sas', u'data-modeling', u'hadoop', u'tableau', u'apache-spark', u'javascript', u'predictive-analytics', u'ibm-spss', u'excel-vba', u'big-data', u'c++']

# %%
for skill_tuple in ds_skill_words.most_common(30):
    print skill_tuple
# Out:
# (u'r', 758)
# (u'python', 714)
# (u'machine-learning', 531)
# (u'data-science', 488)
# (u'data-analysis', 420)
# (u'data-mining', 378)
# (u'statistics', 370)
# (u'sql', 292)
# (u'microsoft-excel', 248)
# (u'java', 201)
# (u'matlab', 194)
# (u'python-numpy', 166)
# (u'data-visualization', 161)
# (u'python-scipy', 152)
# (u'sas', 131)
# (u'data-modeling', 114)
# (u'hadoop', 108)
# (u'tableau', 106)
# (u'apache-spark', 106)
# (u'javascript', 106)
# (u'predictive-analytics', 96)
# (u'ibm-spss', 94)
# (u'excel-vba', 91)
# (u'big-data', 89)
# (u'c++', 80)
# (u'mysql', 76)
# (u'data-scraping', 75)
# (u'statistical-computing', 73)
# (u'analytics', 70)
# (u'c', 68)

# %% [markdown]
# ## Data Engineer

# %%
de_profiles = json_read('../data/skills_id/data_engineer.txt')
de_profiles['title'].value_counts()
# Out:
# Software Engineer                                                         2007
# Engineer                                                                   737
# Senior Software Engineer                                                   364
# Computer Engineer                                                          341
# Mechanical Engineer                                                        328
# Electrical Engineer                                                        301
# Network Engineer                                                           248
# Civil Engineer                                                             215
# software engineer                                                          199
# QA Engineer                                                                195
# Software engineer                                                          166
# System Engineer                                                            154
# Software Developer                                                         144
# Industrial Engineer                                                        135
# Systems Engineer                                                           133
# Software Test Engineer                                                     124
# Data Entry Professional                                                    122
# Electronics Engineer                                                       119
# engineer                                                                   113
# IT Engineer                                                                113
# Web Developer                                                               87
# Data Entry                                                                  75
# Chemical Engineer                                                           73
# Test Engineer                                                               73
# Design Engineer                                                             72
# Technical Support Engineer                                                  68
# computer engineer                                                           66
# Data Engineer                                                               62
# Software Quality Assurance Engineer                                         61
# Mechanical Design Engineer                                                  57
#                                                                           ...
# Teacher/ Instructor/Engineer                                                 1
# oracle developer                                                             1
# LabVIEW Software Engineer                                                    1
# iPhone-iPad & Backend Expert                                                 1
# Chinese-English Translator (all areas) and Technical blogger                 1
# Experienced Project Coordinator                                              1
# Software Engineer / Software Quality Assurance Engineer                      1
# Expert in CAD Design and 3D Printing                                         1
# Data Encoder / Sales Engineer                                                1
# Experienced in Hadoop, ElasticSearch, Java, Grails and Web Development       1
# ISTQB Certified Test Engineer with 8+ plus years of experience in QA         1
# Versatile, US educated                                                       1
# Freelance Data Encoder, Web Researcher, Blogger, Technical Support           1
# Independent Consultant                                                       1
# Mechanical Engineering Design and Consultancy proffessional                  1
# System and network administrator ( microsoft windows )                       1
# Software Engineer Web: Node/Express and C++/Compilers/yacc                   1
# Java/GWT/Javascript Developer                                                1
# Desktop support Engineer with 3 yrs experience in troubleshooting.           1
# Appointment setter/ Virtual Assistant/ WEB Researcher/ Civil Engineer        1
# Technical Support Engineer/Electronics Engineer                              1
# Front End Developer / Javascript Engineer                                    1
# Web Tester                                                                   1
# iOS/Android Developer                                                        1
# Certified - Web Programming, Data Mining , Cloud and System Engineer.        1
# Construction Engineer/ Draughtsperson                                        1
# Expert in  Graphic Designing/CCNA/RF/Content Writing                         1
# Product Designer and Manufacturing Expert                                    1
# Senior C++/C# Developer                                                      1
# Senior PHP, Yii Expert, Laravel, CI, Prestashop, Wordpress,...               1
# Name: title, dtype: int64

# %%
def data_engineer_in(str):
    # Some people may not have titles in which case their titles are NaNs
    if isinstance(str, float):
        return False
    if 'data' in str.lower() and 'engineer' in str.lower() and 'entry' not in str.lower():
        return True
    else: return False

# %%
vect_dei = np.vectorize(data_engineer_in)
de_profiles['de_flag'] = vect_dei(np.array(de_profiles[u'title']))
print de_profiles[de_profiles['de_flag'] == True][u'title'].value_counts()
print de_profiles[de_profiles['de_flag'] == True][u'skills'][0]
# Out:
# Data Engineer                                                             62
# Big Data Engineer                                                         20
# Database Engineer                                                         11
# Data engineer                                                              7
# Big data engineer                                                          6
# Senior Data Engineer                                                       5
# Data Visualization Engineer                                                4
# Data Science Engineer                                                      4
# Python data engineer                                                       4
# Data Network Engineer                                                      3
# Big Data Software Engineer                                                 3
# Data Scientist/Engineer                                                    3
# Engineer in statistics and data analysis                                   3
# Software Engineer/Data Analyst                                             3
# Engineer and Data Analyst                                                  3
# Data Warehouse Engineer                                                    3
# Software Engineer / Data Scientist                                         3
# Software Engineer & Data Scientist                                         3
# Software Engineer and Data Analyst                                         3
# Database engineer                                                          3
# Software Engineer and Data Scientist                                       2
# Value Engineer with Data Analysis experience                               2
# Big Data engineer                                                          2
# Telecom Engineer with linux and database skills                            2
# Software Engineer / Data Engineer                                          2
# Lead Data Engineer                                                         2
# Software Engineer/Data Scientist                                           2
# Computer Engineer, Corporate Secretary, Data Encoder, Analyst              2
# Senior Software Engineer (Databases)                                       2
# Professional Hardware Engineer/System Administrator/Data Analyst/CRM       2
#                                                                           ..
# Software Test Engineer(Mannual & Database Testing)                         1
# Electrical Engineer, Data Analyst and Startup Consultant                   1
# Researcher, Industrial Engineer, Data Visualizer, Logistics                1
# Aerospace Engineer and Data Analyst                                        1
# BIG Data Software Engineer                                                 1
# PhD computational physicist | Data scientist | Software engineer           1
# Sr Data Center Engineer                                                    1
# (Almost) Mechanical Engineer with a passion for Data Visualization         1
# Electronic engineer - Telecomunication, Data analyst                       1
# Experienced manufacturing engineer with metrology and data analysis.       1
# Data Encoder/Typist/Admin Assistant/Chemical Engineer                      1
# Big Data Engineer & Scientist                                              1
# Data Analyst|Software Engineer                                             1
# IT Technician, UPS Support Engineer, Software Tester, Data Analyst         1
# Comercially minded Data Scientist/Machine Learning Engineer                1
# L1 Engineer | Tester | Customer Support | Data Management                  1
# Software Testing Engineer/ Professinal Data enry specialist                1
# Database Engineer, SQL performance optimizer                               1
# Test Engineer with 3.5 yrs of Exp. in Manual,Functional, Database, ETL     1
# Industrial Engineer experienced in Microsoft Excel and Data Analysis       1
# Data annd search engineer                                                  1
# Artificial Intelligence Engineer/Data Scientist                            1
# Developer/Programmer/Software Engineer/Data Analyst/Business/Finance/A     1
# Test Engineer experience in testing of web based,database applications     1
# Data And Information Processing Engineer                                   1
# Cloud Computing and Big Data Analytics Engineer                            1
# Datacom/Netwrok Engineer                                                   1
# Data Center System Engineer Linux Expert, AWS Expert (RHCE,RHCSS)          1
# Senior software engineer/Website Developer/Data Scientist                  1
# VA, Data Researcher, Customer Service, Engineer                            1
# Name: title, dtype: int64
# [u'data-encoding', u'internet-research', u'microsoft-word', u'audacity', u'video-conversion', u'audio-editing', u'microsoft-visio', u'c#', u'java']

# %%
skills_of_de = de_profiles[de_profiles['de_flag'] == True][u'skills']
de_skill_words = Counter()
for index, skill_set in enumerate(skills_of_de):
    if isinstance(skill_set, float):
        pass
    else: de_skill_words += Counter(skill_set)
# Out:
# 1
# 5
# 10
# 23
# 29
# 61
# 65
# 72
# 73
# 80
# 81
# 85
# 88
# 93
# 96
# 97
# 99
# 102
# 105
# 108
# 121
# 122
# 125
# 149
# 169
# 172
# 175
# 178
# 185
# 187
# 197
# 203
# 206
# 207
# 208
# 209
# 211
# 212
# 213
# 215
# 217
# 226
# 228
# 232
# 237
# 240
# 241
# 243
# 245
# 249
# 252
# 258
# 280
# 282
# 283
# 287
# 294
# 313
# 314
# 316
# 322
# 325
# 333
# 337
# 342
# 345
# 361
# 364
# 369
# 374
# 377
# 380
# 386
# 396
# 398
# 408
# 414
# 417
# 420
# 430
# 435
# 437
# 444
# 445
# 446
# 451
# 454
# 456
# 460
# 461
# 462
# 469
# 470
# 477
# 480
# 488
# 490
# 492
# 493
# 497
# 512
# 513
# 524
# 526
# 531
# 537
# 539
# 542
# 551
# 568
# 571
# 584
# 587
# 594
# 596
# 598
# 606
# 609
# 611
# 612
# 613
# 614
# 621
# 626
# 631
# 633
# 636
# 639
# 644
# 647
# 649
# 659
# 661
# 662
# 667
# 670
# 679
# 680
# 681
# 685
# 687
# 690
# 694
# 709
# 720
# 721
# 722
# 725
# 726
# 728
# 731
# 737
# 740
# 748
# 753
# 754
# 755
# 757
# 760
# 763
# 780
# 789
# 790
# 791
# 794
# 795
# 797
# 799
# 800
# 802
# 804
# 805
# 812
# 813
# 815
# 816
# 822
# 829
# 832
# 835
# 837
# 839
# 843
# 846
# 847
# 848
# 853
# 855
# 860
# 862
# 863
# 864
# 867
# 872
# 874
# 877
# 883
# 885
# 886
# 887
# 896
# 908
# 913
# 923
# 932
# 933
# 934
# 964
# 969
# 972
# 976
# 991
# 995
# 998
# 1002
# 1003

# %%
for skill_tuple in de_skill_words.most_common(20):
    print skill_tuple
# Out:
# (u'python', 205)
# (u'java', 163)
# (u'sql', 152)
# (u'microsoft-excel', 140)
# (u'data-analysis', 121)
# (u'hadoop', 111)
# (u'data-entry', 103)
# (u'machine-learning', 100)
# (u'r', 100)
# (u'data-mining', 88)
# (u'mysql', 74)
# (u'data-science', 70)
# (u'microsoft-word', 69)
# (u'javascript', 66)
# (u'apache-spark', 64)
# (u'php', 60)
# (u'c#', 58)
# (u'apache-hive', 52)
# (u'matlab', 49)
# (u'microsoft-powerpoint', 48)
# (u'mongodb', 48)
# (u'c', 45)
# (u'etl', 43)
# (u'big-data', 39)
# (u'excel-vba', 38)
# (u'internet-research', 38)
# (u'database-design', 38)
# (u'data-engineering', 38)
# (u'data-warehousing', 37)
# (u'c++', 37)

# %% [markdown]
# ## Big Data

# %%
bd_profiles = json_read('../data/skills_id/big_data.txt')
bd_profiles['title'].value_counts()
# Out:
# Software Engineer                                                        143
# Data Scientist                                                           132
# Data Entry Professional                                                  107
# Software Developer                                                        91
# Virtual Assistant                                                         84
# Web Developer                                                             83
# Data Analyst                                                              59
# Senior Software Engineer                                                  55
# Data Entry                                                                38
# Data Entry Specialist                                                     37
# Graphic Designer                                                          34
# Java Developer                                                            33
# Web developer                                                             30
# Project Manager                                                           30
# Business Analyst                                                          28
# Android Developer                                                         27
# Consultant                                                                26
# Senior Java Developer                                                     26
# Freelancer                                                                25
# Senior Web Developer                                                      22
# Developer                                                                 22
# Administrative Assistant                                                  22
# Experienced Customer Service Representative                               21
# Big Data Engineer                                                         20
# Certified Public Accountant                                               20
# Full Stack Developer                                                      19
# Mobile Developer                                                          17
# Writer                                                                    17
# Hadoop Developer                                                          16
# Customer Service Representative                                           15
#                                                                         ...
# Linux System Engineer                                                      1
# Programs and Project Director with Full SDLC experience                    1
# Senior Java developer, 10+ years experience                                1
# Raiser's Edge | Windows Applications | SQL Server                          1
# Sr.IOS Developer / Team Leader / Project Manager                           1
# Chief Software Architect and Developer                                     1
# Citation Specialist | Google Places | Local Seo Expert.                    1
# Bachelor of Science in Information and Communication Technology            1
# Broadcast Journalism Student                                               1
# An article writer                                                          1
# Professional Expertise in all types of Writing                             1
# Sr. IT Consultant                                                          1
# Certified Transcriptionist/Proofreading Specialist/Data Entry              1
# Data Entry Specialist, Virtual Assistance, Admin, Translator               1
# Senior Architect                                                           1
# Developer C#                                                               1
# Senior Data Analyst/Bioinformatician                                       1
# Performance Optimization Expert                                            1
# Writer, Business Owner, Consultant                                         1
# Expert Front End Web Designer | PHP | MYSQL | Many More                    1
# Moodle LMS consultant, eLearning designer & UX Expert                      1
# Expert in Finance/Accounts/Business                                        1
# Data Entry, Internet research, Transcription,                              1
# Data Analyst, MSCS, Stockholm University                                   1
# Expert Database DataWarehouse Developer                                    1
# PHP, WORDPRESS , MYSQL, JavaScript, JQuery, AJAX, HTML, CSS Expert         1
# (intern) supply chain analyst & data scientists                            1
# Search Engine Optimization,Social Media Marketing,Back link expert         1
# Solidworks l Inventor l AutoCAD l NX l CATIA l Creo - Design Engineer      1
# Content writer and Subject expert                                          1
# Name: title, dtype: int64

# %%
def big_data_in(str):
    # Some people may not have titles, in which case their titles are NaNs
    if isinstance(str, float):
        return False
    if 'big' in str.lower() and 'data' in str.lower():
        return True
    else: return False

# %%
vect_bdi = np.vectorize(big_data_in)
bd_profiles['bd_flag'] = vect_bdi(np.array(bd_profiles[u'title']))
print bd_profiles[bd_profiles['bd_flag'] == True][u'title'].value_counts()
print bd_profiles[bd_profiles['bd_flag'] == True][u'skills'][0]
# Out:
# Big Data Engineer                                                         20
# Big Data Developer                                                        15
# Big Data Consultant                                                        9
# Big Data Expert                                                            7
# Big Data Architect                                                         6
# Big data engineer                                                          6
# Big Data Analyst                                                           5
# Java/Big Data Developer                                                    5
# Big Data Analytics                                                         4
# Bigdata Developer                                                          3
# Big Data Professional                                                      3
# Big Data developer                                                         3
# Big Data Software Engineer                                                 3
# Big data Developer                                                         3
# Web apps, Mobile Apps, NLP, AI, BigData, SalesForce, iBeacon and BLE       2
# Big Data expert                                                            2
# big data consultant                                                        2
# Big Data Software Developer                                                2
# Big data Analyst                                                           2
# BigData, Hadoop, NLP (Natural Language Processing), RTB (Programmatic)     2
# Python/Django expert with big data and GIS apps projects experience        2
# Big Data Specialist                                                        2
# Expert freelancer with BigData Technology like Hadoop, Spark Eco Syste     2
# Big Data Scientist                                                         2
# Finance Consultant / Big Data Analyst                                      2
# Big Data engineer                                                          2
# Hadoop / Big Data / Pig / Hive / etc, Java / Python developer              2
# Big Data/Hadoop Developer                                                  2
# C, Java, OpenGL, 3d, HPC, Modeling, BigData, SaaS                          2
# Python/BigData/Database Software Developer                                 1
#                                                                           ..
# ex-google. interests - cloud (aws), big-data, java/j2ee                    1
# Expert Python Financial/Statistics/Big Data Developer                      1
# Project Manager, skills with infraestructure DBA and Big Data              1
# Expert in C/C++ programming, Machine Learning/ Big Data aspirant           1
# More than 7 Years Experience in DWBI/Big Data tools                        1
# Software Engineer / Big Data Scientist                                     1
# Java, Big Data Analytics, Tester, IT Auditor, Project Manager              1
# Full Stack Developer - Web Frameworks, Big Data, Databases                 1
# Big data analytics expert                                                  1
# Big data and SPARK developer with experience in Data mining                1
# Hadoop/Cassandra/HTML5/Jquery/J2EE/Big Data/PlSQL Professional             1
# PhD scholar - Finance, Big data analytics expert                           1
# big Data Specialist                                                        1
# Java/J2EE, PHP, Hadoop, Bigdata & Android developer                        1
# Big Data/Hadoop Developer, Free lancer                                     1
# Big Data Developer with 3.5 Years of Experience                            1
# Data Scientist - Big Data Consultant - Scrum Master                        1
# Big Data Consulting Services                                               1
# Web Developer with a Big Data and Cloud Bent                               1
# Big Data Expert, AngularJS, NoSQL, NodeJS, AWS, MEAN                       1
# Experienced Java / Big Data Architect, Project Manager                     1
# Big data professional                                                      1
# Java Architect, 10+ years in web design, Ajax, big data, j2ee tech         1
# Data Science, Big Data, Quantitative Analysis                              1
# NetClick has a sharp focus on providing Big Data Analytics Solutions       1
# Expert Big Data/Backend Architect                                          1
# Big Data Analyst, C++ Programmer, Maths Tutor, SPSS Expert, PDF Expert     1
# Data-Warehouse/Big Data Consultant                                         1
# Expert XML XSLT XQuery Marklogic Big Data Professional                     1
# Curiosity driven Big Data and Tech Enthusiast                              1
# Name: title, dtype: int64
# [u'devops', u'linux-system-administration', u'openstack', u'big-data', u'machine-learning']

# %%
skills_of_bd = bd_profiles[bd_profiles['bd_flag'] == True][u'skills']
bd_skill_words = Counter()
for index, skill_set in enumerate(skills_of_bd):
    if isinstance(skill_set, float):
        pass
    else: bd_skill_words += Counter(skill_set)

# %%
for skill_tuple in bd_skill_words.most_common(20):
    print skill_tuple
# Out:
# (u'hadoop', 331)
# (u'java', 252)
# (u'apache-hive', 163)
# (u'big-data', 159)
# (u'python', 154)
# (u'apache-spark', 154)
# (u'mongodb', 93)
# (u'sql', 92)
# (u'hbase', 87)
# (u'mysql', 73)
# (u'r', 67)
# (u'javascript', 65)
# (u'scala', 65)
# (u'data-analysis', 64)
# (u'pig', 63)
# (u'machine-learning', 60)
# (u'php', 56)
# (u'cassandra', 55)
# (u'mapreduce', 54)
# (u'spring-framework', 54)

# %% [markdown]
# ## Full Stack

# %%
fs_profiles = json_read('../data/skills_id/full_stack.txt')
fs_profiles['title'].value_counts()
# Out:
# Full Stack Web Developer                                              835
# Full Stack Developer                                                  790
# Web Developer                                                         525
# Software Engineer                                                     285
# Full stack web developer                                              198
# Software Developer                                                    196
# Full-Stack Web Developer                                              151
# Full stack developer                                                  148
# Web developer                                                         130
# Full-Stack Developer                                                  117
# Ruby on Rails Developer                                                89
# Senior Software Engineer                                               87
# Full-stack web developer                                               79
# Senior Web Developer                                                   79
# Full-stack Web Developer                                               75
# Full-stack developer                                                   72
# Full Stack Software Engineer                                           68
# Full Stack Software Developer                                          54
# Developer                                                              49
# Full Stack Ruby on Rails Developer                                     46
# Full Stack Engineer                                                    45
# Ruby on Rails Programmer                                               42
# Senior Software Developer                                              42
# Senior Full Stack Developer                                            41
# Ruby on Rails developer                                                40
# Full-stack Developer                                                   38
# Web Application Developer                                              36
# Full Stack developer                                                   34
# Software developer                                                     33
# Mobile Developer                                                       32
#                                                                      ...
# German Software Architect                                               1
# Android Developer | Full-Stack Mobile Apps Developer                    1
# Web and Mobile developer                                                1
# PHP Developer with expertise in Mobile Apps API                         1
# Equity Research Analyst (Duke University)                               1
# Graphic, Web, UX Designer                                               1
# Developer / Product Owner                                               1
# Full stack Developer and Architect                                      1
# PHP, Node.js, AngularJS and Ionic guru                                  1
# ASP.NET,C#,MVC,Web API,JQuery,SQL Server,EntityFramework                1
# Full Stack Rails/Django Senior Developer                                1
# Web Developer (Front-End)                                               1
# Full stack web programmer                                               1
# Python/django coder                                                     1
# Digital Marketing, Social Media, Web & Mobile Apps                      1
# Senior Web Developer (LAMP, Full-stack)                                 1
# Expert Graphic & Web Designer,  Front-End Developer, & Typographer      1
# Full Stack .Net Software Developer                                      1
# Software Developer & Co-Founder of Software Development House           1
# A Beautiful Web                                                         1
# Web designer & developer                                                1
# fullstack laravel web developer                                         1
# Expert Laravel Developer                                                1
# Senior Frontend Developer Lead , UX Designer , Full Stack Dev           1
# Web & Systems Developer                                                 1
# Full stack developer (Python backend/JS/HTML5/CSS3)                     1
# Graphics And Web Designer, Full Stack Developer                         1
# Full stack mobile(Objecive-c/Swift, Java) and Backend developer         1
# Professional Software Developer - ASP.NET MVC                           1
# Web / Mobile Developer / Full Stack                                     1
# Name: title, dtype: int64

# %%
def full_stack_in(str):
    # Some people may not have titles, in which case their titles are NaNs
    if isinstance(str, float):
        return False
    if 'full' in str.lower() and 'stack' in str.lower():
        return True
    else: return False

# %%
vect_fsi = np.vectorize(full_stack_in)
fs_profiles['fs_flag'] = vect_fsi(np.array(fs_profiles[u'title']))
print fs_profiles[fs_profiles['fs_flag'] == True][u'title'].value_counts()
print fs_profiles[fs_profiles['fs_flag'] == True][u'skills'][0]
# Out:
# Full Stack Web Developer                                                 835
# Full Stack Developer                                                     790
# Full stack web developer                                                 198
# Full-Stack Web Developer                                                 151
# Full stack developer                                                     148
# Full-Stack Developer                                                     117
# Full-stack web developer                                                  79
# Full-stack Web Developer                                                  75
# Full-stack developer                                                      72
# Full Stack Software Engineer                                              68
# Full Stack Software Developer                                             54
# Full Stack Ruby on Rails Developer                                        46
# Full Stack Engineer                                                       45
# Senior Full Stack Developer                                               41
# Full-stack Developer                                                      38
# Full Stack developer                                                      34
# Senior Full Stack Web Developer                                           27
# Full-Stack Ruby on Rails Developer                                        26
# Full Stack Javascript Developer                                           25
# Full Stack Mobile Developer                                               24
# Full Stack PHP Developer                                                  23
# full stack web developer                                                  19
# Full Stack web developer                                                  18
# Full stack Ruby on Rails developer                                        18
# Full stack Developer                                                      18
# Full Stack .NET Developer                                                 17
# full stack developer                                                      17
# Full-Stack Software Developer                                             16
# Full Stack JavaScript Developer                                           16
# Full stack Web Developer                                                  16
#                                                                         ...
# Full Stack Developer & Desktop Developer                                   1
# Full Stack Web Developer | Business Development                            1
# Full Stack iOS/Android/Back-end Developer                                  1
# Certified Magento & Wordpress & Full Stack Web Developer                   1
# Full Stack Mobile App (iOS & Android&Hybrid) Developer                     1
# Software Engineer Full Stack Web Development                               1
# Full Stack .Net/MEAN Software Developer                                    1
# Full Stack Developer(Python/Django and Angularjs)                          1
# Full-stack/Python web developer                                            1
# Full-stack Web Developer (Node.js, MEAN, LAMP, ElasticSearch)              1
# Expert Web Developer (Full stack, Mean Stack)                              1
# Full Stack Developer, Embedded Linux, DevOps                               1
# Full Stack Web Developer / Symfony 2 Senior Developer                      1
# FullStack Engr Frontend Backend Responsive Mobile App Games, WP E-Com      1
# Entrepreneur / Full Stack Marketer / Coach                                 1
# CEO & Full-Stack Web Developer.                                            1
# Full-Stack Developer (Ruby On Rails)                                       1
# HTML, CSS, full-stack JavaScript developer                                 1
# I'm Full-Stack Web Developer and iOS/Android Developer                     1
# Full stack developer / Laravel / BI  / PIWIK heat map                      1
# Expert Full Stack Web Developer (Laravel, Yii)                             1
# Full Stack Developer - Objective-C/Java/Android/Python/Javascript          1
# Full Stack -- iOS, Android, PHP, JavaScript, MySQL, Backend, UX, PM        1
# Senior full stack iOS/Android/Xamarin/Hybrid mobile app developer          1
# Full Stack Developer | Software Engineer                                   1
# Full-Stack iOS, Swift, WatchKit, Android Expert,Objective C                1
# Experienced Full Stack E-commerce Developer                                1
# Full Stack Web development                                                 1
# Full Stack Mobile App Developer(iOS, Android, Ionic).                      1
# Web / Mobile Developer / Full Stack                                        1
# Name: title, dtype: int64
# [u'risk-management', u'management-consulting', u'scrum', u'project-management', u'communications', u'art-direction', u'concept-design', u'animation', u'level-design', u'hw-prototyping']

# %%
skills_of_fs = fs_profiles[fs_profiles['fs_flag'] == True][u'skills']
fs_skill_words = Counter()
for index, skill_set in enumerate(skills_of_fs):
    if isinstance(skill_set, float):
        pass
    else: fs_skill_words += Counter(skill_set)

# %%
for skill_tuple in fs_skill_words.most_common(20):
    print skill_tuple
# Out:
# (u'javascript', 5124)
# (u'php', 3824)
# (u'html5', 3173)
# (u'jquery', 2942)
# (u'angularjs', 2760)
# (u'css3', 2383)
# (u'node.js', 2306)
# (u'mysql', 2275)
# (u'css', 1723)
# (u'wordpress', 1670)
# (u'html', 1465)
# (u'ruby-on-rails', 1426)
# (u'java', 1423)
# (u'python', 1408)
# (u'mongodb', 1222)
# (u'twitter-bootstrap', 889)
# (u'laravel-framework', 854)
# (u'ruby', 788)
# (u'sql', 776)
# (u'c#', 753)
