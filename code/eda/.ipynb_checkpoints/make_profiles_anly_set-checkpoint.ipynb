# %%
import json
import pandas as pd
import numpy as np
from pymongo import MongoClient
from collections import Counter
import xgboost
# %matplotlib inline

# %% [markdown]
# Get freelancer profile by key
#
# Endpoint
# GET /api/profiles/v1/providers/{profile_key}.{format}

# %%
def json_prep(in_file):
    # read the entire file into a python array
    with open(in_file, 'rb') as f:
        data = f.readlines()

    # remove the trailing "\n" from each line
    data = map(lambda x: x.rstrip(), data)

    # each element of 'data' is an individual JSON object.
    # i want to convert it into an *array* of JSON objects
    # which, in and of itself, is one large JSON object
    # basically... add square brackets to the beginning
    # and end, and have all the individual business JSON objects
    # separated by a comma
    data_json_str = "[" + ','.join(data) + "]"

    data_list_of_dicts = json.loads(data_json_str)
    
    out_df = pd.read_json(data_json_str)
    return out_df

# %% [markdown]
# ## Make lists of dicts out of JSON data

# %%
as_profiles_df = json_prep('../../data/detailed_profiles_da_0_8715.txt')

# %%
as_profiles_df.T.head(48)
# Out:
#                                                                         0     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                {u'hr': u'', u'fp': {u'job': {u'as_to': u'01/2...
# ciphertext                                               ~01cae3810dc6d2bbbc
# dev_ac_agencies
# dev_adj_score                                                           4.35
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                             15
# dev_billed_assignments                                                     1
# dev_blurb                  Over the more than 6 years, I have developed a...
# dev_city                                                           New Delhi
# dev_country                                                            India
# dev_eng_skill                                                              4
# dev_first_name                                                       Sandeep
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Other -...
# dev_last_activity                                            August 31, 2013
# dev_last_name
# dev_last_worked                                              January 9, 2013
# dev_last_worked_ts                                             1357689600000
# dev_portfolio_items_count                                                  2
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                      LAMP developer with more than 6 years
# dev_recno                                                            2505125
# dev_recno_ciphertext                                     ~01cae3810dc6d2bbbc
# dev_short_name                                                    Sandeep K.
# dev_timezone                   UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# dev_tot_feedback                                                           1
# dev_total_hours                                                            0
# dev_ui_profile_access                                                 Public
# education                  {u'institution': {u'ed_to': u'07/2007', u'ed_a...
# experiences
# job_categories             {u'job_category': [{u'first_level': u'Web Deve...
# permalink
# portfolio_items            {u'portfolio_item': [{u'pi_large_thumbnail': u...
# skills                     {u'skill': [{u'skl_name': u'ajax', u'skl_descr...
# tsexams                    {u'tsexam': [{u'ts_percentile': u'65', u'ts_du...
#
#                                                                         1     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                                         {u'hr': u'', u'fp': u''}
# ciphertext                                               ~01d24ced467385214d
# dev_ac_agencies
# dev_adj_score                                                              0
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                             12
# dev_billed_assignments                                                     0
# dev_blurb                  I am a web application developer, having 2 yea...
# dev_city                                                           Bangalore
# dev_country                                                            India
# dev_eng_skill                                                              5
# dev_first_name                                                        Sruthy
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Other -...
# dev_last_activity                                              June 12, 2015
# dev_last_name                                                            M A
# dev_last_worked
# dev_last_worked_ts
# dev_portfolio_items_count                                                  0
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                   Web Developer / Designer
# dev_recno                                                            5790973
# dev_recno_ciphertext                                     ~01d24ced467385214d
# dev_short_name                                                    Sruthy M A
# dev_timezone                   UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# dev_tot_feedback                                                           0
# dev_total_hours                                                            0
# dev_ui_profile_access                                                 Public
# education                  {u'institution': {u'ed_to': u'12/2012', u'ed_a...
# experiences                {u'experience': {u'exp_from': u'07/2012', u'ex...
# job_categories             {u'job_category': [{u'first_level': u'Web Deve...
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'ajax', u'skl_exter...
# tsexams                    {u'tsexam': {u'ts_percentile': u'65', u'ts_dur...
#
#                                                                         2     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                                         {u'hr': u'', u'fp': u''}
# ciphertext                                               ~01953fb4fa2ceb67dc
# dev_ac_agencies
# dev_adj_score                                                              0
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                          44.44
# dev_billed_assignments                                                     0
# dev_blurb                  Extensive expertise in clinical research publi...
# dev_city                                                           Sunnyvale
# dev_country                                                    United States
# dev_eng_skill                                                              5
# dev_first_name                                                     Catherine
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Other -...
# dev_last_activity                                              March 4, 2014
# dev_last_name                                                          Klifa
# dev_last_worked
# dev_last_worked_ts
# dev_portfolio_items_count                                                  0
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title          English/French Writer/Translator,Scientific Di...
# dev_recno                                                            4887770
# dev_recno_ciphertext                                     ~01953fb4fa2ceb67dc
# dev_short_name                                               Catherine Klifa
# dev_timezone               UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# dev_tot_feedback                                                           0
# dev_total_hours                                                            0
# dev_ui_profile_access                                                 Public
# education                  {u'institution': [{u'ed_to': u'12/2002', u'ed_...
# experiences                {u'experience': [{u'exp_from': u'12/2010', u'e...
# job_categories             {u'job_category': [{u'first_level': u'Writing ...
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'article-writing', ...
# tsexams                    {u'tsexam': {u'ts_percentile': u'65', u'ts_whe...
#
#                                                                         3     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                {u'hr': {u'job': [{u'as_total_hours': u'614', ...
# ciphertext                                               ~01a9ab111f973ae055
# dev_ac_agencies
# dev_adj_score                                                              5
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                          24.44
# dev_billed_assignments                                                     3
# dev_blurb                  I'm a WEB-developer with more than 5 years exp...
# dev_city                                                                Kiev
# dev_country                                                          Ukraine
# dev_eng_skill                                                              5
# dev_first_name                                                          Igor
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': {u'name': u'Web Deve...
# dev_last_activity                                              July 24, 2014
# dev_last_name
# dev_last_worked                                                July 24, 2014
# dev_last_worked_ts                                             1406160000000
# dev_portfolio_items_count                                                  6
# dev_portrait
# dev_portrait_100
# dev_portrait_32
# dev_portrait_50
# dev_profile_title          PHP/Zend Framework/MySql/MongoDB/SPHINX/jQuery...
# dev_recno                                                             583782
# dev_recno_ciphertext                                     ~01a9ab111f973ae055
# dev_short_name                                                       Igor V.
# dev_timezone                            UTC+02:00 Athens, Helsinki, Istanbul
# dev_tot_feedback                                                           2
# dev_total_hours                                                      1809.67
# dev_ui_profile_access                                       oDesk Users only
# education
# experiences                {u'experience': {u'exp_from': u'02/2007', u'ex...
# job_categories             {u'job_category': {u'first_level': u'Web Devel...
# permalink
# portfolio_items            {u'portfolio_item': [{u'pi_large_thumbnail': u...
# skills                     {u'skill': [{u'skl_name': u'facebook-api', u's...
# tsexams                    {u'tsexam': [{u'ts_percentile': u'65', u'ts_wh...
#
#                                                                         4     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                {u'hr': u'', u'fp': {u'job': {u'as_to': u'04/2...
# ciphertext                                               ~016dcec1087cba565c
# dev_ac_agencies
# dev_adj_score                                                              5
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                             15
# dev_billed_assignments                                                     6
# dev_blurb                  Specializes in developing Photoshop and After ...
# dev_city                                                             Colombo
# dev_country                                                        Sri Lanka
# dev_eng_skill
# dev_first_name                                                       Chapman
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Other -...
# dev_last_activity                                             April 24, 2016
# dev_last_name
# dev_last_worked                                               April 24, 2016
# dev_last_worked_ts                                             1461456000000
# dev_portfolio_items_count                                                  0
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title          After Effects, Photoshop - Scripting And Plugi...
# dev_recno                                                            9848718
# dev_recno_ciphertext                                     ~016dcec1087cba565c
# dev_short_name                                                    Chapman M.
# dev_timezone                   UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# dev_tot_feedback                                                           4
# dev_total_hours                                                        144.9
# dev_ui_profile_access                                                 Public
# education
# experiences                {u'experience': [{u'exp_from': u'01/2015', u'e...
# job_categories                                                           NaN
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'actionscript-3', u...
# tsexams                    {u'tsexam': [{u'ts_percentile': u'86', u'ts_wh...
#
#                                                                         5     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                {u'hr': {u'job': [{u'as_to': u'09/2011', u'as_...
# ciphertext                                               ~019e83a0dfa04c0e8b
# dev_ac_agencies
# dev_adj_score                                                        4.55713
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                          16.67
# dev_billed_assignments                                                     3
# dev_blurb
# dev_city                                                       Halle (Saale)
# dev_country                                                          Germany
# dev_eng_skill                                                              5
# dev_first_name                                                    Viacheslav
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Web Dev...
# dev_last_activity                                         September 22, 2013
# dev_last_name                                                        Gonchar
# dev_last_worked                                             January 23, 2013
# dev_last_worked_ts                                             1358899200000
# dev_portfolio_items_count                                                  1
# dev_portrait
# dev_portrait_100
# dev_portrait_32
# dev_portrait_50
# dev_profile_title          Development of reliable and flexible software(...
# dev_recno                                                             872801
# dev_recno_ciphertext                                     ~019e83a0dfa04c0e8b
# dev_short_name                                            Viacheslav Gonchar
# dev_timezone               UTC+01:00 Berlin, Stockholm, Rome, Bern, Brussels
# dev_tot_feedback                                                           2
# dev_total_hours                                                      11.1667
# dev_ui_profile_access                                                 Public
# education                  {u'institution': {u'ed_to': u'01/2008', u'ed_a...
# experiences
# job_categories             {u'job_category': [{u'first_level': u'Software...
# permalink
# portfolio_items            {u'portfolio_item': {u'pi_large_thumbnail': u'...
# skills                     {u'skill': [{u'skl_name': u'c++', u'skl_descri...
# tsexams                    {u'tsexam': [{u'ts_percentile': u'65', u'ts_wh...
#
#                                                                         6     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                {u'hr': u'', u'fp': {u'job': [{u'as_total_hour...
# ciphertext                                               ~01863825efc778f975
# dev_ac_agencies
# dev_adj_score                                                              5
# dev_adj_score_recent                                                       5
# dev_bill_rate                                                             30
# dev_billed_assignments                                                     5
# dev_blurb                  skype :  orange_project_kh\nemail:    contact@...
# dev_city                                                             Kharkov
# dev_country                                                          Ukraine
# dev_eng_skill                                                              4
# dev_first_name                                                          Dima
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Ecommer...
# dev_last_activity                                             April 23, 2016
# dev_last_name                                                       Koriagin
# dev_last_worked                                               April 23, 2016
# dev_last_worked_ts                                             1461369600000
# dev_portfolio_items_count                                                  0
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title          Fullstack web developer, e-commerce developing...
# dev_recno                                                            8660395
# dev_recno_ciphertext                                     ~01863825efc778f975
# dev_short_name                                                 Dima Koriagin
# dev_timezone                                        UTC+02:00 Eastern Europe
# dev_tot_feedback                                                           5
# dev_total_hours                                                          0.5
# dev_ui_profile_access                                                 Public
# education                  {u'institution': {u'ed_to': u'12/2015', u'ed_a...
# experiences                {u'experience': [{u'exp_from': u'01/2015', u'e...
# job_categories                                                           NaN
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'css3', u'skl_exter...
# tsexams                    {u'tsexam': [{u'ts_percentile': u'89', u'ts_wh...
#
#                                                                         7     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                                         {u'hr': u'', u'fp': u''}
# ciphertext                                               ~01614e82e3c5a0ccca
# dev_ac_agencies
# dev_adj_score                                                              0
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                          11.11
# dev_billed_assignments                                                     0
# dev_blurb                  DTL Solutions is the software solutions provid...
# dev_city                                                           Hochiminh
# dev_country                                                          Vietnam
# dev_eng_skill                                                              4
# dev_first_name                                                         Phong
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Product...
# dev_last_activity                                          February 16, 2014
# dev_last_name                                                           Dang
# dev_last_worked
# dev_last_worked_ts
# dev_portfolio_items_count                                                  8
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title          Small IT solution company provides Development...
# dev_recno                                                            4540710
# dev_recno_ciphertext                                     ~01614e82e3c5a0ccca
# dev_short_name                                                    Phong Dang
# dev_timezone                                     UTC+07:00 Omsk, Novosibirsk
# dev_tot_feedback                                                           0
# dev_total_hours                                                            0
# dev_ui_profile_access                                       oDesk Users only
# education
# experiences
# job_categories             {u'job_category': [{u'first_level': u'Web Deve...
# permalink
# portfolio_items            {u'portfolio_item': [{u'pi_large_thumbnail': u...
# skills                     {u'skill': [{u'skl_name': u'agile-software-dev...
# tsexams
#
#                                                                         8     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                {u'hr': {u'job': {u'as_total_hours': u'2.33', ...
# ciphertext                                               ~0122260b02b0c56563
# dev_ac_agencies
# dev_adj_score                                                              5
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                             10
# dev_billed_assignments                                                     2
# dev_blurb                  I am an upcoming college graduate! I will rece...
# dev_city                                                              Tucson
# dev_country                                                    United States
# dev_eng_skill                                                              5
# dev_first_name                                                           Amy
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Persona...
# dev_last_activity                                          February 27, 2013
# dev_last_name                                                          Bryan
# dev_last_worked                                            February 27, 2013
# dev_last_worked_ts                                             1361923200000
# dev_portfolio_items_count                                                  0
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                    Upbeat Enthusiastic Professional Writer
# dev_recno                                                            3677580
# dev_recno_ciphertext                                     ~0122260b02b0c56563
# dev_short_name                                                     Amy Bryan
# dev_timezone                   UTC-08:00 Pacific Time (US & Canada); Tijuana
# dev_tot_feedback                                                           1
# dev_total_hours                                                      2.33333
# dev_ui_profile_access                                                 Public
# education                  {u'institution': {u'ed_to': u'Present', u'ed_a...
# experiences                {u'experience': {u'exp_from': u'08/2012', u'ex...
# job_categories             {u'job_category': [{u'first_level': u'Writing ...
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'creative-writing',...
# tsexams                    {u'tsexam': [{u'ts_percentile': u'65', u'ts_wh...
#
#                                                                         9     \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                                         {u'hr': u'', u'fp': u''}
# ciphertext                                               ~01a3583a33f5146e8e
# dev_ac_agencies
# dev_adj_score                                                              0
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                           5.56
# dev_billed_assignments                                                     0
# dev_blurb                  1)  Shopping Card Management System using C# a...
# dev_city                                                               Dhaka
# dev_country                                                       Bangladesh
# dev_eng_skill
# dev_first_name                                                Ashraful Hoque
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Desktop...
# dev_last_activity                                             April 30, 2014
# dev_last_name                                                         Tanbin
# dev_last_worked
# dev_last_worked_ts
# dev_portfolio_items_count                                                  0
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                    Bsc in Computer Science and Engineering
# dev_recno                                                            5786114
# dev_recno_ciphertext                                     ~01a3583a33f5146e8e
# dev_short_name                                         Ashraful Hoque Tanbin
# dev_timezone                                         UTC+06:00 Almaty, Dhaka
# dev_tot_feedback                                                           0
# dev_total_hours                                                            0
# dev_ui_profile_access                                                 Public
# education                  {u'institution': {u'ed_to': u'12/2014', u'ed_a...
# experiences
# job_categories             {u'job_category': [{u'first_level': u'Networki...
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'android-app-develo...
# tsexams
#
#                                                  ...                          \
# ag_cny_recno                                     ...
# ag_country                                       ...
# ag_country_tz                                    ...
# ag_description                                   ...
# ag_logo                                          ...
# ag_name                                          ...
# ag_recent_hours                                  ...
# ag_total_hours                                   ...
# agency_ciphertext                                ...
# assignments                                      ...
# ciphertext                                       ...
# dev_ac_agencies                                  ...
# dev_adj_score                                    ...
# dev_adj_score_recent                             ...
# dev_bill_rate                                    ...
# dev_billed_assignments                           ...
# dev_blurb                                        ...
# dev_city                                         ...
# dev_country                                      ...
# dev_eng_skill                                    ...
# dev_first_name                                   ...
# dev_groups                                       ...
# dev_is_affiliated                                ...
# dev_job_categories_v2                            ...
# dev_last_activity                                ...
# dev_last_name                                    ...
# dev_last_worked                                  ...
# dev_last_worked_ts                               ...
# dev_portfolio_items_count                        ...
# dev_portrait                                     ...
# dev_portrait_100                                 ...
# dev_portrait_32                                  ...
# dev_portrait_50                                  ...
# dev_profile_title                                ...
# dev_recno                                        ...
# dev_recno_ciphertext                             ...
# dev_short_name                                   ...
# dev_timezone                                     ...
# dev_tot_feedback                                 ...
# dev_total_hours                                  ...
# dev_ui_profile_access                            ...
# education                                        ...
# experiences                                      ...
# job_categories                                   ...
# permalink                                        ...
# portfolio_items                                  ...
# skills                                           ...
# tsexams                                          ...
#
#                                                                         8704  \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                                         {u'hr': u'', u'fp': u''}
# ciphertext                                               ~014c554b69d9ef4904
# dev_ac_agencies
# dev_adj_score                                                              0
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                             10
# dev_billed_assignments                                                     0
# dev_blurb                             Programming skills:\nC++, python, php.
# dev_city                                                            Tel Aviv
# dev_country                                                           Israel
# dev_eng_skill                                                              5
# dev_first_name                                                         Matan
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Web & M...
# dev_last_activity                                             August 1, 2014
# dev_last_name                                                     Sokolovsky
# dev_last_worked
# dev_last_worked_ts
# dev_portfolio_items_count                                                  0
# dev_portrait
# dev_portrait_100
# dev_portrait_32
# dev_portrait_50
# dev_profile_title                                     Mathematics-CS Student
# dev_recno                                                            6192223
# dev_recno_ciphertext                                     ~014c554b69d9ef4904
# dev_short_name                                              Matan Sokolovsky
# dev_timezone                                                UTC+02:00 Israel
# dev_tot_feedback                                                           0
# dev_total_hours                                                            0
# dev_ui_profile_access                                                 Public
# education
# experiences
# job_categories             {u'job_category': [{u'first_level': u'Web Deve...
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'c++', u'skl_descri...
# tsexams                    {u'tsexam': [{u'ts_percentile': u'65', u'ts_wh...
#
#                                                                         8705  \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                                         {u'hr': u'', u'fp': u''}
# ...
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'database-programmi...
# tsexams
#
#                                                                         8710  \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                                         {u'hr': u'', u'fp': u''}
# ciphertext                                               ~01a04f0976bdb92579
# dev_ac_agencies
# dev_adj_score                                                              0
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                           7.78
# dev_billed_assignments                                                     0
# dev_blurb                  Summary:\nExperience:    2 years\nStrong knowl...
# dev_city                                                                Kiev
# dev_country                                                          Ukraine
# dev_eng_skill                                                              4
# dev_first_name                                                       Dmitryi
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Web Dev...
# dev_last_activity                                           October 20, 2015
# dev_last_name                                                        Golovan
# dev_last_worked
# dev_last_worked_ts
# dev_portfolio_items_count                                                  0
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                             Web programmer
# dev_recno                                                            8303002
# dev_recno_ciphertext                                     ~01a04f0976bdb92579
# dev_short_name                                               Dmitryi Golovan
# dev_timezone                      UTC+03:00 Baghdad, Kuwait, Nairobi, Riyadh
# dev_tot_feedback                                                           0
# dev_total_hours                                                            0
# dev_ui_profile_access                                                 Public
# education                  {u'institution': {u'ed_to': u'12/2013', u'ed_a...
# experiences                {u'experience': {u'exp_from': u'01/2013', u'ex...
# job_categories                                                           NaN
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'angularjs', u'skl_...
# tsexams
#
#                                                                         8711  \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                                         {u'hr': u'', u'fp': u''}
# ciphertext                                               ~0190b82a4fa94f3c63
# dev_ac_agencies
# dev_adj_score                                                              0
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                          11.11
# dev_billed_assignments                                                     0
# dev_blurb                  I have developed many website and desktop appl...
# dev_city                                                          Ankleshwar
# dev_country                                                            India
# dev_eng_skill                                                              5
# dev_first_name                                                          Abid
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Desktop...
# dev_last_activity                                                May 1, 2014
# dev_last_name                                                        Samnani
# dev_last_worked
# dev_last_worked_ts
# dev_portfolio_items_count                                                  0
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                 Web and Desktop Programmer
# dev_recno                                                            5788658
# dev_recno_ciphertext                                     ~0190b82a4fa94f3c63
# dev_short_name                                                  Abid Samnani
# dev_timezone                   UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# dev_tot_feedback                                                           0
# dev_total_hours                                                            0
# dev_ui_profile_access                                                 Public
# education                  {u'institution': {u'ed_to': u'12/2013', u'ed_a...
# experiences                {u'experience': {u'exp_from': u'02/2013', u'ex...
# job_categories             {u'job_category': [{u'first_level': u'Software...
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'css', u'skl_extern...
# tsexams                    {u'tsexam': {u'ts_percentile': u'65', u'ts_dur...
#
#                                                                         8712  \
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                                         {u'hr': u'', u'fp': u''}
# ciphertext                                               ~01ee98016e72a53890
# dev_ac_agencies
# dev_adj_score                                                              0
# dev_adj_score_recent                                                       0
# dev_bill_rate                                                             20
# dev_billed_assignments                                                     0
# dev_blurb                  PHP, Drupal 7 , Mysql, JavaScript             ...
# dev_city                                                           New Delhi
# dev_country                                                            India
# dev_eng_skill                                                              5
# dev_first_name                                                       Santosh
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Web Dev...
# dev_last_activity                                             March 23, 2016
# dev_last_name                                                         Tiwari
# dev_last_worked
# dev_last_worked_ts
# dev_portfolio_items_count                                                  0
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title                                 CMS Developer - Open stack
# dev_recno                                                           10936345
# dev_recno_ciphertext                                     ~01ee98016e72a53890
# dev_short_name                                                Santosh Tiwari
# dev_timezone                   UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi
# dev_tot_feedback                                                           0
# dev_total_hours                                                            0
# dev_ui_profile_access                                                 Public
# education                  {u'institution': {u'ed_to': u'01/2009', u'ed_a...
# experiences                {u'experience': {u'exp_from': u'08/2014', u'ex...
# job_categories                                                           NaN
# permalink
# portfolio_items
# skills                     {u'skill': [{u'skl_name': u'bitrix', u'skl_des...
# tsexams
#
#                                                                         8713
# ag_cny_recno                                                             NaN
# ag_country                                                               NaN
# ag_country_tz                                                            NaN
# ag_description                                                           NaN
# ag_logo                                                                  NaN
# ag_name                                                                  NaN
# ag_recent_hours                                                          NaN
# ag_total_hours                                                           NaN
# agency_ciphertext                                                        NaN
# assignments                {u'hr': {u'job': [{u'as_total_hours': u'28', u...
# ciphertext                                               ~0108b97422379b3351
# dev_ac_agencies
# dev_adj_score                                                        4.98885
# dev_adj_score_recent                                                 4.99621
# dev_bill_rate                                                           4.56
# dev_billed_assignments                                                    13
# dev_blurb                  Hi! you can call me VYC, A Computer System Tec...
# dev_city                                                            Caloocan
# dev_country                                                      Philippines
# dev_eng_skill                                                              4
# dev_first_name                                                        Vyctor
# dev_groups
# dev_is_affiliated                                                          0
# dev_job_categories_v2      {u'dev_job_categories_v': [{u'name': u'Data En...
# dev_last_activity                                             April 23, 2016
# dev_last_name                                                       Vysosias
# dev_last_worked                                               April 23, 2016
# dev_last_worked_ts                                             1461369600000
# dev_portfolio_items_count                                                  1
# dev_portrait               https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_100           https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_32            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_portrait_50            https://odesk-prod-portraits.s3.amazonaws.com/...
# dev_profile_title          Web Designer/Web Developer/CMS/HTML5/CSS/PHP/M...
# dev_recno                                                             867244
# dev_recno_ciphertext                                     ~0108b97422379b3351
# dev_short_name                                               Vyctor Vysosias
# dev_timezone               UTC+08:00 Hong Kong SAR, Perth, Singapore, Taipei
# dev_tot_feedback                                                           7
# dev_total_hours                                                       3892.5
# dev_ui_profile_access                                                 Public
# education                  {u'institution': [{u'ed_to': u'01/2016', u'ed_...
# experiences                {u'experience': [{u'exp_from': u'09/2007', u'e...
# job_categories                                                           NaN
# permalink
# portfolio_items            {u'portfolio_item': {u'pi_large_thumbnail': u'...
# skills                     {u'skill': [{u'skl_name': u'administrative-sup...
# tsexams                    {u'tsexam': [{u'ts_percentile': u'65', u'ts_du...
#
# [48 rows x 8714 columns]

# %%
print as_profiles_df.dev_ui_profile_access.value_counts()
# Out:
# Public              7572
# oDesk Users only    1140
# Private                2
# Name: dev_ui_profile_access, dtype: int64

# %%
print as_profiles_df.education[0:5]
# Out:
# 0    {u'institution': {u'ed_to': u'07/2007', u'ed_a...
# 1    {u'institution': {u'ed_to': u'12/2012', u'ed_a...
# 2    {u'institution': [{u'ed_to': u'12/2002', u'ed_...
# 3
# 4
# Name: education, dtype: object

# %%
as_profiles_df[(as_profiles_df['dev_is_affiliated'] <> 0) & (as_profiles_df['dev_ac_agencies'] == '')][['dev_is_affiliated', 'dev_ac_agencies']]
# Out:
#       dev_is_affiliated dev_ac_agencies
# 4300                  1

# %%
print as_profiles_df.dev_ac_agencies.value_counts()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                           7637
# {u'dev_ac_agency': {u'ag_name': u'CSSA Info Media Pvt. Ltd.', u'ciphertext': u'~01c1dd1cf7e3e90d97', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:229385:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=0EQPQKYiNLgmRZkmRWrM6zr1H2M%3D', u'ag_total_hours': u'16585.8333333333', u'ag_tot_feedback': u'234', u'ag_adj_score': u'4.5638057423'}}                    9
# {u'dev_ac_agency': {u'ag_name': u'REMBROS CORPORATION DBA ITECHART GR', u'ciphertext': u'~01a17a64d4d5f499d5', u'ag_logo': u'https://www.odesk.com/att/~~fycV8WtafKa1GKaiXOAQVlQd8XWTr6ucENj5HR6m9f2W40Unwd7yGw==', u'ag_adj_score': u'4.762403897', u'ag_tot_feedback': u'192', u'ag_total_hours': u'61291.5'}}                                                                                                             3
# {u'dev_ac_agency': {u'ag_name': u'Sunvik Web Technosoft', u'ciphertext': u'~01f7ade3eb4397c4c9', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:745282:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=fABxyJnGk1lAuD6xMzRX9ecdeYk%3D', u'ag_total_hours': u'0', u'ag_tot_feedback': u'7', u'ag_adj_score': u'3.2055595366'}}                                         3
# {u'dev_ac_agency': {u'ag_name': u'Galaxy Web Links Ltd.', u'ciphertext': u'~01ff8120fed6ec29ff', u'ag_logo': u'https://www.odesk.com/att/~~fycV8WtafKa6FZ80ClB4vlQd8XWTr6ucENj5HR6m9f2W40Unwd7yGw==', u'ag_adj_score': u'4.3868333556', u'ag_tot_feedback': u'54', u'ag_total_hours': u'6013.9333333333'}}                                                                                                                   2
# {u'dev_ac_agency': {u'ag_name': u'SOFTREACTOR LLC', u'ciphertext': u'~01c85aff3b36389034', u'ag_logo': u'https://www.odesk.com/att/~~fycV8WtafKYsFKc5sgsmw1Qd8XWTr6ucENj5HR6m9f2W40Unwd7yGw==', u'ag_total_hours': u'153059.333333333', u'ag_tot_feedback': u'1160', u'ag_adj_score': u'4.8324911845'}}                                                                                                                      2
# {u'dev_ac_agency': {u'ag_name': u'TechZyena Solutions', u'ciphertext': u'~01d1dc6703b5d0a4ef', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:1426267:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=e0BUwO%2BSzNxNKM%2FbJsSub%2F8mtDQ%3D', u'ag_total_hours': u'1464', u'ag_tot_feedback': u'6', u'ag_adj_score': u'4.5426786355'}}                                 2
# {u'dev_ac_agency': {u'ag_name': u'Sigma Square', u'ciphertext': u'~01d0709dd65a370123', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:413866:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=TLYEvQdTbqRvnCutTzwy5V6r%2FW0%3D', u'ag_total_hours': u'4898.1666666667', u'ag_tot_feedback': u'60', u'ag_adj_score': u'4.7773494036'}}                                 2
# {u'dev_ac_agency': {u'ag_name': u'Exaltsoft Solutions (Pvt) Ltd', u'ciphertext': u'~01b43d4c30e0d6bc68', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:1154471:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=qFZb2TlHaIQ%2BBaKTxVJylfqLXx8%3D', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                         2
# {u'dev_ac_agency': {u'ag_name': u'Singular Software Development', u'ciphertext': u'~016355a4c56d953df8', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:641822:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=UAZDmv3ba%2B%2FheKcH3xGzIyXf1MY%3D', u'ag_adj_score': u'0', u'ag_tot_feedback': u'0', u'ag_total_hours': u'0'}}                                        2
# {u'dev_ac_agency': {u'ag_name': u'SmartData Inc Agency', u'ciphertext': u'~011026e25f2ce61ec1', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:984801:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=Vd21sCgg4S2FOTqpKK2fkfI3Oh0%3D', u'ag_adj_score': u'4.6352782056', u'ag_tot_feedback': u'3194', u'ag_total_hours': u'2001149.64333333'}}                        2
# {u'dev_ac_agency': {u'ag_name': u'DigiGrapes Technologies (SwiftLogic)', u'ciphertext': u'~0188ca145817f08406', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:104194:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=KOx%2BdRCsvHNSNi1tnczqo%2FtvPWY%3D', u'ag_total_hours': u'17100', u'ag_tot_feedback': u'68', u'ag_adj_score': u'4.8624637555'}}                 2
# {u'dev_ac_agency': {u'ag_name': u'Device Developer', u'ciphertext': u'~013bf97024585dfeed', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:1955437:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=TEnxM5AzdX%2FqNr21XiFQE%2BpLGkA%3D', u'ag_adj_score': u'0', u'ag_tot_feedback': u'0', u'ag_total_hours': u'0'}}                                                    2
# {u'dev_ac_agency': {u'ag_name': u'FrontLine Solutions', u'ciphertext': u'~0182e5cd2db3ae58fa', u'ag_logo': u'', u'ag_total_hours': u'103', u'ag_tot_feedback': u'1', u'ag_adj_score': u'5'}}                                                                                                                                                                                                                                 2
# {u'dev_ac_agency': {u'ag_name': u'iTecG Web Solutions Pvt Ltd', u'ciphertext': u'~01ac181ebb15e6a617', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:859565:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=g4S6VQaHzMrYPDfEqMt0sFoX9V4%3D', u'ag_adj_score': u'3.2367332688', u'ag_tot_feedback': u'12', u'ag_total_hours': u'4068.5'}}                             2
# {u'dev_ac_agency': {u'ag_name': u'WebMan Technologies', u'ciphertext': u'~01301c06ae97c38256', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:838005:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=%2BOnmTEV%2BQT2MCcnCzaoK1lXAGow%3D', u'ag_adj_score': u'4.8185350225', u'ag_tot_feedback': u'329', u'ag_total_hours': u'3993'}}                                  2
# {u'dev_ac_agency': {u'ag_name': u'Impinge Solutions Agency', u'ciphertext': u'~0188e526526ad6dd7c', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:32740:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=FUK5UM0n9ya6T4Gqfw137oZIgmI%3D', u'ag_adj_score': u'4.5635537648', u'ag_tot_feedback': u'2399', u'ag_total_hours': u'459132'}}                               2
# {u'dev_ac_agency': {u'ag_name': u'e-SearchPoint', u'ciphertext': u'~01f3864e3026e7fb5e', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:1729989:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=lBQq3rdFdMTZDo%2FKsqqokFDr16E%3D', u'ag_total_hours': u'146', u'ag_tot_feedback': u'11', u'ag_adj_score': u'4.9554526016'}}                                           2
# {u'dev_ac_agency': {u'ag_name': u'LA Net Team Software Solutions Pvt Ltd.', u'ciphertext': u'~01d6410f1dd3066911', u'ag_logo': u'https://www.odesk.com/att/~~fycV8WtafKYP98Cz102vR1Qd8XWTr6ucENj5HR6m9f2W40Unwd7yGw==', u'ag_total_hours': u'161527.166666667', u'ag_tot_feedback': u'427', u'ag_adj_score': u'4.9158443909'}}                                                                                               2
# {u'dev_ac_agency': {u'ag_name': u'Ant Web Technology Pvt Ltd', u'ciphertext': u'~01392dae11e76044aa', u'ag_logo': u'', u'ag_total_hours': u'1471.8333333333', u'ag_tot_feedback': u'3', u'ag_adj_score': u'5'}}                                                                                                                                                                                                              2
# {u'dev_ac_agency': {u'ag_name': u'WebPlanex Infotech Pvt. Ltd.', u'ciphertext': u'~0116347bca48ed4901', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:988930:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=EKUYY9DDSpxkmNbm%2BQhZ5taCUnc%3D', u'ag_total_hours': u'14880.0333333333', u'ag_tot_feedback': u'259', u'ag_adj_score': u'4.8096247851'}}               2
# {u'dev_ac_agency': {u'ag_name': u'IdeallyCloud Agency', u'ciphertext': u'~0142a69263b574c761', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:606990:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=5KugqOe4NA1oHy6g%2BEXPNG8uhNo%3D', u'ag_adj_score': u'4.9994242314', u'ag_tot_feedback': u'2', u'ag_total_hours': u'1180.3333333333'}}                           2
# {u'dev_ac_agency': {u'ag_name': u'ausfim Technologies', u'ciphertext': u'~01d75534de3534fd61', u'ag_logo': u'', u'ag_total_hours': u'212.6666666667', u'ag_tot_feedback': u'2', u'ag_adj_score': u'5'}}                                                                                                                                                                                                                      2
# {u'dev_ac_agency': {u'ag_name': u'Gunaatita Technology Pvt. Ltd.', u'ciphertext': u'~015819f90f7293edbe', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2575683:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=Vm%2BmWC6BWiqL%2BNhD%2BsAXTCumC%2Bw%3D', u'ag_total_hours': u'663', u'ag_tot_feedback': u'1', u'ag_adj_score': u'4.9545119511'}}                     2
# {u'dev_ac_agency': {u'ag_name': u'bruce', u'ciphertext': u'~017e3d353aeaf51395', u'ag_logo': u'', u'ag_total_hours': u'0', u'ag_tot_feedback': u'1', u'ag_adj_score': u'5'}}                                                                                                                                                                                                                                                 2
# {u'dev_ac_agency': {u'ag_name': u'Ramanujan ISS', u'ciphertext': u'~01ebceae7d72d4f61f', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2537654:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=ELRd4g1S%2Fn0d%2Bbcwz0TnroO%2BhFM%3D', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                                     2
# {u'dev_ac_agency': {u'ag_name': u'Cordatazo', u'ciphertext': u'~01d37c14b5b2c97adb', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2218905:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=RYSafVD7Wdl6diNu7LdVwf6%2Ba6c%3D', u'ag_total_hours': u'5', u'ag_tot_feedback': u'1', u'ag_adj_score': u'0'}}                                                             2
# {u'dev_ac_agency': {u'ag_name': u'TechZyena Solutions', u'ciphertext': u'~01d1dc6703b5d0a4ef', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:1426267:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=e0BUwO%2BSzNxNKM%2FbJsSub%2F8mtDQ%3D', u'ag_total_hours': u'366', u'ag_tot_feedback': u'4', u'ag_adj_score': u'5'}}                                             2
# {u'dev_ac_agency': {u'ag_name': u'Nano Web Tech Limited', u'ciphertext': u'~01085b8b4ab7a4c4ab', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:61906:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=u2YB8DT6pMNIyeKdo4ldP5SN4cM%3D', u'ag_adj_score': u'4.7899591375', u'ag_tot_feedback': u'399', u'ag_total_hours': u'136883.5'}}                                 2
# {u'dev_ac_agency': {u'ag_name': u'Haletatech Solutions', u'ciphertext': u'~0115972025d46905f3', u'ag_logo': u'', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                                                                                                                                                                                                                  1
#                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# {u'dev_ac_agency': {u'ag_name': u'Cognite Labs', u'ciphertext': u'~01285532861f1e5e1f', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2240283:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=Idj6G0q%2Bg03XItBwwuDEOsd9yMU%3D', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'5'}}                                                          1
# {u'dev_ac_agency': {u'ag_name': u'Create91', u'ciphertext': u'~01dea208903425ce2b', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2737475:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=2T5g6Sjn%2Fx5dvLyIdAH2ZH4I98A%3D', u'ag_total_hours': u'21.3333333333', u'ag_tot_feedback': u'1', u'ag_adj_score': u'5'}}                                                  1
# {u'dev_ac_agency': {u'ag_name': u'Best Tide Solutions', u'ciphertext': u'~01de624457c55518c5', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2415645:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=7uciId5au8%2BGggOfvv2g0KrmVl0%3D', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                                   1
# {u'dev_ac_agency': {u'ag_name': u'Universal IT Solutions', u'ciphertext': u'~0161b5c9484e90ed66', u'ag_logo': u'', u'ag_total_hours': u'1842.4333333333', u'ag_tot_feedback': u'1', u'ag_adj_score': u'4.591087202'}}                                                                                                                                                                                                        1
# {u'dev_ac_agency': {u'ag_name': u'Teamlance', u'ciphertext': u'~0130bdb1e8ce5634ed', u'ag_logo': u'', u'ag_adj_score': u'5', u'ag_tot_feedback': u'2', u'ag_total_hours': u'218.3333333333'}}                                                                                                                                                                                                                                1
# {u'dev_ac_agency': {u'ag_name': u'CITE', u'ciphertext': u'~01796f7d2552bd138d', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:1875734:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=vN8DdY9NF9ygRWw5JtA%2FXmfTW9I%3D', u'ag_adj_score': u'0', u'ag_tot_feedback': u'0', u'ag_total_hours': u'0'}}                                                                  1
# {u'dev_ac_agency': {u'ag_name': u'digIT', u'ciphertext': u'~01f602432f07d58925', u'ag_logo': u'', u'ag_total_hours': u'10436.5', u'ag_tot_feedback': u'80', u'ag_adj_score': u'4.1105918974'}}                                                                                                                                                                                                                               1
# {u'dev_ac_agency': {u'ag_name': u'Medos Company', u'ciphertext': u'~01e93e136042732450', u'ag_logo': u'', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                                                                                                                                                                                                                         1
# {u'dev_ac_agency': {u'ag_name': u'Munish Kumar', u'ciphertext': u'~019fd282d6263e7e63', u'ag_logo': u'', u'ag_total_hours': u'0', u'ag_tot_feedback': u'1', u'ag_adj_score': u'4'}}                                                                                                                                                                                                                                          1
# {u'dev_ac_agency': {u'ag_name': u'Supremetech', u'ciphertext': u'~015aee68e332e1d267', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2322238:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=DhmMGjWqJSoNV%2FfO5g8aXb5a%2BYs%3D', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'5'}}                                                         1
# {u'dev_ac_agency': {u'ag_name': u'Vishesh It Services', u'ciphertext': u'~01455d71fde9235c1b', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2316239:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=6NrI1Iki%2BFJorYWKzD1YLDfOjik%3D', u'ag_total_hours': u'330.8333333333', u'ag_tot_feedback': u'1', u'ag_adj_score': u'0'}}                                      1
# {u'dev_ac_agency': {u'ag_name': u'Bharatsync Technologies', u'ciphertext': u'~010f8206d2be476248', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2474611:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=ZODK%2F4KSYwpmKXm12BMtkhy%2FnzI%3D', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                             1
# {u'dev_ac_agency': {u'ag_name': u'ONEDISH, LLC Agency', u'ciphertext': u'~019a80058e356cc84e', u'ag_logo': u'', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                                                                                                                                                                                                                   1
# {u'dev_ac_agency': {u'ag_name': u'Zealas Solutions', u'ciphertext': u'~0161f5ef59ab7545d9', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:788944:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=4VRnVvf3mD1xSWf9dRJmFpBsWU8%3D', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                                         1
# {u'dev_ac_agency': {u'ag_name': u'GbroTech', u'ciphertext': u'~01c6c346de4085fd6a', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:299605:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=EImq5baTQhZwsSexRTbLys4G8mg%3D', u'ag_total_hours': u'8.1666666667', u'ag_tot_feedback': u'1', u'ag_adj_score': u'1'}}                                                      1
# {u'dev_ac_agency': {u'ag_name': u'Rose IT Ltd', u'ciphertext': u'~01603037b0e35f85ee', u'ag_logo': u'', u'ag_adj_score': u'0', u'ag_tot_feedback': u'0', u'ag_total_hours': u'0'}}                                                                                                                                                                                                                                           1
# {u'dev_ac_agency': {u'ag_name': u'Globalnexo', u'ciphertext': u'~01856f8614b18e17ef', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:949921:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=KMsRmNCqu86FB06zTCbqqdHggoQ%3D', u'ag_adj_score': u'4.5952823752', u'ag_tot_feedback': u'9', u'ag_total_hours': u'15833.6666666667'}}                                     1
# {u'dev_ac_agency': {u'ag_name': u'WW', u'ciphertext': u'~01f29fe56776d85b20', u'ag_logo': u'', u'ag_adj_score': u'4.4187273017', u'ag_tot_feedback': u'43', u'ag_total_hours': u'21992.3333333333'}}                                                                                                                                                                                                                         1
# {u'dev_ac_agency': {u'ag_name': u'Unicode Systems', u'ciphertext': u'~01fe3a90ec10764b0b', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:122715:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=%2Blf8RPc6Axf%2BzxpdADk7lJkhd0M%3D', u'ag_total_hours': u'15705.1666666667', u'ag_tot_feedback': u'50', u'ag_adj_score': u'4.6744656862'}}                           1
# {u'dev_ac_agency': {u'ag_name': u'Intelmobiz Solution  Ltd', u'ciphertext': u'~01de3ae44fbc5952d6', u'ag_logo': u'', u'ag_total_hours': u'2979.1666666667', u'ag_tot_feedback': u'29', u'ag_adj_score': u'4.1587640402'}}                                                                                                                                                                                                    1
# {u'dev_ac_agency': {u'ag_name': u'Hardev soft solution', u'ciphertext': u'~0181aec9d6ca28dad2', u'ag_logo': u'', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                                                                                                                                                                                                                  1
# {u'dev_ac_agency': {u'ag_name': u'Richest soft', u'ciphertext': u'~01e84916e4526b2b1d', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:196592:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=pyM3Wo8NrkO9ZX%2BKCwfIj7z%2B5V0%3D', u'ag_total_hours': u'72865.5', u'ag_tot_feedback': u'1127', u'ag_adj_score': u'4.7315691895'}}                                     1
# {u'dev_ac_agency': {u'ag_name': u'modloaded corporation', u'ciphertext': u'~011c03dd37f6fd0329', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:1754239:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=jdDGKW4WSlbvLj%2FdYrvCEoMHOlc%3D', u'ag_total_hours': u'11.3333333333', u'ag_tot_feedback': u'1', u'ag_adj_score': u'5'}}                                     1
# {u'dev_ac_agency': {u'ag_name': u'ITRex Group', u'ciphertext': u'~010e61f430108e5be5', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:135223:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=BYao%2Be5FVI350Mqa5Uc0MxQ57xU%3D', u'ag_total_hours': u'59299.1666666667', u'ag_tot_feedback': u'80', u'ag_adj_score': u'4.9657162865'}}                                 1
# {u'dev_ac_agency': {u'ag_name': u'Strikingsoft Solutions', u'ciphertext': u'~010966f853d6238649', u'ag_logo': u'', u'ag_adj_score': u'3', u'ag_tot_feedback': u'1', u'ag_total_hours': u'14.1666666667'}}                                                                                                                                                                                                                    1
# {u'dev_ac_agency': {u'ag_name': u'SCALE-S', u'ciphertext': u'~01297b00546a705b05', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:1039453:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=DfY0%2FYlQKGELbac%2BriKErKU9f1Q%3D', u'ag_total_hours': u'41803.1333333333', u'ag_tot_feedback': u'21', u'ag_adj_score': u'4.9820745076'}}                                  1
# {u'dev_ac_agency': {u'ag_name': u'zenStudio.com.au', u'ciphertext': u'~01c185d1c8413b22f3', u'ag_logo': u'', u'ag_adj_score': u'0', u'ag_tot_feedback': u'1', u'ag_total_hours': u'4.8333333333'}}                                                                                                                                                                                                                           1
# {u'dev_ac_agency': {u'ag_name': u'InnoChip', u'ciphertext': u'~015c20169df763ed0b', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:2183267:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=yGZNvxb%2BL7ISWBZ2DiGw7C%2B8uHY%3D', u'ag_adj_score': u'0', u'ag_tot_feedback': u'0', u'ag_total_hours': u'0'}}                                                            1
# {u'dev_ac_agency': {u'ag_name': u'SystemLogic', u'ciphertext': u'~01324736e77b023f26', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:696288:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=6I6GFB94fLznv%2BT1yr58M39gvYo%3D', u'ag_total_hours': u'0', u'ag_tot_feedback': u'0', u'ag_adj_score': u'0'}}                                                            1
# {u'dev_ac_agency': {u'ag_name': u'InfoAccords IT Solutions Private Limited', u'ciphertext': u'~016ac917eb23d52e5a', u'ag_logo': u'https://odesk-prod-portraits.s3.amazonaws.com/Companies:330603:CompanyLogoURL?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=qhm0aDggWlJOmOiyFT8eKpUH8Ig%3D', u'ag_total_hours': u'5022.8333333333', u'ag_tot_feedback': u'19', u'ag_adj_score': u'4.8873635922'}}       1
# Name: dev_ac_agencies, dtype: int64

# %%
print as_profiles_lod[0]
# Out:
# {u'dev_adj_score_recent': u'0', u'dev_ui_profile_access': u'Public', u'dev_portrait': u'https://odesk-prod-portraits.s3.amazonaws.com/Users:sandytechwork:PortraitUrl?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=zJ35Fdd3Md%2ByXrFRzdOmWRTTEhk%3D', u'dev_country': u'India', u'dev_first_name': u'Sandeep', u'dev_groups': u'', u'dev_city': u'New Delhi', u'dev_blurb': u'Over the more than 6 years, I have developed a wide range of complex websites using PHP, MySQL, AJAX etc. My core competency lies in complete end-end management of a website development project.\n\nKey Skills-\n\nPHP5, MySQL5, AJAX, OAUTH, JSON, Oracle 10g, 11g, SMTP, XML, XML-RPC, API-DEVELOPMENT, REST,OOP, Software Design and Testing, Database Design, Data Modeling, PL/SQL, SQL, Stored Procedures, Zend Framework 2, Linux , Magento, PayPal, Authorize.Net, 2Checkout, Moneris, MoneyBookers, eWay, BeanStream, PayGate, PayMate, Google Checkout, BluePay, LinkPoint, PSI Gate, iTransact, Setcom, SagePay, VCS, Ogone.', u'education': {u'institution': {u'ed_to': u'07/2007', u'ed_area': u'Computer science', u'ed_school': u'U.P. Technical University', u'ed_comment': u'Studied Computer Science with some focus on Programming languages, Data Structure, Algorithm, SDLC and Database etc.', u'ed_from': u'07/2004', u'ed_degree': u'Masters'}}, u'dev_profile_title': u'LAMP developer with more than 6 years', u'dev_adj_score': u'4.35', u'dev_billed_assignments': u'1', u'dev_portrait_100': u'https://odesk-prod-portraits.s3.amazonaws.com/Users:sandytechwork:PortraitUrl_100?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=651NBiTq6eKeJW8MPufqT8x8KMw%3D', u'dev_recno': u'2505125', u'dev_portrait_32': u'https://odesk-prod-portraits.s3.amazonaws.com/Users:sandytechwork:PortraitUrl_32?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=N%2F0HfLJoYlh2d%2BpbOlwH%2B73zELk%3D', u'portfolio_items': {u'portfolio_item': [{u'pi_large_thumbnail': u'https://www.odesk.com/att/~~8Cen7zpTWXydf3Q6RU*s4tZg6O*fjsjurI9-Q9metWi5HDU*5JVCJA==', u'pi_image': u'https://www.odesk.com/att/~~8Cen7zpTWXydf3Q6RU*s4tZg6O*fjsjurI9-Q9metWi5HDU*5JVCJA==', u'pi_title': u'Zumbawear UK', u'pi_recno': u'1323486'}, {u'pi_large_thumbnail': u'https://www.odesk.com/att/~~8Cen7zpTWXydf3Q6RU*s4mAcZMVg*tU0rI9-Q9metWi5HDU*5JVCJA==', u'pi_recno': u'1323514', u'pi_title': u'Bobby Jones Golf', u'pi_image': u'https://www.odesk.com/att/~~8Cen7zpTWXydf3Q6RU*s4mAcZMVg*tU0rI9-Q9metWi5HDU*5JVCJA=='}]}, u'dev_bill_rate': u'15', u'ciphertext': u'~01cae3810dc6d2bbbc', u'dev_portrait_50': u'https://odesk-prod-portraits.s3.amazonaws.com/Users:sandytechwork:PortraitUrl_50?AWSAccessKeyId=1XVAX3FNQZAFC9GJCFR2&Expires=2147483647&Signature=LZnvyV%2BYKE8I5zGYK2E2vOzM658%3D', u'dev_timezone': u'UTC+05:30 Mumbai, Kolkata, Chennai, New Delhi', u'dev_ac_agencies': u'', u'dev_portfolio_items_count': u'2', u'tsexams': {u'tsexam': [{u'ts_percentile': u'65', u'ts_duration': u'3', u'ts_pass': u'1', u'ts_name_raw': u'oDesk Readiness Test for Independent Contractors and Staffing Managers', u'ts_score': u'5.0000000000000000', u'ts_id': u'4695823', u'ts_when': u'06/10/2012'}, {u'ts_percentile': u'85', u'ts_duration': u'38', u'ts_pass': u'1', u'ts_name_raw': u'PHP5', u'ts_score': u'4.1000000000000000', u'ts_id': u'4712628', u'ts_when': u'06/12/2012'}, {u'ts_percentile': u'57', u'ts_when': u'06/09/2013', u'ts_pass': u'1', u'ts_name_raw': u'MySQL 5.0', u'ts_score': u'2.9000000000000000', u'ts_id': u'7360191', u'ts_duration': u'31'}, {u'ts_percentile': u'55', u'ts_when': u'06/23/2012', u'ts_pass': u'1', u'ts_name_raw': u'JavaScript 1.8', u'ts_score': u'3.4000000000000000', u'ts_id': u'4802395', u'ts_duration': u'39'}, {u'ts_percentile': u'36', u'ts_duration': u'12', u'ts_pass': u'1', u'ts_name_raw': u'AJAX', u'ts_score': u'3.1000000000000000', u'ts_id': u'7360279', u'ts_when': u'06/09/2013'}]}, u'permalink': u'', u'dev_eng_skill': u'4', u'dev_last_activity': u'August 31, 2013', u'job_categories': {u'job_category': [{u'first_le ...

# %%
def json_prep_pandas(in_file):
    # read the entire file into a python array
    with open(in_file, 'rb') as f:
        data = f.readlines()

    # remove the trailing "\n" from each line
    data = map(lambda x: x.rstrip(), data)

    # each element of 'data' is an individual JSON object.
    # i want to convert it into an *array* of JSON objects
    # which, in and of itself, is one large JSON object
    # basically... add square brackets to the beginning
    # and end, and have all the individual business JSON objects
    # separated by a comma
    data_json_str = "[" + ','.join(data) + "]"

    data_list_of_dicts = json.loads(data_json_str)
    
#     now, load it into pandas
    out_df = pd.read_json(data_json_str)
    return out_df

# %%
df = json_prep_pandas('../../data/detailed_profiles_da_0_8715.txt')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8714 entries, 0 to 8713
# Data columns (total 48 columns):
# ag_cny_recno                 735 non-null float64
# ag_country                   735 non-null object
# ag_country_tz                735 non-null object
# ag_description               735 non-null object
# ag_logo                      735 non-null object
# ag_name                      735 non-null object
# ag_recent_hours              735 non-null float64
# ag_total_hours               735 non-null float64
# agency_ciphertext            735 non-null object
# assignments                  8714 non-null object
# ciphertext                   8714 non-null object
# dev_ac_agencies              8714 non-null object
# dev_adj_score                8714 non-null float64
# dev_adj_score_recent         8714 non-null float64
# dev_bill_rate                8714 non-null float64
# dev_billed_assignments       8714 non-null int64
# dev_blurb                    8714 non-null object
# dev_city                     8714 non-null object
# dev_country                  8714 non-null object
# dev_eng_skill                8714 non-null object
# dev_first_name               8714 non-null object
# dev_groups                   8714 non-null object
# dev_is_affiliated            8714 non-null int64
# dev_job_categories_v2        8337 non-null object
# dev_last_activity            8714 non-null object
# dev_last_name                8714 non-null object
# dev_last_worked              8714 non-null object
# dev_last_worked_ts           8714 non-null object
# dev_portfolio_items_count    8714 non-null int64
# dev_portrait                 8714 non-null object
# dev_portrait_100             8714 non-null object
# dev_portrait_32              8714 non-null object
# dev_portrait_50              8714 non-null object
# dev_profile_title            8714 non-null object
# dev_recno                    8714 non-null int64
# dev_recno_ciphertext         8714 non-null object
# dev_short_name               8714 non-null object
# dev_timezone                 8714 non-null object
# dev_tot_feedback             8714 non-null int64
# dev_total_hours              8714 non-null float64
# dev_ui_profile_access        8714 non-null object
# education                    8714 non-null object
# experiences                  8714 non-null object
# job_categories               4222 non-null object
# permalink                    8714 non-null object
# portfolio_items              8714 non-null object
# skills                       8714 non-null object
# tsexams                      8714 non-null object
# dtypes: float64(7), int64(5), object(36)
# memory usage: 3.3+ MB

# %%
df.assignments.head(10)
# Out:
# 0    {u'hr': u'', u'fp': {u'job': {u'as_to': u'01/2...
# 1                             {u'hr': u'', u'fp': u''}
# 2                             {u'hr': u'', u'fp': u''}
# 3    {u'hr': {u'job': [{u'as_total_hours': u'614', ...
# 4    {u'hr': u'', u'fp': {u'job': {u'as_to': u'04/2...
# 5    {u'hr': {u'job': [{u'as_to': u'09/2011', u'as_...
# 6    {u'hr': u'', u'fp': {u'job': [{u'as_total_hour...
# 7                             {u'hr': u'', u'fp': u''}
# 8    {u'hr': {u'job': {u'as_total_hours': u'2.33', ...
# 9                             {u'hr': u'', u'fp': u''}
# Name: assignments, dtype: object

# %%
for char in df.assignments.iloc[[0]]:
    print char
# Out:
# {u'hr': u'', u'fp': {u'job': {u'as_to': u'01/2013', u'feedback': {u'comment': u'Excellent work will be working with you again.', u'score': u'4.35', u'scores': {u'score': [{u'score': u'5', u'description': u'competency and skills for the job, understanding of specifications/instructions', u'label': u'Skills'}, {u'score': u'4', u'description': u'quality of work deliverables', u'label': u'Quality'}, {u'score': u'4', u'description': u'online presence on a consistent schedule', u'label': u'Availability'}, {u'score': u'3', u'description': u'ability to complete tasks on time', u'label': u'Deadlines'}, {u'score': u'5', u'description': u'communication skills, frequent progress updates, responsiveness', u'label': u'Communication'}, {u'score': u'5', u'description': u'cooperation and flexibility, suggestions for improvement', u'label': u'Cooperation'}]}}, u'as_total_hours': u'0.00', u'as_total_hours_precise': u'0', u'as_opening_title': u'Development of Firovia client/associate project management database', u'as_job_type': u'Fixed', u'as_to_full': u'01/09/2013'}}}

# %%
for x in range(20):
    print x
    jobs = df.assignments[x]
    for k1, v1 in jobs.iteritems():        
        print 'k1 = ', k1
        if isinstance(v1, basestring):
            print 'basestring'
            pass
        elif isinstance(v1, dict):
            print 'dict'
            for k2, v2 in v1.iteritems():
                print '  k2 = ', k2
                if isinstance(v2, basestring):
                    print '  basestring'
                    pass
                elif isinstance(v2, dict):
                    print '  dict'
                    for k3, v3 in v2.iteritems():
                        print '    k3 = ' + k3
                elif isinstance(v2, list):
                    print '  list'
                    for index2, item in enumerate(v2):
                        print '    item', index2
                        if isinstance(item, dict):
                            for k4, v4 in item.iteritems():
                                print '    k4 = ', k4
        elif isinstance(v1, list):
            print 'list'
            for item in v1:
                print item
    print
# Out:
# 0
# k1 =  hr
# basestring
# k1 =  fp
# dict
#   k2 =  job
#   dict
#     k3 = as_to
#     k3 = feedback
#     k3 = as_total_hours
#     k3 = as_total_hours_precise
#     k3 = as_opening_title
#     k3 = as_job_type
#     k3 = as_to_full
#
# 1
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 2
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 3
# k1 =  hr
# dict
#   k2 =  job
#   list
#     item 0
#     k4 =  as_total_hours
#     k4 =  as_rate
#     k4 =  as_total_charge
#     k4 =  as_to
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     item 1
#     k4 =  as_total_hours
#     k4 =  as_rate
#     k4 =  as_total_charge
#     k4 =  as_to
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     k4 =  feedback
# k1 =  fp
# dict
#   k2 =  job
#   dict
#     k3 = as_to
#     k3 = as_rate
#     k3 = as_financial_privacy
#     k3 = as_total_hours
#     k3 = as_from_full
#     k3 = as_ciphertext_opening_recno
#     k3 = as_total_hours_precise
#     k3 = as_total_charge
#     k3 = as_opening_title
#     k3 = as_job_type
#     k3 = as_agency_name
#     k3 = as_to_full
#     k3 = feedback
#
# 4
# k1 =  hr
# basestring
# k1 =  fp
# dict
#   k2 =  job
#   dict
#     k3 = as_to
#     k3 = as_rate
#     k3 = as_total_charge
#     k3 = as_total_hours
#     k3 = as_from_full
#     k3 = as_ciphertext_opening_recno
#     k3 = as_total_hours_precise
#     k3 = as_opening_title
#     k3 = as_job_type
#     k3 = as_agency_name
#     k3 = as_to_full
#     k3 = as_financial_privacy
#
# 5
# k1 =  hr
# dict
#   k2 =  job
#   list
#     item 0
#     k4 =  as_to
#     k4 =  as_total_hours
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     item 1
#     k4 =  as_to
#     k4 =  as_rate
#     k4 =  as_total_charge
#     k4 =  as_total_hours
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     k4 =  feedback
# k1 =  fp
# dict
#   k2 =  job
#   dict
#     k3 = as_to
#     k3 = as_rate
#     k3 = as_total_charge
#     k3 = as_total_hours
#     k3 = as_total_hours_precise
#     k3 = as_opening_title
#     k3 = as_job_type
#     k3 = as_to_full
#     k3 = feedback
#
# 6
# k1 =  hr
# basestring
# k1 =  fp
# dict
#   k2 =  job
#   list
#     item 0
#     k4 =  as_total_hours
#     k4 =  as_rate
#     k4 =  as_financial_privacy
#     k4 =  as_to
#     k4 =  as_from_full
#     k4 =  as_ciphertext_opening_recno
#     k4 =  as_total_hours_precise
#     k4 =  as_total_charge
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_agency_name
#     k4 =  as_to_full
#     k4 =  feedback
#     item 1
#     k4 =  as_to
#     k4 =  as_rate
#     k4 =  as_total_charge
#     k4 =  as_total_hours
#     k4 =  as_from_full
#     k4 =  as_ciphertext_opening_recno
#     k4 =  feedback
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     k4 =  as_agency_name
#     k4 =  as_financial_privacy
#     item 2
#     k4 =  as_to
#     k4 =  as_rate
#     k4 =  as_total_charge
#     k4 =  as_total_hours
#     k4 =  as_from_full
#     k4 =  as_ciphertext_opening_recno
#     k4 =  feedback
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     k4 =  as_agency_name
#     k4 =  as_financial_privacy
#     item 3
#     k4 =  as_to
#     k4 =  feedback
#     k4 =  as_total_hours
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     item 4
#     k4 =  as_total_hours
#     k4 =  as_rate
#     k4 =  as_financial_privacy
#     k4 =  as_to
#     k4 =  as_from_full
#     k4 =  as_ciphertext_opening_recno
#     k4 =  as_total_hours_precise
#     k4 =  as_total_charge
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_agency_name
#     k4 =  as_to_full
#     k4 =  feedback
#
# 7
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 8
# k1 =  hr
# dict
#   k2 =  job
#   dict
#     k3 = as_total_hours
#     k3 = as_rate
#     k3 = as_total_charge
#     k3 = as_to
#     k3 = as_total_hours_precise
#     k3 = as_opening_title
#     k3 = as_job_type
#     k3 = as_to_full
# k1 =  fp
# dict
#   k2 =  job
#   dict
#     k3 = as_to
#     k3 = as_rate
#     k3 = feedback
#     k3 = as_total_hours
#     k3 = as_total_hours_precise
#     k3 = as_opening_title
#     k3 = as_job_type
#     k3 = as_to_full
#     k3 = as_total_charge
#
# 9
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 10
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 11
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 12
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 13
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 14
# k1 =  hr
# basestring
# k1 =  fp
# dict
#   k2 =  job
#   list
#     item 0
#     k4 =  as_to
#     k4 =  as_rate
#     k4 =  as_total_charge
#     k4 =  as_total_hours
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     item 1
#     k4 =  as_total_hours
#     k4 =  as_rate
#     k4 =  as_financial_privacy
#     k4 =  feedback
#     k4 =  as_to
#     k4 =  as_from_full
#     k4 =  as_ciphertext_opening_recno
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_agency_name
#     k4 =  as_to_full
#     k4 =  as_total_charge
#
# 15
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 16
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 17
# k1 =  hr
# basestring
# k1 =  fp
# basestring
#
# 18
# k1 =  hr
# dict
#   k2 =  job
#   list
#     item 0
#     k4 =  as_to
#     k4 =  as_rate
#     k4 =  as_financial_privacy
#     k4 =  as_total_hours
#     k4 =  as_from_full
#     k4 =  as_ciphertext_opening_recno
#     k4 =  as_total_hours_precise
#     k4 =  as_total_charge
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     k4 =  as_agency_name
#     k4 =  feedback
#     item 1
#     k4 =  as_total_hours
#     k4 =  feedback
#     k4 =  as_to
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     item 2
#     k4 =  as_to
#     k4 =  as_rate
#     k4 =  as_total_charge
#     k4 =  as_total_hours
#     k4 =  as_from_full
#     k4 =  as_ciphertext_opening_recno
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     k4 =  as_agency_name
#     k4 =  as_financial_privacy
#     item 3
#     k4 =  as_total_hours
#     k4 =  feedback
#     k4 =  as_to
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     item 4
#     k4 =  as_total_hours
#     k4 =  as_rate
#     k4 =  as_total_charge
#     k4 =  as_to
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     k4 =  feedback
#     item 5
#     k4 =  as_to
#     k4 =  as_total_hours
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     item 6
#     k4 =  as_total_hours
#     k4 =  feedback
#     k4 =  as_to
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
#     item 7
#     k4 =  as_to
#     k4 =  feedback
#     k4 =  as_total_hours
#     k4 =  as_total_hours_precise
#     k4 =  as_opening_title
#     k4 =  as_job_type
#     k4 =  as_to_full
# k1 =  fp
# dict
#   k2 =  job
#   dict
#     k3 = as_total_hours
#     k3 = as_rate
#     k3 = as_financial_privacy
#     k3 = as_to
#     k3 = as_from_full
#     k3 = as_ciphertext_opening_recno
#     k3 = as_total_hours_precise
#     k3 = as_opening_title
#     k3 = as_job_type
#     k3 = as_agency_name
#     k3 = as_to_full
#     k3 = as_total_charge
#
# 19
# k1 =  hr
# basestring
# k1 =  fp
# dict
#   k2 =  job
#   dict
#     k3 = as_total_hours
#     k3 = as_rate
#     k3 = as_total_charge
#     k3 = as_to
#     k3 = as_total_hours_precise
#     k3 = as_opening_title
#     k3 = as_job_type
#     k3 = as_to_full
#     k3 = feedback

# %%
def triage(dict_, level=0):
    if not(isinstance(dict_, float) or isinstance(dict_, basestring)):
        print type(dict_)
        for key, val in dict_.iteritems():
            print ' '*level*2, key
            if isinstance(val, dict):
                triage(val, level=level+1)
            elif isinstance(val, list):
                for index, item in enumerate(val): 
                    print ' '*level*2, 'item', index
                    triage(item, level=level+1)
            elif isinstance(val, basestring):
                print ' '*(level+1)*2, '=', val

for x in range(1000,1020):
    print x
    jobs = df.dev_job_categories_v2[x]
    triage(jobs)
# Out:
# 1000
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Information Security
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668419
#        name
#          = IT & Networking
#  item 1
# <type 'dict'>
#    name
#      = Network & System Administration
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = IT & Networking
#        uid
#          = 531770282580668419
#  item 2
# <type 'dict'>
#    name
#      = Scripts & Utilities
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 3
# <type 'dict'>
#    name
#      = Web Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 4
# <type 'dict'>
#    name
#      = Technical Writing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Writing
#        uid
#          = 531770282580668423
#  item 5
# <type 'dict'>
#    name
#      = Academic Writing & Research
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668423
#        name
#          = Writing
#  item 6
# <type 'dict'>
#    name
#      = Other - IT & Networking
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = IT & Networking
#        uid
#          = 531770282580668419
# 1001
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Web Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 1
# <type 'dict'>
#    name
#      = Scripts & Utilities
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 2
# <type 'dict'>
#    name
#      = Product Management
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 3
# <type 'dict'>
#    name
#      = Ecommerce Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 4
# <type 'dict'>
#    name
#      = A/B Testing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Data Science & Analytics
#        uid
#          = 531770282580668420
#  item 5
# <type 'dict'>
#    name
#      = Desktop Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
# 1002
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Web Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 1
# <type 'dict'>
#    name
#      = Product Management
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 2
# <type 'dict'>
#    name
#      = SEO - Search Engine Optimization
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668422
#        name
#          = Sales & Marketing
#  item 3
# <type 'dict'>
#    name
#      = Ecommerce Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 4
# <type 'dict'>
#    name
#      = Web & Mobile Design
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 5
# <type 'dict'>
#    name
#      = QA & Testing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 6
# <type 'dict'>
#    name
#      = SEM - Search Engine Marketing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668422
#        name
#          = Sales & Marketing
#  item 7
# <type 'dict'>
#    name
#      = SMM - Social Media Marketing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Sales & Marketing
#        uid
#          = 531770282580668422
#  item 8
# <type 'dict'>
#    name
#      = Other - Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
# 1003
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Other - Data Science & Analytics
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668420
#        name
#          = Data Science & Analytics
#  item 1
# <type 'dict'>
#    name
#      = Data Mining & Management
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Data Science & Analytics
#        uid
#          = 531770282580668420
#  item 2
# <type 'dict'>
#    name
#      = Data Visualization
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Data Science & Analytics
#        uid
#          = 531770282580668420
#  item 3
# <type 'dict'>
#    name
#      = Quantitative Analysis
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668420
#        name
#          = Data Science & Analytics
# 1004
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Web Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 1
# <type 'dict'>
#    name
#      = Game Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 2
# <type 'dict'>
#    name
#      = Desktop Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 3
# <type 'dict'>
#    name
#      = Scripts & Utilities
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 4
# <type 'dict'>
#    name
#      = Mobile Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 5
# <type 'dict'>
#    name
#      = Other - Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
# 1005
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Other - Writing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Writing
#        uid
#          = 531770282580668423
#  item 1
# <type 'dict'>
#    name
#      = Scripts & Utilities
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 2
# <type 'dict'>
#    name
#      = QA & Testing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 3
# <type 'dict'>
#    name
#      = Data Entry
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668416
#        name
#          = Admin Support
#  item 4
# <type 'dict'>
#    name
#      = General Translation
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282584862720
#        name
#          = Translation
#  item 5
# <type 'dict'>
#    name
#      = Game Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 6
# <type 'dict'>
#    name
#      = Web Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 7
# <type 'dict'>
#    name
#      = ERP / CRM Software
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = IT & Networking
#        uid
#          = 531770282580668419
#  item 8
# <type 'dict'>
#    name
#      = Desktop Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 9
# <type 'dict'>
#    name
#      = Web Content
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668423
#        name
#          = Writing
# 1006
# 1007
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Scripts & Utilities
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 1
# <type 'dict'>
#    name
#      = Desktop Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 2
# <type 'dict'>
#    name
#      = Other - Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 3
# <type 'dict'>
#    name
#      = Ecommerce Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 4
# <type 'dict'>
#    name
#      = Web & Mobile Design
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
# 1008
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Ecommerce Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 1
# <type 'dict'>
#    name
#      = Product Management
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 2
# <type 'dict'>
#    name
#      = Technical Writing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Writing
#        uid
#          = 531770282580668423
#  item 3
# <type 'dict'>
#    name
#      = Web Content
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668423
#        name
#          = Writing
#  item 4
# <type 'dict'>
#    name
#      = SEO - Search Engine Optimization
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668422
#        name
#          = Sales & Marketing
#  item 5
# <type 'dict'>
#    name
#      = QA & Testing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 6
# <type 'dict'>
#    name
#      = Other - Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 7
# <type 'dict'>
#    name
#      = Web Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 8
# <type 'dict'>
#    name
#      = Web & Mobile Design
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
# 1009
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = SMM - Social Media Marketing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668422
#        name
#          = Sales & Marketing
#  item 1
# <type 'dict'>
#    name
#      = Graphic Design
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668421
#        name
#          = Design & Creative
#  item 2
# <type 'dict'>
#    name
#      = Web Content
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668423
#        name
#          = Writing
#  item 3
# <type 'dict'>
#    name
#      = Personal / Virtual Assistant
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Admin Support
#        uid
#          = 531770282580668416
#  item 4
# <type 'dict'>
#    name
#      = Other - Customer Service
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668417
#        name
#          = Customer Service
#  item 5
# <type 'dict'>
#    name
#      = Transcription
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668416
#        name
#          = Admin Support
#  item 6
# <type 'dict'>
#    name
#      = Customer Service
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Customer Service
#        uid
#          = 531770282580668417
#  item 7
# <type 'dict'>
#    name
#      = Resumes & Cover Letters
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668423
#        name
#          = Writing
#  item 8
# <type 'dict'>
#    name
#      = Data Entry
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Admin Support
#        uid
#          = 531770282580668416
#  item 9
# <type 'dict'>
#    name
#      = Copywriting
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Writing
#        uid
#          = 531770282580668423
# 1010
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Web Research
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668416
#        name
#          = Admin Support
#  item 1
# <type 'dict'>
#    name
#      = Web Content
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668423
#        name
#          = Writing
#  item 2
# <type 'dict'>
#    name
#      = Data Entry
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Admin Support
#        uid
#          = 531770282580668416
#  item 3
# <type 'dict'>
#    name
#      = Other - Admin Support
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668416
#        name
#          = Admin Support
#  item 4
# <type 'dict'>
#    name
#      = Personal / Virtual Assistant
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668416
#        name
#          = Admin Support
#  item 5
# <type 'dict'>
#    name
#      = Article & Blog Writing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Writing
#        uid
#          = 531770282580668423
# 1011
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Other - IT & Networking
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = IT & Networking
#        uid
#          = 531770282580668419
#  item 1
# <type 'dict'>
#    name
#      = Database Administration
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = IT & Networking
#        uid
#          = 531770282580668419
# 1012
# <type 'dict'>
#  dev_job_categories_v
# <type 'dict'>
#    name
#      = Electrical Engineering
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282584862722
#        name
#          = Engineering & Architecture
# 1013
# <type 'dict'>
#  dev_job_categories_v
# <type 'dict'>
#    name
#      = QA & Testing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
# 1014
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Mobile Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 1
# <type 'dict'>
#    name
#      = Desktop Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 2
# <type 'dict'>
#    name
#      = Other - Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
# 1015
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Product Management
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 1
# <type 'dict'>
#    name
#      = Other - Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 2
# <type 'dict'>
#    name
#      = Web & Mobile Design
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 3
# <type 'dict'>
#    name
#      = QA & Testing
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 4
# <type 'dict'>
#    name
#      = Web Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 5
# <type 'dict'>
#    name
#      = Ecommerce Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
# 1016
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = General Translation
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Translation
#        uid
#          = 531770282584862720
#  item 1
# <type 'dict'>
#    name
#      = Web & Mobile Design
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 2
# <type 'dict'>
#    name
#      = Web Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 3
# <type 'dict'>
#    name
#      = Data Entry
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Admin Support
#        uid
#          = 531770282580668416
# 1017
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Data Entry
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668416
#        name
#          = Admin Support
#  item 1
# <type 'dict'>
#    name
#      = Mobile Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 2
# <type 'dict'>
#    name
#      = Ecommerce Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = Web, Mobile & Software Dev
#        uid
#          = 531770282580668418
#  item 3
# <type 'dict'>
#    name
#      = Other - Software Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
#  item 4
# <type 'dict'>
#    name
#      = Web Development
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668418
#        name
#          = Web, Mobile & Software Dev
# 1018
# <type 'dict'>
#  dev_job_categories_v
# <type 'dict'>
#    name
#      = Personal / Virtual Assistant
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668416
#        name
#          = Admin Support
# 1019
# <type 'dict'>
#  dev_job_categories_v
#  item 0
# <type 'dict'>
#    name
#      = Information Security
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668419
#        name
#          = IT & Networking
#  item 1
# <type 'dict'>
#    name
#      = Network & System Administration
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668419
#        name
#          = IT & Networking
#  item 2
# <type 'dict'>
#    name
#      = ERP / CRM Software
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        name
#          = IT & Networking
#        uid
#          = 531770282580668419
#  item 3
# <type 'dict'>
#    name
#      = Database Administration
#    groups
# <type 'dict'>
#      group
# <type 'dict'>
#        uid
#          = 531770282580668419
#        name
#          = IT & Networking

# %%
for x in range(1000,1020):
    print x
    jobs = df.education[x]
    triage(jobs)
# Out:
# 1000
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 12/2014
#    ed_area
#      = Security
#    ed_school
#      = UET LAHORE
#    ed_comment
#      = Networks
# Security
# Operating System
# Programming
#    ed_from
#      = 01/2012
#    ed_degree
#      = Master of Science (M.S.)
# 1001
# <type 'dict'>
#  institution
#  item 0
# <type 'dict'>
#    ed_to
#      = 12/2011
#    ed_area
#      = Computer science
#    ed_school
#      = State University of New York at Stony Brook
#    ed_comment
#      =
#    ed_from
#      = 01/2010
#    ed_degree
#      = Master of Science (M.S.)
#  item 1
# <type 'dict'>
#    ed_to
#      = 12/2010
#    ed_area
#      = Computer science
#    ed_school
#      = State University of New York at Stony Brook
#    ed_comment
#      = Human Computer Interaction specialization
#    ed_from
#      = 01/2007
#    ed_degree
#      = Bachelor of Science (B.S.)
# 1002
# 1003
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 12/2004
#    ed_area
#      = Statistics
#    ed_school
#      = Banaras Hindu University
#    ed_comment
#      =
#    ed_from
#      = 01/2002
#    ed_degree
#      = Master of Science (M.S.)
# 1004
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 09/1991
#    ed_area
#      = Computer Sciences
#    ed_school
#      = Technical University Varna
#    ed_comment
#      =
#    ed_from
#      = 09/1988
#    ed_degree
#      = Masters
# 1005
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 12/2013
#    ed_area
#      = Computer engineering
#    ed_school
#      = American College Skopje
#    ed_comment
#      =
#    ed_from
#      = 01/2010
#    ed_degree
#      = Bachelor of Engineering (B.Eng.)
# 1006
# 1007
# <type 'dict'>
#  institution
#  item 0
# <type 'dict'>
#    ed_to
#      = 12/2012
#    ed_area
#      = Strategic Information Systems
#    ed_school
#      = Cardiff University
#    ed_comment
#      = (Passed with merit - secured 63% marks)
#
# Key Modules: Computer Architecture & Networks, Distributed Computer Systems, Autonomic Computing, Management& Information Technology. Dissertation topic was ‘Deriving geospatial information from social networking websites for real world applications’ using Foursquare (a social networking website) API and a software tool I developed in JAVA, Oracle.
#    ed_from
#      = 01/2010
#    ed_degree
#      = Master of Science (M.S.)
#  item 1
# <type 'dict'>
#    ed_to
#      = 12/2010
#    ed_area
#      = Information Technology
#    ed_school
#      = St. Thomas College of Engineering & Tech.
#    ed_comment
#      = (Secured DGPA  8.22 / 10)
# Key Modules: Object oriented programming (JAVA, C++), Operating systems, Networking and data communication, Management information systems, Database management systems. Recipient of undergraduate university scholarship for securing first class degree.
#    ed_from
#      = 01/2004
#    ed_degree
#      = Bachelor of Technology (B.Tech.)
#  item 2
# <type 'dict'>
#    ed_to
#      = 12/2004
#    ed_area
#      =
#    ed_school
#      = Tirthapati Institution
#    ed_comment
#      = (Secured 70.5% marks)
#    ed_from
#      = 01/2002
#    ed_degree
#      = High school degree
#  item 3
# <type 'dict'>
#    ed_to
#      = 12/2002
#    ed_area
#      =
#    ed_school
#      = Nava Nalanda High School
#    ed_comment
#      = (Secured 77.375% marks)
#    ed_from
#      = 01/1990
#    ed_degree
#      = High school degree
# 1008
# <type 'dict'>
#  institution
#  item 0
# <type 'dict'>
#    ed_to
#      = 07/2007
#    ed_area
#      = BE
#    ed_school
#      = BVCEOW
#    ed_comment
#      = I have completed BE(comp) from Pune University in 2007.
#    ed_from
#      = 09/2003
#    ed_degree
#      = Bachelors
#  item 1
# <type 'dict'>
#    ed_to
#      = 06/2003
#    ed_area
#      = HSC
#    ed_school
#      = S.P.College
#    ed_comment
#      =
#    ed_from
#      = 06/2001
#    ed_degree
#      = High School
# 1009
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 12/2010
#    ed_area
#      = Design, Branding and Marketing
#    ed_school
#      = University of the Creative Arts
#    ed_comment
#      =
#    ed_from
#      = 01/2006
#    ed_degree
#      = Bachelor of Arts (B.A.)
# 1010
# <type 'dict'>
#  institution
#  item 0
# <type 'dict'>
#    ed_to
#      = 01/2016
#    ed_area
#      = Public administration
#    ed_school
#      = Cebu Normal University
#    ed_comment
#      =
#    ed_from
#      = 01/2012
#    ed_degree
#      = Master of Public Adminstration (M.P.A.)
#  item 1
# <type 'dict'>
#    ed_to
#      = 12/2006
#    ed_area
#      = Computer science
#    ed_school
#      = Systems Technology Institute
#    ed_comment
#      = self supporting student
#    ed_from
#      = 01/2001
#    ed_degree
#      = Bachelor of Science (B.S.)
# 1011
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 12/2017
#    ed_area
#      =
#    ed_school
#      = Univerzitet Metropolitan
#    ed_comment
#      =
#    ed_from
#      = 01/2013
#    ed_degree
#      =
# 1012
# <type 'dict'>
#  institution
#  item 0
# <type 'dict'>
#    ed_to
#      = 01/2015
#    ed_area
#      = power electronics and power system
#    ed_school
#      = adishankara institue o engineering and technology
#    ed_comment
#      =
#    ed_from
#      = 01/2013
#    ed_degree
#      = Master of Technology (M.Tech.)
#  item 1
# <type 'dict'>
#    ed_to
#      = 01/2013
#    ed_area
#      = Electrical engineering
#    ed_school
#      = college of engineering thalassery
#    ed_comment
#      =
#    ed_from
#      = 01/2009
#    ed_degree
#      = Bachelor of Technology (B.Tech.)
# 1013
# 1014
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 12/2010
#    ed_area
#      =
#    ed_school
#      = B P S & J C
#    ed_comment
#      =
#    ed_from
#      = 01/2003
#    ed_degree
#      =
# 1015
# <type 'dict'>
#  institution
#  item 0
# <type 'dict'>
#    ed_to
#      = 07/2002
#    ed_area
#      = Certificate in Web Programming
#    ed_school
#      = Institut Superieur d'Informatique (ISI)
#    ed_comment
#      =
#    ed_from
#      = 09/2001
#    ed_degree
#      = Diploma
#  item 1
# <type 'dict'>
#    ed_to
#      = 07/2001
#    ed_area
#      = Certificate in Computer Science
#    ed_school
#      = Universite du Quebec (UQAM)
#    ed_comment
#      =
#    ed_from
#      = 09/2000
#    ed_degree
#      = Diploma
#  item 2
# <type 'dict'>
#    ed_to
#      = 01/1999
#    ed_area
#      = Bachelor Degree in Music
#    ed_school
#      = University of Montreal
#    ed_comment
#      =
#    ed_from
#      = 07/1996
#    ed_degree
#      = Bachelors
# 1016
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 12/2007
#    ed_area
#      = Communication - programming - networks
#    ed_school
#      = Faculty of Engineering - Communication and Electronic Dept
#    ed_comment
#      = Faculty of Engineering - Communication and Electronic Dept
#
# Mansoura University
#    ed_from
#      = 01/2002
#    ed_degree
#      = Bachelor's degree
# 1017
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 12/2009
#    ed_area
#      = Computer engineering
#    ed_school
#      = Binus University
#    ed_comment
#      = Master Degree
#    ed_from
#      = 01/2005
#    ed_degree
#      = Master of Social Work (M.S.W.)
# 1018
# <type 'dict'>
#  institution
#  item 0
# <type 'dict'>
#    ed_to
#      = 01/2019
#    ed_area
#      = Information Technology
#    ed_school
#      = Jahangirnagar University
#    ed_comment
#      = I am currently studying here.
#
# Programs offered by IIT aims at developing up-to-date human resources in the field of Information Technology. Through the delivery of state-of-art teaching and practical insights, these programs will ultimately endeavor to create the IT specialists who will lead our nation as well as the world.
#
# http://www.juniv.edu/iit/
#    ed_from
#      = 01/2015
#    ed_degree
#      = Bachelor of Science (B.S.)
#  item 1
# <type 'dict'>
#    ed_to
#      = 01/2015
#    ed_area
#      = science
#    ed_school
#      = Dhaka Residential Model College
#    ed_comment
#      = I completed my secondary and higher education here.
#
# Dhaka Residential Model College is noted for its academic performance and extracurricular activities, having produced many notable alumni including leaders in business, the military and state and national politics as well as senior government officers, scientists and engineers.
#
# http://drmc.edu.bd.banglavision.com/
#    ed_from
#      = 01/2005
#    ed_degree
#      = High school degree
# 1019
# <type 'dict'>
#  institution
# <type 'dict'>
#    ed_to
#      = 12/1997
#    ed_area
#      =
#    ed_school
#      = Ecole Superieur d'informatique
#    ed_comment
#      =
#    ed_from
#      = 01/1994
#    ed_degree
#      = Master of Computer Applications (M.C.A.)

# %%
q = 3.4
print isinstance(q, float)
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8714 entries, 0 to 8713
# Data columns (total 48 columns):
# ag_cny_recno                 735 non-null float64
# ag_country                   735 non-null object
# ag_country_tz                735 non-null object
# ag_description               735 non-null object
# ag_logo                      735 non-null object
# ag_name                      735 non-null object
# ag_recent_hours              735 non-null float64
# ag_total_hours               735 non-null float64
# agency_ciphertext            735 non-null object
# assignments                  8714 non-null object
# ciphertext                   8714 non-null object
# dev_ac_agencies              8714 non-null object
# dev_adj_score                8714 non-null float64
# dev_adj_score_recent         8714 non-null float64
# dev_bill_rate                8714 non-null float64
# dev_billed_assignments       8714 non-null int64
# dev_blurb                    8714 non-null object
# dev_city                     8714 non-null object
# dev_country                  8714 non-null object
# dev_eng_skill                8714 non-null object
# dev_first_name               8714 non-null object
# dev_groups                   8714 non-null object
# dev_is_affiliated            8714 non-null int64
# dev_job_categories_v2        8337 non-null object
# dev_last_activity            8714 non-null object
# dev_last_name                8714 non-null object
# dev_last_worked              8714 non-null object
# dev_last_worked_ts           8714 non-null object
# dev_portfolio_items_count    8714 non-null int64
# dev_portrait                 8714 non-null object
# dev_portrait_100             8714 non-null object
# dev_portrait_32              8714 non-null object
# dev_portrait_50              8714 non-null object
# dev_profile_title            8714 non-null object
# dev_recno                    8714 non-null int64
# dev_recno_ciphertext         8714 non-null object
# dev_short_name               8714 non-null object
# dev_timezone                 8714 non-null object
# dev_tot_feedback             8714 non-null int64
# dev_total_hours              8714 non-null float64
# dev_ui_profile_access        8714 non-null object
# education                    8714 non-null object
# experiences                  8714 non-null object
# job_categories               4222 non-null object
# permalink                    8714 non-null object
# portfolio_items              8714 non-null object
# skills                       8714 non-null object
# tsexams                      8714 non-null object
# dtypes: float64(7), int64(5), object(36)
# memory usage: 3.3+ MB

# %%
print as_profiles_lod[0]['ciphertext']
# Out:
# ~01cae3810dc6d2bbbc

# %%
print as_profiles_lod[0]['dev_recno_ciphertext']
# Out:
# ~01cae3810dc6d2bbbc

# %%
if profile['assignments']['hr'] =

# %%
print as_profiles_lod[0]['assignments']['hr']

# %%
print type(as_profiles_lod[0]['assignments']['hr'])
# Out:
# <type 'unicode'>

# %%
print type(as_profiles_lod[0]['assignments']['fp'])
# Out:
# <type 'dict'>

# %%
print as_profiles_lod[0]['assignments']['fp']
# Out:
# {u'job': {u'as_to': u'01/2013', u'feedback': {u'comment': u'Excellent work will be working with you again.', u'score': u'4.35', u'scores': {u'score': [{u'score': u'5', u'description': u'competency and skills for the job, understanding of specifications/instructions', u'label': u'Skills'}, {u'score': u'4', u'description': u'quality of work deliverables', u'label': u'Quality'}, {u'score': u'4', u'description': u'online presence on a consistent schedule', u'label': u'Availability'}, {u'score': u'3', u'description': u'ability to complete tasks on time', u'label': u'Deadlines'}, {u'score': u'5', u'description': u'communication skills, frequent progress updates, responsiveness', u'label': u'Communication'}, {u'score': u'5', u'description': u'cooperation and flexibility, suggestions for improvement', u'label': u'Cooperation'}]}}, u'as_total_hours': u'0.00', u'as_total_hours_precise': u'0', u'as_opening_title': u'Development of Firovia client/associate project management database', u'as_job_type': u'Fixed', u'as_to_full': u'01/09/2013'}}

# %%
print as_profiles_lod[1]['assignments']
# Out:
# {u'hr': u'', u'fp': u''}

# %%
print type(as_profiles_lod[2]['assignments']['hr'])
# Out:
# <type 'unicode'>

# %%
print as_profiles_lod[3]['assignments']['hr']['job'][0]
# Out:
# {u'job': [{u'as_total_hours': u'614', u'as_rate': u'$22.22', u'as_total_charge': u'13642.99', u'as_to': u'Present', u'as_total_hours_precise': u'614', u'as_opening_title': u'Zend Senior Developer + Junior Developer for big web application', u'as_job_type': u'Hourly', u'as_to_full': u'Present'}, {u'as_total_hours': u'1196', u'as_rate': u'$16.67', u'as_total_charge': u'19932.02', u'as_to': u'02/2013', u'as_total_hours_precise': u'1195.66666666667', u'as_opening_title': u'Top notch PHP / Zend Developer (experienced)', u'as_job_type': u'Hourly', u'as_to_full': u'02/07/2013', u'feedback': {u'comment': u'Igor is very good. He completed the project and was very professional in communication, team working. He was always available for conference calls and was very good at PHP/Zend.', u'score': u'5.00', u'scores': {u'score': [{u'score': u'5', u'description': u'competency and skills for the job, understanding of specifications/instructions', u'label': u'Skills'}, {u'score': u'5', u'description': u'quality of work deliverables', u'label': u'Quality'}, {u'score': u'5', u'description': u'online presence on a consistent schedule', u'label': u'Availability'}, {u'score': u'5', u'description': u'ability to complete tasks on time', u'label': u'Deadlines'}, {u'score': u'5', u'description': u'communication skills, frequent progress updates, responsiveness', u'label': u'Communication'}, {u'score': u'5', u'description': u'cooperation and flexibility, suggestions for improvement', u'label': u'Cooperation'}]}}}]}

# %%
print as_profiles_lod[3]['assignments']['hr']['job'][1]
# Out:
# {u'as_total_hours': u'1196', u'as_rate': u'$16.67', u'as_total_charge': u'19932.02', u'as_to': u'02/2013', u'as_total_hours_precise': u'1195.66666666667', u'as_opening_title': u'Top notch PHP / Zend Developer (experienced)', u'as_job_type': u'Hourly', u'as_to_full': u'02/07/2013', u'feedback': {u'comment': u'Igor is very good. He completed the project and was very professional in communication, team working. He was always available for conference calls and was very good at PHP/Zend.', u'score': u'5.00', u'scores': {u'score': [{u'score': u'5', u'description': u'competency and skills for the job, understanding of specifications/instructions', u'label': u'Skills'}, {u'score': u'5', u'description': u'quality of work deliverables', u'label': u'Quality'}, {u'score': u'5', u'description': u'online presence on a consistent schedule', u'label': u'Availability'}, {u'score': u'5', u'description': u'ability to complete tasks on time', u'label': u'Deadlines'}, {u'score': u'5', u'description': u'communication skills, frequent progress updates, responsiveness', u'label': u'Communication'}, {u'score': u'5', u'description': u'cooperation and flexibility, suggestions for improvement', u'label': u'Cooperation'}]}}}

# %%
q = {'dog': 'day', 'cat': '~yay'}

# %%
def possible_key(dict):
    key_flag = False
    possible_key = ''.join([dict[key] if '~' in dict[key] else '' for key in dict.keys()])
    if possible_key == '': 
        key_flag = True
        possible_key = None
    return key_flag, possible_key
# Out:
# (False, '~yay')

# %%
for index, dict_item in enumerate(as_profiles_lod):
    hr_assignments = dict_item['assignments']['hr']
    if isinstance(hr_assignments, basestring):
        if '~' in hr_assignments:
            return hr_assignments
    elif isinstance(hr_assignments, dict):
#         print "hr_assignments = dict"
        if 'job' in hr_assignments:
#             print 'job'
            hr_assignments_jobs = hr_assignments['job']
            if isinstance(hr_assignments_jobs, list):
#                 print 'is list'
                for job in hr_assignments_jobs:
                    if 'as_ciphertext_opening_recno' in job:
                        print job['as_ciphertext_opening_recno']
                    else:
                        poss_key, ciphertext = possible_key(dict)
                        if poss_key: return ciphertext
            elif isinstance(hr_assignments_jobs, dict):
#                 print 'is dict'
                if 'as_ciphertext_opening_recno' in hr_assignments_jobs:
                    print hr_assignments_jobs['as_ciphertext_opening_recno']
        elif 'assignment' in hr_assignments:
#             print 'assignment'
            hr_assignments_jobs = hr_assignments['assignment']
            if isinstance(hr_assignments_jobs, list):
                for job in hr_assignments_jobs:
                    if 'as_ciphertext_opening_recno' in job:
                        print job['as_ciphertext_opening_recno']
        else:
            print 'neither key'
            for job in hr_assignments:
                print type(job)
    elif isinstance(hr_assignments, list):
        print "hr_assignments = list"
        for job in hr_assignments:
            print job

#     print '---------'
    if index > 500: break
# Out:
# ~01d84a6e743b0b5287
# ~01d08c5117652f8d6e
# ~01d6a1d5d4f116e5de
# ~0136359de5872f7560
# ~01cb2dc9b976977bd0
# ~01c5f777dd2e406b19
# ~0116f41576b54662bf
# ~0137abee5b41a1b82b
# ~01a2edc1742a0a993a
# ~01de59c08baf9f59a8
# ~01b3dc6c016de877a6
# ~01a039c54705a324a8
# ~0137b99422993d6246
# ~0192c3da9b4279ae66
# ~016c397ca95eef7335
# ~0179f698dbe57c485e
# ~01fb5cde645c407318
# ~01fb5cde645c407318
# ~01f53c4dab850e0d2a
# ~01aed978f2dd563888
# ~01808abebc5bb954d3
# ~01161cce7f463cf9d4
# ~01ac0325a8fa8a8574
# ~01c2bae51619c2f4d4
# ~012db787300e0a9adc
# ~01538ecc4be6f4977b
# ~019c4be06b0bbe2ddf
# ~0148de673cc9db83ae
# ~01ee4c946bcebd4514
# ~0189939d9bb3e3ae4d
# ~01cf608e9207dc5625
# ~01a42de079929e2feb
# ~01305a13e14291d642
# ~017da997e520448294
# ~0160db10e9ce8f770a
# ~01a322d6644e77d319
# ~01e0c64e8aff4a9642
# ~018ced954e2a7ed01c
# ~0129bd4241624eecee
# ~01799c78454c9cb569
# ~0182ccb490d2680b99
# ~012bd1969edd09b55b
# ~015f1cdc6560646b37
# ~016919712dbec26aa5
# ~018d861c73737007df
# ~01d2292593fc8d65a7
# ~01957d7d2b54f75251
# ~01ea49ae72fe0f0b3c
# ~013ef0e1101c7b17cb
# ~01b342cae81c4b4c6c
# ~016c35d719cae7bcd3
# ~01455cd90cf021b111
# ~014f1884b730bcfb80
# ~01281fc6b1ba979a06
# ~010791fcaede723c18
# ~0172385d188ebc01c0
# ~012ea7cf2737a9a25c
# ~019a11d131babc6814
# ~01416e319fcfebfb21
# ~01a68311fcc27e8d35
# ~01e47241fef3944ef7
# ~019f9886310f36ab33
# ~0105d64f8502694196
# ~01f8ffad18d9b93f11
# ~01a08acc7822d892b5
# ~0110a6439cbd8ce37a
# ~01c67d43503f08aa4b
# ~01ad11c7630eb772cf
# ~01040d06dbf1c89419
# ~017322b036bef635d0
# ~019148192aa6d85cc8
# ~010d46b9e9718fd019
# ~01dbdb244039857e24
# ~010d94bff29ab7c204
# ~0147d230240fd3b026
# ~01f93e2a55dc3ca0af
# ~01af123dce50309012
# ~019c45eaf96934e539
# ~01e4458070da5b4219
# ~01e0a818678fd636d1
# ~01016bf38eda4e780f
# ~0116148aed17c009d8
# ~012f572171da18bf2f
# ~015e1d48d7b598ae89
# ~0139d69deb76f24948
# ~0138413125f06102ee
# ~01a04763b3c4d530d9
# ~01624bde712fe0d992
# ~014442dd0e2af6d07f
# ~014442dd0e2af6d07f
# ~010673748a6ba2803b
# ~01a1e27d63a8f840eb
# ~01a88434596a271d91
# ~01e3e348be6a74956b
# ~01a8698359d43acc50
# ~01988e856b8bf6a339
# ~01cc1a39ae43e82ede
# ~016a63d18fb114f9ab
# ~015a46dad79ccfdafd
# ~01d19071684ff47b28
# ~017e081df8b66f0ebf
# ~013b05ed31b7a03464
# ~01ee4937c49570438c
# ~01b95f1783eb85f5d9
# ~018e46385470bba52f
# ~010bf2af72581a57c3
# ~0196d3e4e1672a6c77
# ~012b6eaa9fe629525f
# ~0130b78e106b69c2b4
# ~017cdb10e4c5ff5b74
# ~01f8f8e6ba9c09181f
# ~01a31ef14e7b1f623b
# ~01b680a181e9d9cd77
# ~01e91a55f8be36b11a
# ~01e7ef5b0d4263b287
# ~01457e872b5d114c50
# ~01002968a2d992e166
# ~01e7ef5b0d4263b287
# ~011d7e66cfc0674704
# ~018a5050a58f75323e
# ~012a9fd0b57ad7a00b
# ~018e5ba7e45fb78199
# ~015e86d7c891714776
# ~0135b5efc3fda93aec
# ~01498f9a6ea66cd96f
# ~01a45e5e21b8d258cd
# ~019f182b8f5cf8716e
# ~01000e131dc97813f0
# ~01aa0ac1c96148568d
# ~01632b26633defa606
# ~011d91867bcf060c2b
# ~01549b6a8243e68b9c
# ~01b0cb4ec118c80a81
# ~0117a2a6e8dcccf547
# ~0117a2a6e8dcccf547
# ~019e17607f8469698a
# ~015d20bef816a1e8a1
# ~017a09d729b844aedf
# ~01bd0d41fb81335a14
# ~01c59976edfff53bca
# ~013942528ba35d3d31
# ~01efb874bb423d1b08
# ~01439ab02ca067755c
# ~01b78f9b50c7a8249a
# ~01c57d3c542ee250b6
# ~01b0418c60a4629d84
# ~01a5cee79bb3cf604b
# ~01e7981386509c6792
# ~01900971b08caeb7c5
# ~01a3fe53e243b07cf3
# ~01161157c1cd4c86e6
# ~0129d0c192eb9cc5d1
# ~01deafe833bfeb74f5
# ~0107d9d5419b55edfe
# ~01df8c436673f9b80d
# ~0161a3292b81ca3c84
# ~0149f3459249d35635
# ~0149f3459249d35635
# ~0179b4310856ae4694
# ~015da3f111ce44580e
# ~015fa68ed40f636da1
# ~015fa68ed40f636da1
# ~01942efdc5232106d4
# ~0183bbc56b3bc8f405
# ~01ebcca6e9f08f6827
# ~019d1d3368b04dadf3
# ~015e7474d9840b76cf
# ~013e7fe3b9b54ae772
# ~01d8332eba20f4302d
# ~013b63f7400ad16711
# ~01f18de68883efd2ee
# ~01a8e511c2612a5ef3
# ~01a692137ff2176917
# ~0168fc796363620168
# ~0196d748058b8c5da8
# ~01a413effbc2387c70
# ~01b46c390b600a3d32
# ~01b9c59e33ccdd672e
# ~0154ac07fefba35673
# ~01ba3650439d3e775f
# ~016cefd8a5f9694cf0
# ~01551bfc1fc43d625b
# ~01a931e6890f576099
# ~0180971bed5f9a7256
# ~01d46e28ac5fa801a4
# ~013e40da08bc5bfcbe
# ~015840f9794a8c9a6e
# ~015840f9794a8c9a6e
# ~0188c76902234be6a8
